# %% [markdown]
# # Import Packages

# %%
import json
import os
import pandas as pd
from datetime import datetime

# %% [markdown]
# # Example JSON Load

# %%
sample = {
    "col1": {
        "Layer2":[{
            "Layer3"
        }]
    }, 
    "col2": "Hello"
}

# %%
pd.DataFrame.from_dict(sample)
# Out:
#               col1   col2
# Layer2  [{Layer3}]  Hello

# %% [markdown]
# # Load Data

# %%
data_folder = "raw_data/"
output_dir = "output_data/"
file = "sdgeorge_cyverse.json"
raw_json = None

#Handy for making an output dir inline if needed. 
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

#I always read JSON in as JSON first and then parse. 
with open(data_folder + file, "r+") as f:
    raw_json = json.load(f)
raw_json
# Out:
# {'logs': [{'_id': 'Bash:0962bdbd-2ad5-4603-8c84-abb884c6121c',
#    '_rev': '6-983019e528a22175815cc8f3280badb3',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2023-01-19 16:10:54.892756',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-19:16:10'}]},
#    'log_id': 'd04e4ff0c8708760457e1cefad014855b3262f35c85a7a76c87d1f72539299ec',
#    'log_type': 'Bash',
#    'machine_id': 'a3f8b',
#    'session_id': 'sdgeorge',
#    'timestamp': '2023-01-19 16:17:38.825687'},
#   {'_id': 'Bash:228fec05-757c-474a-8a61-e899518fc635',
#    '_rev': '1-5625a6768d30b3d30808d03cbd29ed7f',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2022-11-21 20:39:59.313098',
#    'log': {'commands': []},
#    'log_id': '2ad878c3393162c3ce826b3660d608f6b82c6f6af6a93ae05b27105945324187',
#    'log_type': 'Bash',
#    'machine_id': 'ad8ae',
#    'session_id': 'None',
#    'timestamp': '2022-11-21 20:39:59.313098'},
#   {'_id': 'Bash:29b65ae0-1c67-485c-abad-f3123428339b',
#    '_rev': '71-4b5c3f0879dcbe98acd3e0080a40bb79',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2023-01-17 19:03:21.927560',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls /home/jovyan',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-01-17:19:03'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '.',
#       'full_command': 'ls .',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-01-17:19:03'},
#      {'command': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#       'file': '',
#       'filename': '',
#       'full_command': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#       'stderr': '/home/jovyan/.offline.sh: line 368: /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES: Is a directory',
#       'stdout': '',
#       'time': '2023-01-17:19:03'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-01-17:19:03'},
#      {'command': 'ls',
#       'file': '',
#       'filename': './data/input/RNA_SEQ_SAMPLES',
#       'full_command': 'ls ./data/input/RNA_SEQ_SAMPLES',
#       'stderr': "ls: cannot access './data/input/RNA_SEQ_SAMPLES': No such file or directory",
#       'stdout': '',
#       'time': '2023-01-17:19:04'},
#      {'command': 'ls',
#       'file': '',
#       'filename': './data-store/data/input/RNA_SEQ_SAMPLES',
#       'full_command': 'ls ./data-store/data/input/RNA_SEQ_SAMPLES',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-01-17:19:04'},
#      {'command': 'ls',
#       'file': '',
#       'filename': 'stderr.txtls',
#       'full_command': 'ls stderr.txtls stderr.txt',
#       'stderr': "ls: cannot access 'stderr.txtls': No such file or directory",
#       'stdout': 'stderr.txt',
#       'time': '2023-01-17:19:04'},
#      {'command': 'ls',
#       'file': '',
#       'filename': 'stderr.txt',
#       'full_command': 'ls stderr.txt',
#       'stderr': '',
#       'stdout': 'stderr.txt',
#       'time': '2023-01-17:19:05'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls d^t',
#       'stderr': "ls: cannot access 'd^t': No such file or directory",
#       'stdout': '',
#       'time': '2023-01-17:19:08'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-01-17:19:08'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls data-store/data/input/Discov',
#       'stderr': "ls: cannot access 'data-store/data/input/Discov': No such file or directory",
#       'stdout': '',
#       'time': '2023-01-17:19:10'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l data-store/data/input/Discovery/',
#       'stderr': '',
#       'stdout': 'total 0\ndr-x------ 1 jovyan jovyan 0 Sep 20 17:53 FilteredSortedOutput\ndr-x------ 1 jovyan jovyan 0 Sep 20 17:53 RNASequenceOutput\ndr-x------ 1 jovyan jovyan 0 Sep 20 17:53 TSVFiles\ndr-x------ 1 jovyan jovyan 0 Sep 20 17:54 UncompressedSamples',
#       'time': '2023-01-17:19:10'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l data-store/data/input/Discovery/',
#       'stderr': '',
#       'stdout': 'total 0\ndr-x------ 1 jovyan jovyan 0 Sep 20 17:53 FilteredSortedOutput\ndr-x------ 1 jovyan jovyan 0 Sep 20 17:53 RNASequenceOutput\ndr-x------ 1 jovyan jovyan 0 Sep 20 17:53 TSVFiles\ndr-x------ 1 jovyan jovyan 0 Sep 20 17:54 UncompressedSamples',
#       'time': '2023-01-17:19:11'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l data-store/data/input/Discovery/TSVFiles',
#       'stderr': '',
#       'stdout': 'total 0',
#       'time': '2023-01-17:19:12'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data-store/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data\nhome',
#       'time': '2023-01-17:19:12'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'input\niplant\noutput',
#       'time': '2023-01-17:19:12'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd input/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\nRNA_SEQ_SAMPLES',
#       'time': '2023-01-17:19:12'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Discovery/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'FilteredSortedOutput\nRNASequenceOutput\nTSVFiles\nUncompressedSamples',
#       'time': '2023-01-17:19:12'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd TSVFiles/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:12'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:13'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:19:13'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan',
#       'time': '2023-01-17:19:13'},
#      {'command': 'history',
#       'file': '',
#       'filename': '',
#       'full_command': 'history',
#       'stderr': '',
#       'stdout': ' 1 ls /home/jovyan\n 2 ls .\n 3 /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 4 ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 5 ls ./data/input/RNA_SEQ_SAMPLES\n 6 ls ./data-store/data/input/RNA_SEQ_SAMPLES\n 7 ls stderr.txtls stderr.txt\n 8 ls stderr.txt\n 9 ls d^t\n 10 ls\n 11 ls data-store/data/input/Discov\n 12 ls -l data-store/data/input/Discovery/\n 13 ls -l data-store/data/input/Discovery/\n 14 ls -l data-store/data/input/Discovery/TSVFiles\n 15 cd data-store/\n 16 ls\n 17 cd data\n 18 ls\n 19 cd input/\n 20 ls\n 21 cd Discovery/\n 22 ls\n 23 cd TSVFiles/\n 24 ls\n 25 cd ~\n 26 ls\n 27 pwd\n 28 history',
#       'time': '2023-01-17:19:13'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-01-17:19:14'},
#      {'command': 'history',
#       'file': '',
#       'filename': '',
#       'full_command': 'history',
#       'stderr': '',
#       'stdout': ' 1 ls /home/jovyan\n 2 ls .\n 3 /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 4 ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 5 ls ./data/input/RNA_SEQ_SAMPLES\n 6 ls ./data-store/data/input/RNA_SEQ_SAMPLES\n 7 ls stderr.txtls stderr.txt\n 8 ls stderr.txt\n 9 ls d^t\n 10 ls\n 11 ls data-store/data/input/Discov\n 12 ls -l data-store/data/input/Discovery/\n 13 ls -l data-store/data/input/Discovery/\n 14 ls -l data-store/data/input/Discovery/TSVFiles\n 15 cd data-store/\n 16 ls\n 17 cd data\n 18 ls\n 19 cd input/\n 20 ls\n 21 cd Discovery/\n 22 ls\n 23 cd TSVFiles/\n 24 ls\n 25 cd ~\n 26 ls\n 27 pwd\n 28 history\n 29 ! !\n 30 ! !.\n 31 ! pw\n 32 ls\n 33 history',
#       'time': '2023-01-17:19:14'},
#      {'command': 'history',
#       'file': '',
#       'filename': '',
#       'full_command': 'history',
#       'stderr': '',
#       'stdout': ' 1 ls /home/jovyan\n 2 ls .\n 3 /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 4 ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 5 ls ./data/input/RNA_SEQ_SAMPLES\n 6 ls ./data-store/data/input/RNA_SEQ_SAMPLES\n 7 ls stderr.txtls stderr.txt\n 8 ls stderr.txt\n 9 ls d^t\n 10 ls\n 11 ls data-store/data/input/Discov\n 12 ls -l data-store/data/input/Discovery/\n 13 ls -l data-store/data/input/Discovery/\n 14 ls -l data-store/data/input/Discovery/TSVFiles\n 15 cd data-store/\n 16 ls\n 17 cd data\n 18 ls\n 19 cd input/\n 20 ls\n 21 cd Discovery/\n 22 ls\n 23 cd TSVFiles/\n 24 ls\n 25 cd ~\n 26 ls\n 27 pwd\n 28 history\n 29 ! !\n 30 ! !.\n 31 ! pw\n 32 ls\n 33 history\n 34 !\n 35 history',
#       'time': '2023-01-17:19:15'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l',
#       'stderr': '',
#       'stdout': 'total 4\ndrwxrwsrwx 2 root jovyan 42 Jan 17 18:58 data-store\n-rw-r--r-- 1 jovyan users 0 Jan 17 19:22 stderr.txt\n-rw-r--r-- 1 jovyan users 0 Jan 17 19:22 stdout.txt\ndrwxr-xr-x 6 jovyan users 4096 Jan 17 19:03 SuperShell\ndrwsrwsr-x. 2 jovyan users 6 May 3 2022 work',
#       'time': '2023-01-17:19:22'},
#      {'command': 'clear',
#       'file': '',
#       'filename': '',
#       'full_command': 'clear',
#       'stderr': '',
#       'stdout': '\x1b[H\x1b[2J\x1b[3J',
#       'time': '2023-01-17:19:22'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l',
#       'stderr': '',
#       'stdout': 'total 4\ndrwxrwsrwx 2 root jovyan 42 Jan 17 18:58 data-store\n-rw-r--r-- 1 jovyan users 0 Jan 17 19:23 stderr.txt\n-rw-r--r-- 1 jovyan users 0 Jan 17 19:23 stdout.txt\ndrwxr-xr-x 6 jovyan users 4096 Jan 17 19:03 SuperShell\ndrwsrwsr-x. 2 jovyan users 6 May 3 2022 work',
#       'time': '2023-01-17:19:23'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l stderr.txt',
#       'stderr': '',
#       'stdout': '-rw-r--r-- 1 jovyan users 0 Jan 17 19:23 stderr.txt',
#       'time': '2023-01-17:19:23'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l ./data-store/data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#       'stderr': '',
#       'stdout': '-rw-r--r-- 1 jovyan users 0 Jan 17 19:24 stderr.txt\n\n./data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B',
#       'time': '2023-01-17:19:24'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l -R ./data-store/data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': './data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 0\n-r-------- 1 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-------- 1 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-------- 1 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 0\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#       'time': '2023-01-17:19:24'},
#      {'command': 'clear',
#       'file': '',
#       'filename': '',
#       'full_command': 'clear',
#       'stderr': '',
#       'stdout': '\x1b[H\x1b[2J\x1b[3J',
#       'time': '2023-01-17:19:25'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l -R data-store/data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': 'data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B\n\ndata-store/data/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 0\n-r-------- 1 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-------- 1 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-------- 1 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\ndata-store/data/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 0\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#       'time': '2023-01-17:19:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data-store/data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:26'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#       'time': '2023-01-17:19:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-01-17:19:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:29'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/input',
#       'time': '2023-01-17:19:29'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:30'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'input\niplant\noutput',
#       'time': '2023-01-17:19:30'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data',
#       'time': '2023-01-17:19:30'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data-store/data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '/home/jovyan/.offline.sh: line 354: cd: data-store/data/input/RNA_SEQ_SAMPLES/: No such file or directory',
#       'stdout': '',
#       'time': '2023-01-17:19:31'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'input\niplant\noutput',
#       'time': '2023-01-17:19:31'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd input/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:31'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\nRNA_SEQ_SAMPLES',
#       'time': '2023-01-17:19:31'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:31'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-01-17:19:31'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-01-17:19:31'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#       'time': '2023-01-17:19:31'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:31'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/input',
#       'time': '2023-01-17:19:31'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:33'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data',
#       'time': '2023-01-17:19:33'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:33'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:34'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:19:34'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:34'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:34'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan',
#       'time': '2023-01-17:19:34'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:35'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which ls',
#       'stderr': '',
#       'stdout': '/usr/bin/ls',
#       'time': '2023-01-17:19:36'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:37'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '../Drug_B',
#       'full_command': 'cd ../Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:37'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '../..',
#       'full_command': 'cd ../..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:38'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -a',
#       'stderr': '',
#       'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#       'time': '2023-01-17:19:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': './../Drug_A',
#       'full_command': 'cd ./../Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd /home/jovyan/data-store/data/output',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:39'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:39'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:39'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:39'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:40'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:40'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:40'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child',
#       'time': '2023-01-17:19:40'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child/misc_child_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:40'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child',
#       'time': '2023-01-17:19:41'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-01-17:19:41'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:41'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc\nmisc_child',
#       'time': '2023-01-17:19:41'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output',
#       'time': '2023-01-17:19:41'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:41'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child',
#       'time': '2023-01-17:19:41'},
#      {'command': 'pico',
#       'diff_l': 1,
#       'diff_wc': 1,
#       'file': 'YeTest',
#       'filename': 'hello.txt',
#       'new_l': 1,
#       'new_wc': 1,
#       'old_l': 0,
#       'old_wc': 0,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:42',
#       'total_time(s)': 24},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'hello.txt\nmisc_child',
#       'time': '2023-01-17:19:42'},
#      {'command': 'cat',
#       'file': 'YeTest',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt',
#       'stderr': '',
#       'stdout': 'YeTest',
#       'time': '2023-01-17:19:42'},
#      {'command': 'pico',
#       'diff_l': 1,
#       'diff_wc': 3,
#       'file': 'See You Later! ',
#       'filename': 'goodbye.txt',
#       'new_l': 1,
#       'new_wc': 3,
#       'old_l': 0,
#       'old_wc': 0,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:43',
#       'total_time(s)': 14},
#      {'command': 'cat',
#       'file': 'YeTest',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt',
#       'stderr': '',
#       'stdout': 'YeTest\nSee You Later! ',
#       'time': '2023-01-17:19:43'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat',
#       'stderr': '',
#       'stdout': 'abc\ndef',
#       'time': '2023-01-17:19:43'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls > ls.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:44'},
#      {'command': 'cat',
#       'file': 'YeTest',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:50'},
#      {'command': 'cat',
#       'file': 'YeTest\nSee You Later! ',
#       'filename': 'hello_goodbye.txt',
#       'full_command': 'cat hello_goodbye.txt',
#       'stderr': '',
#       'stdout': 'YeTest\nSee You Later! ',
#       'time': '2023-01-17:19:50'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat < hello.txt',
#       'stderr': '',
#       'stdout': 'YeTest',
#       'time': '2023-01-17:19:51'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat > cat.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:51'},
#      {'command': 'cat',
#       'file': 'this is cat input\nMore cat input',
#       'filename': 'cat.out',
#       'full_command': 'cat cat.out',
#       'stderr': '',
#       'stdout': 'this is cat input\nMore cat input',
#       'time': '2023-01-17:19:51'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-01-17:19:51'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo "Hello World"',
#       'stderr': '',
#       'stdout': 'Hello World',
#       'time': '2023-01-17:19:51'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo "hello world"',
#       'stderr': '',
#       'stdout': 'hello world',
#       'time': '2023-01-17:19:52'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo 1 2',
#       'stderr': '',
#       'stdout': '1 2',
#       'time': '2023-01-17:19:52'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “hello world” > misc_child/echo.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:54'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:19:54'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc_child/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:54'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'echo.out\nmisc_child_child',
#       'time': '2023-01-17:19:54'},
#      {'command': 'cat',
#       'file': '“hello world”',
#       'filename': 'echo.out',
#       'full_command': 'cat echo.out',
#       'stderr': '',
#       'stdout': '“hello world”',
#       'time': '2023-01-17:19:54'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'echo.out\nmisc_child_child',
#       'time': '2023-01-17:19:55'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:55'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:19:55'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-01-17:19:55'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat ~/data-store/data/output/misc/*',
#       'stderr': 'cat: /home/jovyan/data-store/data/output/misc/misc_child: Is a directory',
#       'stdout': 'this is cat input\nMore cat input\nSee You Later! \nYeTest\nSee You Later! \nYeTest\ngoodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:19:56'},
#      {'command': 'cat',
#       'file': 'See You Later! ',
#       'filename': 'goodbye.txt',
#       'full_command': 'cat goodbye.txt hello_goodbye.txt hello.txt',
#       'stderr': '',
#       'stdout': 'See You Later! \nYeTest\nSee You Later! \nYeTest',
#       'time': '2023-01-17:19:56'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l ~/*.log',
#       'stderr': "ls: cannot access '–l': No such file or directory\nls: cannot access '/home/jovyan/*.log': No such file or directory",
#       'stdout': '',
#       'time': '2023-01-17:19:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:19:58'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:58'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc\nmisc_child',
#       'time': '2023-01-17:19:58'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:58'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'input\niplant\noutput',
#       'time': '2023-01-17:19:58'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:58'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data\nhome',
#       'time': '2023-01-17:19:58'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:19:58'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:19:58'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l ~/*.txt',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': '/home/jovyan/stderr.txt',
#       'time': '2023-01-17:19:58'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l *.txt',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': 'stderr.txt',
#       'time': '2023-01-17:19:59'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:19:59'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l ~/*-store',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': '/home/jovyan/data-store:\ndata\nhome',
#       'time': '2023-01-17:19:59'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l ~/*.err',
#       'stderr': "ls: cannot access '–l': No such file or directory\nls: cannot access '/home/jovyan/*.err': No such file or directory",
#       'stdout': '',
#       'time': '2023-01-17:20:00'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:20:00'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l ~/*.txt',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': '/home/jovyan/stderr.txt',
#       'time': '2023-01-17:20:00'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '~/*.txt',
#       'full_command': 'echo ~/*.txt',
#       'stderr': '',
#       'stdout': '/home/jovyan/stderr.txt',
#       'time': '2023-01-17:20:01'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:20:01'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data-store/data/output/misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:01'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:20:01'},
#      {'command': 'cp',
#       'file': 'See You Later! ',
#       'filename': 'goodbye.txt',
#       'full_command': 'cp goodbye.txt copied_ goodbye.txt',
#       'stderr': "cp: target 'goodbye.txt' is not a directory",
#       'stdout': '',
#       'time': '2023-01-17:20:01'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:20:01'},
#      {'command': 'cp',
#       'file': 'See You Later! ',
#       'filename': 'goodbye.txt',
#       'full_command': 'cp goodbye.txt copied_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:02'},
#      {'command': 'cp',
#       'file': 'See You Later! ',
#       'filename': 'goodbye.txt',
#       'full_command': 'cp goodbye.txt copied_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:02'},
#      {'command': 'cat',
#       'file': 'See You Later! ',
#       'filename': 'copied_goodbye.txt',
#       'full_command': 'cat copied_goodbye.txt',
#       'stderr': '',
#       'stdout': 'See You Later! ',
#       'time': '2023-01-17:20:03'},
#      {'command': 'cp',
#       'file': 'See You Later! ',
#       'filename': 'goodbye.txt',
#       'full_command': 'cp goodbye.txt misc_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:03'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc_child/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:03'},
#      {'command': 'cat',
#       'file': 'See You Later! ',
#       'filename': 'goodbye.txt',
#       'full_command': 'cat goodbye.txt',
#       'stderr': '',
#       'stdout': 'See You Later! ',
#       'time': '2023-01-17:20:03'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:03'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-01-17:20:03'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data-store/data/output/misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:04'},
#      {'command': 'mv',
#       'file': '',
#       'filename': 'goodbye.txt',
#       'full_command': 'mv goodbye.txt renamed_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:04'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child\nrenamed_goodbye.txt',
#       'time': '2023-01-17:20:04'},
#      {'command': 'mv',
#       'file': '',
#       'filename': 'renamed_goodbye.txt',
#       'full_command': 'mv renamed_goodbye.txt misc_child/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:04'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data-store/data/output/misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:05'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:20:05'},
#      {'command': 'ln',
#       'file': '',
#       'filename': '',
#       'full_command': 'ln –s hello.txt linked _hello.txt',
#       'stderr': "ln: target '_hello.txt' is not a directory",
#       'stdout': '',
#       'time': '2023-01-17:20:07'},
#      {'command': 'ln',
#       'file': '',
#       'filename': '',
#       'full_command': 'ln -s hello.txt linked_hello.txt',
#       'stderr': "ln: failed to create symbolic link 'linked_hello.txt': Input/output error",
#       'stdout': '',
#       'time': '2023-01-17:20:07'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-01-17:20:07'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:20:07'},
#      {'command': 'mv',
#       'file': '',
#       'filename': 'hello.txt',
#       'full_command': 'mv hello.txt ~',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:10'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:20:10'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:10'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nhello.txt\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:20:10'},
#      {'command': 'ln',
#       'file': '',
#       'filename': '',
#       'full_command': 'ln -s hello.txt linked_hello.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:11'},
#      {'command': 'cat',
#       'file': 'YeTest',
#       'filename': 'linked_hello.txt',
#       'full_command': 'cat linked_hello.txt',
#       'stderr': '',
#       'stdout': 'YeTest',
#       'time': '2023-01-17:20:11'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l linked_hello.txt',
#       'stderr': '',
#       'stdout': 'lrwxrwxrwx 1 jovyan users 9 Jan 17 20:11 linked_hello.txt -> hello.txt',
#       'time': '2023-01-17:20:11'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir link_test',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:12'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd link_test',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:12'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/link_test',
#       'time': '2023-01-17:20:12'},
#      {'command': 'ln',
#       'file': '',
#       'filename': '',
#       'full_command': 'ln -s ../hello.txt hello.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:13'},
#      {'command': 'cat',
#       'file': 'YeTest',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt',
#       'stderr': '',
#       'stdout': 'YeTest',
#       'time': '2023-01-17:20:13'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l hello.txt',
#       'stderr': '',
#       'stdout': 'lrwxrwxrwx 1 jovyan users 12 Jan 17 20:13 hello.txt -> ../hello.txt',
#       'time': '2023-01-17:20:13'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data-store/data/output/misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:14'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nls.out\nmisc_child',
#       'time': '2023-01-17:20:14'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:15'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nhello.txt\nlinked_hello.txt\nlink_test\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:20:15'},
#      {'command': 'pico',
#       'diff_l': 0,
#       'diff_wc': 1,
#       'file': 'Hello Universe',
#       'filename': 'hello.txt',
#       'new_l': 1,
#       'new_wc': 2,
#       'old_l': 1,
#       'old_wc': 1,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:17',
#       'total_time(s)': 15},
#      {'command': 'cat',
#       'file': 'Hello Universe',
#       'filename': 'linked_hello.txt',
#       'full_command': 'cat linked_hello.txt',
#       'stderr': '',
#       'stdout': 'Hello Universe',
#       'time': '2023-01-17:20:17'},
#      {'command': 'pico',
#       'diff_l': 0,
#       'diff_wc': 0,
#       'file': 'Hello World',
#       'filename': 'hello.txt',
#       'new_l': 1,
#       'new_wc': 2,
#       'old_l': 1,
#       'old_wc': 2,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:18',
#       'total_time(s)': 7},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nhello.txt\nlinked_hello.txt\nlink_test\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:20:18'},
#      {'command': 'cp',
#       'file': 'Hello World',
#       'filename': 'hello.txt',
#       'full_command': 'cp hello.txt copied_hello.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:20'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'copied_hello.txt\ndata-store\nhello.txt\nlinked_hello.txt\nlink_test\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:20:20'},
#      {'command': 'pico',
#       'diff_l': 0,
#       'diff_wc': 0,
#       'file': 'Hello Universe',
#       'filename': 'hello.txt',
#       'new_l': 1,
#       'new_wc': 2,
#       'old_l': 1,
#       'old_wc': 2,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:20',
#       'total_time(s)': 7},
#      {'command': 'cat',
#       'file': 'Hello Universe',
#       'filename': 'linked_hello.txt',
#       'full_command': 'cat linked_hello.txt',
#       'stderr': '',
#       'stdout': 'Hello Universe',
#       'time': '2023-01-17:20:20'},
#      {'command': 'cat',
#       'file': 'Hello World',
#       'filename': 'copied_hello.txt',
#       'full_command': 'cat copied_hello.txt',
#       'stderr': '',
#       'stdout': 'Hello World',
#       'time': '2023-01-17:20:20'},
#      {'command': 'diff',
#       'file': 'Hello Universe',
#       'filename': 'hello.txt',
#       'full_command': 'diff hello.txt copied_hello.txt',
#       'stderr': '',
#       'stdout': '1c1\n< Hello Universe\n---\n> Hello World',
#       'time': '2023-01-17:20:21'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nhello.txt\nlinked_hello.txt\nlink_test\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-17:20:23'},
#      {'command': 'pico',
#       'diff_l': 1,
#       'diff_wc': 0,
#       'file': 'Hello\nUniverse',
#       'filename': 'hello.txt',
#       'new_l': 2,
#       'new_wc': 2,
#       'old_l': 1,
#       'old_wc': 2,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:23',
#       'total_time(s)': 9},
#      {'command': 'pico',
#       'diff_l': 0,
#       'diff_wc': 0,
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'new_l': 2,
#       'new_wc': 2,
#       'old_l': 2,
#       'old_wc': 2,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:24',
#       'total_time(s)': 11},
#      {'command': 'cp',
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'full_command': 'cp hello.txt copied_hello.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:24'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld',
#       'filename': 'linked_hello.txt',
#       'full_command': 'cat linked_hello.txt',
#       'stderr': '',
#       'stdout': 'Hello\nWorld',
#       'time': '2023-01-17:20:24'},
#      {'command': 'pico',
#       'diff_l': 0,
#       'diff_wc': 0,
#       'file': 'Hello\nUniverse',
#       'filename': 'hello.txt',
#       'new_l': 2,
#       'new_wc': 2,
#       'old_l': 2,
#       'old_wc': 2,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:24',
#       'total_time(s)': 7},
#      {'command': 'cat',
#       'file': 'Hello\nUniverse',
#       'filename': 'linked_hello.txt',
#       'full_command': 'cat linked_hello.txt',
#       'stderr': '',
#       'stdout': 'Hello\nUniverse',
#       'time': '2023-01-17:20:24'},
#      {'command': 'diff',
#       'file': 'Hello\nUniverse',
#       'filename': 'hello.txt',
#       'full_command': 'diff hello.txt copied_hello.txt',
#       'stderr': '',
#       'stdout': '2c2\n< Universe\n---\n> World',
#       'time': '2023-01-17:20:25'},
#      {'command': 'diff',
#       'file': 'Hello\nWorld',
#       'filename': 'copied_hello.txt',
#       'full_command': 'diff copied_hello.txt hello.txt',
#       'stderr': '',
#       'stdout': '2c2\n< World\n---\n> Universe',
#       'time': '2023-01-17:20:30'},
#      {'command': 'diff',
#       'file': 'Hello\nUniverse',
#       'filename': 'hello.txt',
#       'full_command': 'diff hello.txt linked_hello.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-17:20:31'},
#      {'command': 'cp',
#       'file': '',
#       'filename': '',
#       'full_command': 'cp ~/data-store/data/output/misc ~/misc',
#       'stderr': "cp: -r not specified; omitting directory '/home/jovyan/data-store/data/output/misc'",
#       'stdout': '',
#       'time': '2023-01-17:20:34'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
# ...
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': 'stderr.txt\n\n./data/input/RNA_SEQ_SAMPLES:\nDrug_A\nDrug_B',
#       'time': '2022-12-01:20:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l ./data/input/RNA_SEQ_SAMPLES stderr.txt',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': 'stderr.txt\n\n./data/input/RNA_SEQ_SAMPLES:\nDrug_A\nDrug_B',
#       'time': '2022-12-01:20:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l ./data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': 'total 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B',
#       'time': '2022-12-01:20:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l ./data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#       'stderr': '',
#       'stdout': '-rw-r--r-- 1 jovyan jovyan 0 Dec 1 20:17 stderr.txt\n\n./data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B',
#       'time': '2022-12-01:20:18'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l -R data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': 'data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B\n\ndata/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 0\n-r-------- 1 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-------- 1 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-------- 1 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\ndata/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 0\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#       'time': '2022-12-01:20:18'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:20'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input/RNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:20'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2022-12-01:20:20'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:20'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#       'time': '2022-12-01:20:20'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:20'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input/RNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:20'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:21'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input',
#       'time': '2022-12-01:20:21'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:21'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:21'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2022-12-01:20:21'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:21'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#       'time': '2022-12-01:20:21'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'time': '2022-12-01:20:21'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:23'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data/input/RNA_SEQ_SAMPLES/Dcd ~/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '/home/jovyan/.offline.sh: line 354: cd: too many arguments',
#       'stdout': '',
#       'time': '2022-12-01:20:23'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:23'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:24'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:24'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:25'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '../Drug_B/',
#       'full_command': 'cd ../Drug_B/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:25'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '../../',
#       'full_command': 'cd ../../',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:25'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:25'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -a',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:25'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:25'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#       'time': '2022-12-01:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -a',
#       'stderr': '',
#       'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#       'time': '2022-12-01:20:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': './../Drug_A',
#       'full_command': 'cd ./../Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#       'time': '2022-12-01:20:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2022-12-01:20:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Bash/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:26'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input/Bash',
#       'time': '2022-12-01:20:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:31'}]},
#    'log_id': '6406489831cdc8e2baabf1bb55c770db7402111997feddd153a0e115eec30373',
#    'log_type': 'Bash',
#    'machine_id': 'a1294',
#    'session_id': 'None',
#    'timestamp': '2022-12-02 20:42:31.293563'},
#   {'_id': 'Bash:45e056b3-9fa5-4b1d-92f8-9abfbf597a80',
#    '_rev': '33-243aa986026265b6f15e0cd455341f3d',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2023-01-19 13:59:22.693349',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-19:14:29'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir bin',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:29'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd work/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:30'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:30'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir Bash',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:32'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Bash/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:32'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/work/Bash',
#       'time': '2023-01-19:14:32'},
#      {'command': 'clear',
#       'file': '',
#       'filename': '',
#       'full_command': 'clear',
#       'stderr': '',
#       'stdout': '\x1b[H\x1b[2J\x1b[3J',
#       'time': '2023-01-19:14:33'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:33'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/work/Bash',
#       'time': '2023-01-19:14:33'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/work/Bash',
#       'time': '2023-01-19:14:34'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls ~/data-store/data/input/Discovery/TSVFiles/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:39'},
#      {'command': 'touch',
#       'file': '',
#       'filename': '~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#       'full_command': 'touch ~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#       'stderr': "touch: cannot touch '/home/jovyan/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv': Permission denied",
#       'stdout': '',
#       'time': '2023-01-19:14:40'}]},
#    'log_id': 'f310fbeac6853eb621fdec11fbf18b37d4c3a6aa9e7f33f41f54ebfa00f38515',
#    'log_type': 'Bash',
#    'machine_id': 'a5cc4',
#    'session_id': 'sdgeorge',
#    'timestamp': '2023-01-19 14:42:18.120106'},
#   {'_id': 'Bash:45fb4c3a-6a18-45e2-8a09-d878c0e35347',
#    '_rev': '6-1aa39d4f2b466fcbfdc372bfe74d8d24',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2022-12-15 19:12:05.912220',
#    'log': {'commands': [{'command': 'clear',
#       'file': '',
#       'filename': '',
#       'full_command': 'clear',
#       'stderr': '',
#       'stdout': '\x1b[H\x1b[2J\x1b[3J',
#       'time': '2022-12-15:19:11'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#       'time': '2022-12-15:19:11'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-15:19:14'},
#      {'command': 'clear',
#       'file': '',
#       'filename': '',
#       'full_command': 'clear',
#       'stderr': '',
#       'stdout': '\x1b[H\x1b[2J\x1b[3J',
#       'time': '2022-12-15:19:16'}]},
#    'log_id': '7450c9f9ba0d2c95651dffecd26e1fb9d33247117dd9acc897e4ad591582c159',
#    'log_type': 'Bash',
#    'machine_id': 'aed0e',
#    'session_id': 'None',
#    'timestamp': '2022-12-15 19:18:42.457909'},
#   {'_id': 'Bash:5396f659-8c88-4ebd-a967-2a36742e0fb4',
#    '_rev': '1-8e45b3131d00eb4f0400a62941db34b6',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2022-12-15 20:09:56.838695',
#    'log': {'commands': []},
#    'log_id': 'ee1a33a83e16f50e19693bb4fefdb2d9a26ba626f97a0d24322f17c5d78b687d',
#    'log_type': 'Bash',
#    'machine_id': '4324b31f',
#    'session_id': 'None',
#    'timestamp': '2022-12-15 20:09:56.838695'},
#   {'_id': 'Bash:5657d40e-755a-482f-b4f1-bc29b0edeb7e',
#    '_rev': '1-f0610036b0a4af15ed2538efe65af25f',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2022-11-21 21:13:39.556649',
#    'log': {'commands': []},
#    'log_id': '63f8b84563a4b0527e3f1dee9db859800fb8e0782894cea9ab4ac2301de4898d',
#    'log_type': 'Bash',
#    'machine_id': 'abd49',
#    'session_id': 'None',
#    'timestamp': '2022-11-21 21:13:39.556649'},
#   {'_id': 'Bash:57777a82-b3e2-42a5-ac4a-b1a05364ef32',
#    '_rev': '1-e373e9718b71e1c0d77eb1fb674a3c99',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2023-01-19 16:06:50.248766',
#    'log': {'commands': []},
#    'log_id': '686a95ebc792a90bc9ae01ea365eea459974f94cf948c76ecd495705a0af55e8',
#    'log_type': 'Bash',
#    'machine_id': 'a7d15',
#    'session_id': 'Unknown Cyverse ID',
#    'timestamp': '2023-01-19 16:06:50.248766'},
#   {'_id': 'Bash:6733b682-70dd-4ed0-b112-5789bd6a1636',
#    '_rev': '1-d148b49d086194d692facd6b5a65ded9',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2023-01-24 20:41:48.286156',
#    'log': {'commands': []},
#    'log_id': 'd786815fdedfd62dd6815814b2d692c79fe576293edfdb603029096f4141f432',
#    'log_type': 'Bash',
#    'machine_id': 'a3dc4',
#    'session_id': 'sdgeorge',
#    'timestamp': '2023-01-24 20:41:48.286156'}]}

# %%
#Iterate and load all files in a folder
loaded = []
for i in os.listdir(data_folder):
    with open(data_folder + i, "r+") as f:
        load = json.load(f)
        loaded.append(load)
loaded
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-858a45791095> in <module>
#       3 for i in os.listdir(data_folder):
#       4     with open(data_folder + i, "r+") as f:
# ----> 5         load = json.load(f)
#       6         loaded.append(load)
#       7 loaded
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xaf in position 571: invalid start byte

# %% [markdown]
# # Process Data

# %% [markdown]
# ## Build Command Records - Array of JSON Objects

# %%
what_it_expects = [{"Animal": "Cat", "Size": "Medium"}, {"Animal": "Dog", "Size": "Large"}]
pd.DataFrame.from_records(what_it_expects)
# Out:
#   Animal    Size
# 0    Cat  Medium
# 1    Dog   Large

# %%
raw_records = []
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    machine_id = i['machine_id']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        #Build the common columns for all events
        to_add = {
            "Log ID": log_id, 
            "Course": course, 
            "Log Type": log_type,
        }
        
        #add to dict with equal
        to_add['Machine ID'] = machine_id
        
        #Add each command to array and update 
        to_add.update(event)
        
        #Sometimes processing type prior to building frame is easiest
        #For example, pandas can understand datetime, but right now it is a string. 
        #Convert the time into a string using this datetime function.
        to_add['time'] = datetime.strptime(to_add['time'], "%Y-%m-%d:%H:%M")
        
        raw_records.append(to_add)

#Look at the records we have made
raw_records[0:1]
# Out:
# [{'Log ID': 'd04e4ff0c8708760457e1cefad014855b3262f35c85a7a76c87d1f72539299ec',
#   'Course': 'Cyverse-RNA-Tutorial',
#   'Log Type': 'Bash',
#   'Machine ID': 'a3f8b',
#   'command': 'ls',
#   'file': '',
#   'filename': '',
#   'full_command': 'ls',
#   'stderr': '',
#   'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#   'time': datetime.datetime(2023, 1, 19, 16, 10)}]

# %%
## Convert to Pandas Dataframe 
pd_records = pd.DataFrame.from_records(raw_records)
pd_records.head()
# Out:
#                                               Log ID                Course  \
# 0  d04e4ff0c8708760457e1cefad014855b3262f35c85a7a...  Cyverse-RNA-Tutorial
# 1  cb4db30c2a3bc9fca043f180f62c72c7d1bc8184cd7417...  Cyverse-RNA-Tutorial
# 2  cb4db30c2a3bc9fca043f180f62c72c7d1bc8184cd7417...  Cyverse-RNA-Tutorial
# 3  cb4db30c2a3bc9fca043f180f62c72c7d1bc8184cd7417...  Cyverse-RNA-Tutorial
# 4  cb4db30c2a3bc9fca043f180f62c72c7d1bc8184cd7417...  Cyverse-RNA-Tutorial
#
#   Log Type Machine ID                                            command file  \
# 0     Bash      a3f8b                                                 ls
# 1     Bash      a07f4                                                 ls
# 2     Bash      a07f4                                                 ls
# 3     Bash      a07f4  /home/jovyan/data-store/data/input/RNA_SEQ_SAM...
# 4     Bash      a07f4                                                 ls
#
#   filename                                       full_command  \
# 0                                                          ls
# 1                                             ls /home/jovyan
# 2        .                                               ls .
# 3           /home/jovyan/data-store/data/input/RNA_SEQ_SAM...
# 4           ls /home/jovyan/data-store/data/input/RNA_SEQ_...
#
#                                               stderr  \
# 0
# 1
# 2
# 3  /home/jovyan/.offline.sh: line 368: /home/jovy...
# 4
#
#                                               stdout                time  \
# 0           data-store\nstderr.txt\nSuperShell\nwork 2023-01-19 16:10:00
# 1  data-store\nstderr.txt\nstdout.txt\nSuperShell... 2023-01-17 19:03:00
# 2  data-store\nstderr.txt\nstdout.txt\nSuperShell... 2023-01-17 19:03:00
# 3                                                    2023-01-17 19:03:00
# 4                                     Drug_A\nDrug_B 2023-01-17 19:03:00
#
#    diff_l  diff_wc  new_l  new_wc  old_l  old_wc  total_time(s)
# 0     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 3     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN            NaN

# %%
print(max(pd_records['time']))
pd_records.info()
# Out:
# 2023-01-19 16:10:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Log ID         346 non-null    object
#  1   Course         346 non-null    object
#  2   Log Type       346 non-null    object
#  3   Machine ID     346 non-null    object
#  4   command        346 non-null    object
#  5   file           346 non-null    object
#  6   filename       346 non-null    object
#  7   full_command   338 non-null    object
#  8   stderr         346 non-null    object
#  9   stdout         346 non-null    object
#  10  time           346 non-null    datetime64[ns]
#  11  diff_l         8 non-null      float64
#  12  diff_wc        8 non-null      float64
#  13  new_l          8 non-null      float64
#  14  new_wc         8 non-null      float64
#  15  old_l          8 non-null      float64
#  16  old_wc         8 non-null      float64
#  17  total_time(s)  8 non-null      float64
# dtypes: datetime64[ns](1), float64(7), object(10)
# memory usage: 48.8+ KB

# %% [markdown]
# ## Build Command Records - JSON of Arrays

# %%
high_level_json = {
    "Log ID": [],
    "Course": [],
    "Log Type": [], 
    "command": [],
    "file": [],
    "filename": [], 
    "full_command": [],
    "stderr": [],
    "stdout": [],
    "time": []
}
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        #Build the common columns for all events
        high_level_json['Log ID'].append(log_id)
        high_level_json['Course'].append(course)
        high_level_json['Log Type'].append(log_type)
        
        for i in event: 
            high_level_json[i].append(event[i])
        
        #Note it is a little more difficult to convert these strings here.
        #You could do an if in the for i in event statement 
        #We will leverage Pandas datetime function to do this for us. 
        

#Look at the JSON
high_level_json
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e85c11f36819> in <module>
#      26
#      27         for i in event:
# ---> 28             high_level_json[i].append(event[i])
#      29
#      30         #Note it is a little more difficult to convert these strings here.
#
# KeyError: 'diff_l'

# %%
## Convert to Dataframe 
pd_from_json = pd.DataFrame.from_dict(high_level_json)
pd_from_json.head()
# Out:
#                                               Log ID                Course  \
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 1  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 2  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 3  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 4  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
#
#   Log Type command file filename full_command  \
# 0     Bash      ls                         ls
# 1     Bash      ls             .         ls .
# 2     Bash   clear                      clear
# 3     Bash      cd                    cd Bash
# 4     Bash      cd                    cd home
#
#                                               stderr  \
# 0
# 1
# 2
# 3  /home/jovyan/.offline.sh: line 354: cd: Bash: ...
# 4
#
#                                stdout              time
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:19
# 1  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:20
# 2                           2022-09-29:19:20
# 3                                      2022-09-29:19:24
# 4                                      2022-09-29:19:24

# %%
## Notice Types 
pd_from_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Log ID        27 non-null     object
#  1   Course        27 non-null     object
#  2   Log Type      27 non-null     object
#  3   command       27 non-null     object
#  4   file          27 non-null     object
#  5   filename      27 non-null     object
#  6   full_command  27 non-null     object
#  7   stderr        27 non-null     object
#  8   stdout        27 non-null     object
#  9   time          27 non-null     object
# dtypes: object(10)
# memory usage: 2.2+ KB

# %%
## Time is an object, we want these to be datetimes, can do this in pandas 
pd_from_json['Timestamp'] = pd.to_datetime(pd_from_json['time'], format="%Y-%m-%d:%H:%M")
print(max(pd_from_json['time']))
print(max(pd_from_json['Timestamp']))
pd_from_json.info()
# Out:
# 2022-10-14:00:23
# 2022-10-14 00:23:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Log ID        27 non-null     object
#  1   Course        27 non-null     object
#  2   Log Type      27 non-null     object
#  3   command       27 non-null     object
#  4   file          27 non-null     object
#  5   filename      27 non-null     object
#  6   full_command  27 non-null     object
#  7   stderr        27 non-null     object
#  8   stdout        27 non-null     object
#  9   time          27 non-null     object
#  10  Timestamp     27 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 2.4+ KB

# %% [markdown]
# ## Build Command Records - DataFrame Hybrid

# %%
base_frame = pd.DataFrame()
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        
        #Build a dataframe for the smallest unit
        subframe = pd.DataFrame.from_records([event])
        
        #Add common fields to subframe 
        subframe['Log ID'] = log_id
        subframe['Course'] = course
        subframe['Log Type'] = log_type
        
        if base_frame.shape[0] == 0:
            base_frame = subframe
            # breaks out of for loop 
            # a nifty command
            continue 
            
        base_frame = pd.concat([base_frame, subframe])
        

base_frame.head()
# Out:
#   command file filename full_command  \
# 0      ls                         ls
# 0      ls             .         ls .
# 0   clear                      clear
# 0      cd                    cd Bash
# 0      cd                    cd home
#
#                                               stderr  \
# 0
# 0
# 0
# 0  /home/jovyan/.offline.sh: line 354: cd: Bash: ...
# 0
#
#                                stdout              time  \
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:19
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:20
# 0                           2022-09-29:19:20
# 0                                      2022-09-29:19:24
# 0                                      2022-09-29:19:24
#
#                                               Log ID                Course  \
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
#
#   Log Type
# 0     Bash
# 0     Bash
# 0     Bash
# 0     Bash
# 0     Bash

# %%
## Clean up again 
## Time is an object, we want these to be datetimes, can do this in pandas 
base_frame['Timestamp'] = pd.to_datetime(base_frame['time'], format="%Y-%m-%d:%H:%M")
base_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 0
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   command       27 non-null     object
#  1   file          27 non-null     object
#  2   filename      27 non-null     object
#  3   full_command  27 non-null     object
#  4   stderr        27 non-null     object
#  5   stdout        27 non-null     object
#  6   time          27 non-null     object
#  7   Log ID        27 non-null     object
#  8   Course        27 non-null     object
#  9   Log Type      27 non-null     object
#  10  Timestamp     27 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 2.5+ KB

# %% [markdown]
# # Export Dataframe

# %%
#This will allow you to manipulate what you export and not effect pd_records
to_export = pd_records.copy()

#Some column manipulation can be useful 
column_list = list(to_export.columns)

#You can reorder like so 
column_list.remove('time')
column_list = ["time"] + column_list
print(column_list)

#Rearrange columns, time is now the first column
to_export = to_export[column_list]
to_export.head()
# Out:
# ['time', 'Log ID', 'Course', 'Log Type', 'Machine ID', 'command', 'file', 'filename', 'full_command', 'stderr', 'stdout', 'diff_l', 'diff_wc', 'new_l', 'new_wc', 'old_l', 'old_wc', 'total_time(s)']
#                  time                                             Log ID  \
# 0 2023-01-19 16:10:00  d04e4ff0c8708760457e1cefad014855b3262f35c85a7a...
# 1 2023-01-17 19:03:00  cb4db30c2a3bc9fca043f180f62c72c7d1bc8184cd7417...
# 2 2023-01-17 19:03:00  cb4db30c2a3bc9fca043f180f62c72c7d1bc8184cd7417...
# 3 2023-01-17 19:03:00  cb4db30c2a3bc9fca043f180f62c72c7d1bc8184cd7417...
# 4 2023-01-17 19:03:00  cb4db30c2a3bc9fca043f180f62c72c7d1bc8184cd7417...
#
#                  Course Log Type Machine ID  \
# 0  Cyverse-RNA-Tutorial     Bash      a3f8b
# 1  Cyverse-RNA-Tutorial     Bash      a07f4
# 2  Cyverse-RNA-Tutorial     Bash      a07f4
# 3  Cyverse-RNA-Tutorial     Bash      a07f4
# 4  Cyverse-RNA-Tutorial     Bash      a07f4
#
#                                              command file filename  \
# 0                                                 ls
# 1                                                 ls
# 2                                                 ls             .
# 3  /home/jovyan/data-store/data/input/RNA_SEQ_SAM...
# 4                                                 ls
#
#                                         full_command  \
# 0                                                 ls
# 1                                    ls /home/jovyan
# 2                                               ls .
# 3  /home/jovyan/data-store/data/input/RNA_SEQ_SAM...
# 4  ls /home/jovyan/data-store/data/input/RNA_SEQ_...
#
#                                               stderr  \
# 0
# 1
# 2
# 3  /home/jovyan/.offline.sh: line 368: /home/jovy...
# 4
#
#                                               stdout  diff_l  diff_wc  new_l  \
# 0           data-store\nstderr.txt\nSuperShell\nwork     NaN      NaN    NaN
# 1  data-store\nstderr.txt\nstdout.txt\nSuperShell...     NaN      NaN    NaN
# 2  data-store\nstderr.txt\nstdout.txt\nSuperShell...     NaN      NaN    NaN
# 3                                                        NaN      NaN    NaN
# 4                                     Drug_A\nDrug_B     NaN      NaN    NaN
#
#    new_wc  old_l  old_wc  total_time(s)
# 0     NaN    NaN     NaN            NaN
# 1     NaN    NaN     NaN            NaN
# 2     NaN    NaN     NaN            NaN
# 3     NaN    NaN     NaN            NaN
# 4     NaN    NaN     NaN            NaN

# %%
# Make sure to add the suffix to the file name. You can also give path 
to_export.to_csv(output_dir + "sd_george.csv")

# %%
# If you are going to import to pandas later, I suggest pickle file 
# This will preserve types such as datetimes 
to_export.to_pickle(output_dir + "sd_george.pki")

# %% [markdown]
# # Read Back to Check

# %%
reloaded = pd.read_pickle(output_dir + "response2.pki")
reloaded.head()
# Out:
#                  time                                             Log ID  \
# 0 2021-04-19 19:34:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 1 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 2 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 3 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 4 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
#
#           Course Log Type Machine ID command file filename  \
# 0  Comp-512-Test     Bash   10bcd15c      ls
# 1  Comp-512-Test     Bash   10bcd15c  export
# 2  Comp-512-Test     Bash   10bcd15c  export
# 3  Comp-512-Test     Bash   10bcd15c  export
# 4  Comp-512-Test     Bash   10bcd15c  export
#
#                   full_command  \
# 0                           ls
# 1           export $TEST=Hello
# 2         export $TEST='Hello'
# 3  export PATH=$PATH:$HOME/bin
# 4   export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#    diff_l  diff_wc  new_l  new_wc  old_l  old_wc  total_time(s)
# 0     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 3     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN            NaN

# %%
reloaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           333 non-null    datetime64[ns]
#  1   Log ID         333 non-null    object
#  2   Course         333 non-null    object
#  3   Log Type       333 non-null    object
#  4   Machine ID     333 non-null    object
#  5   command        333 non-null    object
#  6   file           333 non-null    object
#  7   filename       333 non-null    object
#  8   full_command   326 non-null    object
#  9   stderr         333 non-null    object
#  10  stdout         333 non-null    object
#  11  diff_l         7 non-null      float64
#  12  diff_wc        7 non-null      float64
#  13  new_l          7 non-null      float64
#  14  new_wc         7 non-null      float64
#  15  old_l          7 non-null      float64
#  16  old_wc         7 non-null      float64
#  17  total_time(s)  7 non-null      float64
# dtypes: datetime64[ns](1), float64(7), object(10)
# memory usage: 47.0+ KB
