# %% [markdown]
# # Import Packages

# %%
import json
import os
import pandas as pd
from datetime import datetime

# %% [markdown]
# # Example JSON Load

# %%
sample = {
    "col1": {
        "Layer2":[{
            "Layer3"
        }]
    }, 
    "col2": "Hello"
}

# %%
pd.DataFrame.from_dict(sample)
# Out:
#               col1   col2
# Layer2  [{Layer3}]  Hello

# %% [markdown]
# # Load Data

# %%
data_folder = "raw_data/"
output_dir = "output_data/"
file = "response4.json"
raw_json = None

#Handy for making an output dir inline if needed. 
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

#I always read JSON in as JSON first and then parse. 
with open(data_folder + file, "r+") as f:
    raw_json = json.load(f)
raw_json
# Out:
# {'logs': [{'_id': 'Bash:032b6289-1f8d-4337-9393-872984d701a4',
#    '_rev': '6-204aab77ecdd05e3ccaa4396be8397d3',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2021-04-19 19:34:29.171635',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'SuperShell\nstderr.txt',
#       'time': '2021-04-19:19:34'},
#      {'command': 'export',
#       'file': '',
#       'filename': '',
#       'full_command': 'export $TEST=Hello',
#       'stderr': "/home/supershell/.offline.sh: line 358: export: `=Hello': not a valid identifier",
#       'stdout': '',
#       'time': '2021-04-19:19:35'},
#      {'command': 'export',
#       'file': '',
#       'filename': '',
#       'full_command': "export $TEST='Hello'",
#       'stderr': "/home/supershell/.offline.sh: line 358: export: `=Hello': not a valid identifier",
#       'stdout': '',
#       'time': '2021-04-19:19:35'},
#      {'command': 'export',
#       'file': '',
#       'filename': '',
#       'full_command': 'export PATH=$PATH:$HOME/bin',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-19:19:36'},
#      {'command': 'export',
#       'file': '',
#       'filename': '',
#       'full_command': 'export PATH=$PATH:test/bin',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-19:19:36'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo $PATH',
#       'stderr': '',
#       'stdout': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#       'time': '2021-04-19:19:36'}]},
#    'log_id': '490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519e3a41d8fbd2f2af05e',
#    'log_type': 'Bash',
#    'machine_id': '10bcd15c',
#    'session_id': 'None',
#    'timestamp': '2021-04-19 19:39:33.510650'},
#   {'_id': 'Bash:0962bdbd-2ad5-4603-8c84-abb884c6121c',
#    '_rev': '6-983019e528a22175815cc8f3280badb3',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2023-01-19 16:10:54.892756',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-19:16:10'}]},
#    'log_id': 'd04e4ff0c8708760457e1cefad014855b3262f35c85a7a76c87d1f72539299ec',
#    'log_type': 'Bash',
#    'machine_id': 'a3f8b',
#    'session_id': 'sdgeorge',
#    'timestamp': '2023-01-19 16:17:38.825687'},
#   {'_id': 'Bash:101efe50-ea8a-4b85-84dc-d7c1ec6486d2',
#    '_rev': '1113-b1f77878b358303a9903402e699c72c5',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2023-04-08 20:09:52.009177',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls /home/jovyan',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-04-08:20:10'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '..',
#       'full_command': 'ls ..',
#       'stderr': '',
#       'stdout': 'jovyan',
#       'time': '2023-04-08:20:11'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-04-08:20:11'},
#      {'command': 'ls',
#       'file': '',
#       'filename': './data-store/data/input/RNA_SEQ_SAMPLES',
#       'full_command': 'ls ./data-store/data/input/RNA_SEQ_SAMPLES',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-04-08:20:11'},
#      {'command': 'ls',
#       'file': '',
#       'filename': 'stderr.txt',
#       'full_command': 'ls stderr.txt',
#       'stderr': '',
#       'stdout': 'stderr.txt',
#       'time': '2023-04-08:20:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls aa',
#       'stderr': "ls: cannot access 'aa': No such file or directory",
#       'stdout': '',
#       'time': '2023-04-08:20:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-04-08:20:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l data-store/data/input/Discovery/',
#       'stderr': '',
#       'stdout': 'total 0\ndr-x------ 1 jovyan jovyan 0 Apr 8 15:27 FilteredSortedOutput\ndr-x------ 1 jovyan jovyan 0 Apr 8 15:27 RNASequenceOutput\ndr-x------ 1 jovyan jovyan 0 Apr 8 15:27 TSVFiles\ndr-x------ 1 jovyan jovyan 0 Apr 8 15:27 UncompressedSamples',
#       'time': '2023-04-08:20:16'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l data-store/data/input/Discovery/TSVFiles',
#       'stderr': '',
#       'stdout': 'total 0\n-r-------- 1 jovyan jovyan 6237689 Apr 6 14:16 A1_abundance.tsv\n-r-------- 1 jovyan jovyan 6135948 Apr 6 14:17 A2_abundance.tsv\n-r-------- 1 jovyan jovyan 6237909 Apr 6 14:17 B1_abundance.tsv\n-r-------- 1 jovyan jovyan 6237909 Apr 6 14:17 B2_abundance.tsv',
#       'time': '2023-04-08:20:17'},
#      {'command': 'history',
#       'file': '',
#       'filename': '',
#       'full_command': 'history',
#       'stderr': '',
#       'stdout': ' 1 ls /home/jovyan\n 2 ls ..\n 3 ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 4 ls ./data-store/data/input/RNA_SEQ_SAMPLES\n 5 ls stderr.txt\n 6 ls aa\n 7 ls\n 8 ls -l data-store/data/input/Discovery/\n 9 ls -l data-store/data/input/Discovery/TSVFiles\n 10 history',
#       'time': '2023-04-08:20:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l stderr.txt',
#       'stderr': '',
#       'stdout': '-rw-r--r-- 1 jovyan users 0 Apr 8 20:34 stderr.txt',
#       'time': '2023-04-08:20:34'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l ./data-store/data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#       'stderr': '',
#       'stdout': '-rw-r--r-- 1 jovyan users 0 Apr 8 20:34 stderr.txt\n\n./data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B',
#       'time': '2023-04-08:20:34'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l -R ./data-store/data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': './data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 0\n-r-------- 1 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-------- 1 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-------- 1 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 0\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#       'time': '2023-04-08:20:35'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan',
#       'time': '2023-04-08:20:36'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-04-08:20:44'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l',
#       'stderr': '',
#       'stdout': 'total 4\ndrwxrwsrwx 2 root jovyan 42 Apr 8 15:24 data-store\n-rw-r--r-- 1 jovyan users 0 Apr 8 20:44 stderr.txt\n-rw-r--r-- 1 jovyan users 0 Apr 8 20:44 stdout.txt\ndrwxr-xr-x 6 jovyan users 4096 Apr 8 20:09 SuperShell\ndrwsrwsr-x 2 jovyan users 10 May 3 2022 work',
#       'time': '2023-04-08:20:44'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd SuperShell/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:20:44'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l',
#       'stderr': '',
#       'stdout': 'total 60360\n-rwxr-xr-x 1 jovyan users 47 Apr 8 20:09 add_interactive.sh\n-rwxr-xr-x 1 jovyan users 7154 Apr 8 20:09 codehelper.sh\n-rwxr-xr-x 1 jovyan users 9953 Apr 8 20:09 consent.txt\n-rwxr-xr-x 1 jovyan users 20 Apr 8 20:09 courseid.txt\n-rwxr-xr-x 1 jovyan users 440 Apr 8 20:09 cyverse_install.sh\n-rwxr-xr-x 1 jovyan users 82 Apr 8 20:09 disable_help.sh\n-rwxr-xr-x 1 jovyan users 493 Apr 8 20:09 docker_install.sh\n-rwxr-xr-x 1 jovyan users 83 Apr 8 20:09 enable_help.sh\n-rwxr-xr-x 1 jovyan users 256548 Apr 8 20:09 flowchart.png\ndrwxr-xr-x 2 jovyan users 239 Apr 8 20:09 images\n-rwxr-xr-x 1 jovyan users 449 Apr 8 20:09 install.sh\n-rwxr-xr-x 1 jovyan users 25 Apr 8 20:09 interactive.txt\n-rwxr-xr-x 1 jovyan users 1074 Apr 8 20:09 LICENSE\n-rwxr-xr-x 1 jovyan users 678 Apr 8 20:09 linux_install.sh\n-rwxr-xr-x 1 jovyan users 699 Apr 8 20:09 mac_install.sh\n-rwxr-xr-x 1 jovyan users 0 Apr 8 20:09 mail.txt\n-rwxr-xr-x 1 jovyan users 39814 Apr 8 20:09 offline.sh\n-rwxr-xr-x 1 jovyan users 18137 Apr 8 20:09 offline_with_online.sh\n-rwxr-xr-x 1 jovyan users 1868 Apr 8 20:09 push_events.sh\n-rwxr-xr-x 1 jovyan users 3446 Apr 8 20:09 README.md\n-rwxr-xr-x 1 jovyan users 15 Apr 8 20:09 ruledir.txt\n-rwxr-xr-x 1 jovyan users 339 Apr 8 20:09 session_extract.sh\n-rwxr-xr-x 1 jovyan users 6105 Apr 8 20:09 shell2.sh\n-rwxr-xr-x 1 jovyan users 6101 Apr 8 20:09 shell.sh\ndrwxr-xr-x 2 jovyan users 71 Apr 8 20:09 StatParam\n-rwxr-xr-x 1 jovyan users 62 Apr 8 20:09 supershellhelpmessage.txt\n-rwxr-xr-x 1 jovyan users 3 Apr 8 20:09 supershellhelp.txt\ndrwxr-xr-x 2 jovyan users 77 Apr 8 20:09 SuperShellHistory\n-rwxr-xr-x 1 jovyan users 2118 Apr 8 20:09 supershellinfo.txt\ndrwxr-xr-x 3 jovyan users 144 Apr 8 20:09 SuperShellRules\n-rwxr-xr-x 1 jovyan users 30522687 Apr 8 20:09 TestSender2.jar\n-rwxr-xr-x 1 jovyan users 30523328 Apr 8 20:09 TestSender.jar\n-rwxr-xr-x 1 jovyan users 1195 Apr 8 20:09 title.txt\n-rwxr-xr-x 1 jovyan users 326139 Apr 8 20:09 Towards a Helpful Shell_ Scenarios and Commands.pdf',
#       'time': '2023-04-08:20:44'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l -R',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': '',
#       'time': '2023-04-08:21:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l',
#       'stderr': '',
#       'stdout': 'total 60360\n-rwxr-xr-x 1 jovyan users 47 Apr 8 20:09 add_interactive.sh\n-rwxr-xr-x 1 jovyan users 7154 Apr 8 20:09 codehelper.sh\n-rwxr-xr-x 1 jovyan users 9953 Apr 8 20:09 consent.txt\n-rwxr-xr-x 1 jovyan users 20 Apr 8 20:09 courseid.txt\n-rwxr-xr-x 1 jovyan users 440 Apr 8 20:09 cyverse_install.sh\n-rwxr-xr-x 1 jovyan users 82 Apr 8 20:09 disable_help.sh\n-rwxr-xr-x 1 jovyan users 493 Apr 8 20:09 docker_install.sh\n-rwxr-xr-x 1 jovyan users 83 Apr 8 20:09 enable_help.sh\n-rwxr-xr-x 1 jovyan users 256548 Apr 8 20:09 flowchart.png\ndrwxr-xr-x 2 jovyan users 239 Apr 8 20:09 images\n-rwxr-xr-x 1 jovyan users 449 Apr 8 20:09 install.sh\n-rwxr-xr-x 1 jovyan users 25 Apr 8 20:09 interactive.txt\n-rwxr-xr-x 1 jovyan users 1074 Apr 8 20:09 LICENSE\n-rwxr-xr-x 1 jovyan users 678 Apr 8 20:09 linux_install.sh\n-rwxr-xr-x 1 jovyan users 699 Apr 8 20:09 mac_install.sh\n-rwxr-xr-x 1 jovyan users 0 Apr 8 20:09 mail.txt\n-rwxr-xr-x 1 jovyan users 39814 Apr 8 20:09 offline.sh\n-rwxr-xr-x 1 jovyan users 18137 Apr 8 20:09 offline_with_online.sh\n-rwxr-xr-x 1 jovyan users 1868 Apr 8 20:09 push_events.sh\n-rwxr-xr-x 1 jovyan users 3446 Apr 8 20:09 README.md\n-rwxr-xr-x 1 jovyan users 15 Apr 8 20:09 ruledir.txt\n-rwxr-xr-x 1 jovyan users 339 Apr 8 20:09 session_extract.sh\n-rwxr-xr-x 1 jovyan users 6105 Apr 8 20:09 shell2.sh\n-rwxr-xr-x 1 jovyan users 6101 Apr 8 20:09 shell.sh\ndrwxr-xr-x 2 jovyan users 71 Apr 8 20:09 StatParam\n-rwxr-xr-x 1 jovyan users 62 Apr 8 20:09 supershellhelpmessage.txt\n-rwxr-xr-x 1 jovyan users 3 Apr 8 20:09 supershellhelp.txt\ndrwxr-xr-x 2 jovyan users 77 Apr 8 20:09 SuperShellHistory\n-rwxr-xr-x 1 jovyan users 2118 Apr 8 20:09 supershellinfo.txt\ndrwxr-xr-x 3 jovyan users 144 Apr 8 20:09 SuperShellRules\n-rwxr-xr-x 1 jovyan users 30522687 Apr 8 20:09 TestSender2.jar\n-rwxr-xr-x 1 jovyan users 30523328 Apr 8 20:09 TestSender.jar\n-rwxr-xr-x 1 jovyan users 1195 Apr 8 20:09 title.txt\n-rwxr-xr-x 1 jovyan users 326139 Apr 8 20:09 Towards a Helpful Shell_ Scenarios and Commands.pdf',
#       'time': '2023-04-08:21:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l -R',
#       'stderr': '',
#       'stdout': '.:\ntotal 60360\n-rwxr-xr-x 1 jovyan users 47 Apr 8 20:09 add_interactive.sh\n-rwxr-xr-x 1 jovyan users 7154 Apr 8 20:09 codehelper.sh\n-rwxr-xr-x 1 jovyan users 9953 Apr 8 20:09 consent.txt\n-rwxr-xr-x 1 jovyan users 20 Apr 8 20:09 courseid.txt\n-rwxr-xr-x 1 jovyan users 440 Apr 8 20:09 cyverse_install.sh\n-rwxr-xr-x 1 jovyan users 82 Apr 8 20:09 disable_help.sh\n-rwxr-xr-x 1 jovyan users 493 Apr 8 20:09 docker_install.sh\n-rwxr-xr-x 1 jovyan users 83 Apr 8 20:09 enable_help.sh\n-rwxr-xr-x 1 jovyan users 256548 Apr 8 20:09 flowchart.png\ndrwxr-xr-x 2 jovyan users 239 Apr 8 20:09 images\n-rwxr-xr-x 1 jovyan users 449 Apr 8 20:09 install.sh\n-rwxr-xr-x 1 jovyan users 25 Apr 8 20:09 interactive.txt\n-rwxr-xr-x 1 jovyan users 1074 Apr 8 20:09 LICENSE\n-rwxr-xr-x 1 jovyan users 678 Apr 8 20:09 linux_install.sh\n-rwxr-xr-x 1 jovyan users 699 Apr 8 20:09 mac_install.sh\n-rwxr-xr-x 1 jovyan users 0 Apr 8 20:09 mail.txt\n-rwxr-xr-x 1 jovyan users 39814 Apr 8 20:09 offline.sh\n-rwxr-xr-x 1 jovyan users 18137 Apr 8 20:09 offline_with_online.sh\n-rwxr-xr-x 1 jovyan users 1868 Apr 8 20:09 push_events.sh\n-rwxr-xr-x 1 jovyan users 3446 Apr 8 20:09 README.md\n-rwxr-xr-x 1 jovyan users 15 Apr 8 20:09 ruledir.txt\n-rwxr-xr-x 1 jovyan users 339 Apr 8 20:09 session_extract.sh\n-rwxr-xr-x 1 jovyan users 6105 Apr 8 20:09 shell2.sh\n-rwxr-xr-x 1 jovyan users 6101 Apr 8 20:09 shell.sh\ndrwxr-xr-x 2 jovyan users 71 Apr 8 20:09 StatParam\n-rwxr-xr-x 1 jovyan users 62 Apr 8 20:09 supershellhelpmessage.txt\n-rwxr-xr-x 1 jovyan users 3 Apr 8 20:09 supershellhelp.txt\ndrwxr-xr-x 2 jovyan users 77 Apr 8 20:09 SuperShellHistory\n-rwxr-xr-x 1 jovyan users 2118 Apr 8 20:09 supershellinfo.txt\ndrwxr-xr-x 3 jovyan users 144 Apr 8 20:09 SuperShellRules\n-rwxr-xr-x 1 jovyan users 30522687 Apr 8 20:09 TestSender2.jar\n-rwxr-xr-x 1 jovyan users 30523328 Apr 8 20:09 TestSender.jar\n-rwxr-xr-x 1 jovyan users 1195 Apr 8 20:09 title.txt\n-rwxr-xr-x 1 jovyan users 326139 Apr 8 20:09 Towards a Helpful Shell_ Scenarios and Commands.pdf\n\n./images:\ntotal 3268\n-rwxr-xr-x 1 jovyan users 261428 Apr 8 20:09 default-rstats.png\n-rwxr-xr-x 1 jovyan users 1281649 Apr 8 20:09 helloword-python-example.png\n-rwxr-xr-x 1 jovyan users 642075 Apr 8 20:09 opening-banner.png\n-rwxr-xr-x 1 jovyan users 523443 Apr 8 20:09 rhistory-default.png\n-rwxr-xr-x 1 jovyan users 473525 Apr 8 20:09 rhistory-doubleflag.png\n-rwxr-xr-x 1 jovyan users 86110 Apr 8 20:09 rhistory-options.png\n-rwxr-xr-x 1 jovyan users 67636 Apr 8 20:09 rstats-options.png\n\n./StatParam:\ntotal 8\n-rwxr-xr-x 1 jovyan users 12 Apr 8 20:09 mailstatparam.txt\n-rwxr-xr-x 1 jovyan users 16 Apr 8 20:09 welcomestatparam.txt\n\n./SuperShellHistory:\ntotal 16\n-rwxr-xr-x 1 jovyan users 17 Apr 8 20:09 start.json\n-rw-r--r-- 1 jovyan jovyan 9405 Apr 8 21:12 SuperShellHistory-2023-04-08.json\n\n./SuperShellRules:\ntotal 16\ndrwxr-xr-x 2 jovyan users 36 Apr 8 20:09 old-ss\n-rwxr-xr-x 1 jovyan users 209 Apr 8 20:09 rule-bashcmds.sh\n-rwxr-xr-x 1 jovyan users 1005 Apr 8 20:09 rule-compiledfile.sh\n-rwxr-xr-x 1 jovyan users 986 Apr 8 20:09 rule-dupe.sh\n-rwxr-xr-x 1 jovyan users 192 Apr 8 20:09 rule-stdoutfilesh.sh\n\n./SuperShellRules/old-ss:\ntotal 4\n-rwxr-xr-x 1 jovyan users 794 Apr 8 20:09 rule-sscmds.sh',
#       'time': '2023-04-08:21:12'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'add_interactive.sh\ncodehelper.sh\nconsent.txt\ncourseid.txt\ncyverse_install.sh\ndisable_help.sh\ndocker_install.sh\nenable_help.sh\nflowchart.png\nimages\ninstall.sh\ninteractive.txt\nLICENSE\nlinux_install.sh\nmac_install.sh\nmail.txt\noffline.sh\noffline_with_online.sh\npush_events.sh\nREADME.md\nruledir.txt\nsession_extract.sh\nshell2.sh\nshell.sh\nStatParam\nsupershellhelpmessage.txt\nsupershellhelp.txt\nSuperShellHistory\nsupershellinfo.txt\nSuperShellRules\nTestSender2.jar\nTestSender.jar\ntitle.txt\nTowards a Helpful Shell_ Scenarios and Commands.pdf',
#       'time': '2023-04-08:21:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:21:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-04-08:21:27'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan',
#       'time': '2023-04-08:21:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-04-08:21:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data-store/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:21:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:21:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'input\niplant\noutput',
#       'time': '2023-04-08:21:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd input/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:21:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:21:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-04-08:21:28'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:21:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#       'time': '2023-04-08:21:28'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:21:28'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which ls',
#       'stderr': '',
#       'stdout': '/usr/bin/ls',
#       'time': '2023-04-08:22:12'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which pwd',
#       'stderr': '',
#       'stdout': '/usr/bin/pwd',
#       'time': '2023-04-08:22:24'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which which',
#       'stderr': '',
#       'stdout': '/usr/bin/which',
#       'time': '2023-04-08:22:24'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which echo',
#       'stderr': '',
#       'stdout': '/usr/bin/echo',
#       'time': '2023-04-08:22:24'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#       'time': '2023-04-08:22:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2023-04-08:22:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#       'time': '2023-04-08:22:27'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd /home/jovyan/data-store/data/output',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:35'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:35'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:35'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc',
#       'time': '2023-04-08:22:36'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:36'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:36'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child',
#       'time': '2023-04-08:22:36'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child/misc_child_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:36'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -R misc_child/',
#       'stderr': '',
#       'stdout': 'misc_child/:\nmisc_child_child\n\nmisc_child/misc_child_child:',
#       'time': '2023-04-08:22:36'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child',
#       'time': '2023-04-08:22:37'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-04-08:22:37'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child',
#       'time': '2023-04-08:22:37'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd m`',
#       'stderr': "/home/jovyan/.offline.sh: eval: line 354: unexpected EOF while looking for matching ``'\n/home/jovyan/.offline.sh: eval: line 355: syntax error: unexpected end of file",
#       'stdout': '',
#       'time': '2023-04-08:22:37'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc_child/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:37'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc_child_child/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:37'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:37'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child_child_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:37'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:37'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-04-08:22:37'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:38'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'jovyan',
#       'time': '2023-04-08:22:38'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home',
#       'time': '2023-04-08:22:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '../..',
#       'full_command': 'cd ../..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:38'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'bin\nboot\ndata-store\ndev\netc\nhome\nlib\nlib32\nlib64\nlibx32\nllvm-instr\nmedia\nmnt\nOpenMPTraining\nopt\nproc\nroot\nrun\nsbin\nsrv\nSuperShell\nsys\ntmp\nusr\nvar',
#       'time': '2023-04-08:22:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:38'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-04-08:22:38'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#       'time': '2023-04-08:22:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd xiaomajur',
#       'stderr': '/home/jovyan/.offline.sh: line 354: cd: xiaomajur: No such file or directory',
#       'stdout': '',
#       'time': '2023-04-08:22:46'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'jovyan',
#       'time': '2023-04-08:22:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:46'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-04-08:22:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data-store/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:46'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data\nhome',
#       'time': '2023-04-08:22:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd home',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:46'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'shared\nxiaomajur',
#       'time': '2023-04-08:22:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd xiaomajur/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:47'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#       'time': '2023-04-08:22:47'},
#      {'command': 'history',
#       'file': '',
#       'filename': '',
#       'full_command': 'history',
#       'stderr': '',
#       'stdout': ' 1 ls /home/jovyan\n 2 ls ..\n 3 ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 4 ls ./data-store/data/input/RNA_SEQ_SAMPLES\n 5 ls stderr.txt\n 6 ls aa\n 7 ls\n 8 ls -l data-store/data/input/Discovery/\n 9 ls -l data-store/data/input/Discovery/TSVFiles\n 10 history\n 11 ls -l stderr.txt\n 12 ls -l ./data-store/data/input/RNA_SEQ_SAMPLES/ stderr.txt\n 13 ls -l -R ./data-store/data/input/RNA_SEQ_SAMPLES/\n 14 pwd\n 15 s\n 16 ls\n 17 ls -l\n 18 cd SuperShell/\n 19 ls -l\n 20 ls –l -R\n 21 ls -l\n 22 ls -l -R\n 23 ls\n 24 cd ..\n 25 ls\n 26 pwd\n 27 ls\n 28 cd data-store/\n 29 cd data\n 30 ls\n 31 cd input/\n 32 cd RNA_SEQ_SAMPLES/\n 33 ls\n 34 cd Drug_A\n 35 ls\n 36 cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_A\n 37 which ls\n 38 which pwd\n 39 which which\n 40 which echo\n 41 ls\n 42 cd ..\n 43 ls\n 44 cd Drug_A\n 45 ls\n 46 cd /home/jovyan/data-store/data/output\n 47 ls\n 48 mkdir misc\n 49 ls\n 50 cd misc/\n 51 mkdir misc_child\n 52 ls\n 53 mkdir misc_child/misc_child_child\n 54 ls -R misc_child/\n 55 ls\n 56 pwd\n 57 ls\n 58 cd m`\n 59 cd misc_child/\n 60 cd misc_child_child/\n 61 ls\n 62 mkdir misc_child_child_child\n 63 cd\n 64 ls\n 65 cd ..\n 66 ls\n 67 pwd\n 68 cd\n 69 cd ../..\n 70 ls\n 71 cd ~\n 72 ls\n 73 ls\n 74 cd ..\n 75 cd xiaomajur\n 76 ls\n 77 cd\n 78 ls\n 79 cd data-store/\n 80 ls\n 81 cd data\n 82 cd ..\n 83 cd home\n 84 ls\n 85 cd xiaomajur/\n 86 ls\n 87 history',
#       'time': '2023-04-08:22:47'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data-store/data/output/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:47'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc',
#       'time': '2023-04-08:22:47'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir UncompressedSamples',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:47'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir FilteredSortedOutput',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:47'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir TSVFiles',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir PermissionsTest',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir RNASeqOutput',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir bin',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nRNASeqOutput\nTSVFiles\nUncompressedSamples',
#       'time': '2023-04-08:22:48'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd RNASeqOutput/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir Advanced',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nRNASeqOutput\nTSVFiles\nUncompressedSamples',
#       'time': '2023-04-08:22:48'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd PermissionsTest/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir PermissionsChild',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:48'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'PermissionsChild',
#       'time': '2023-04-08:22:48'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'PermissionsChild',
#       'time': '2023-04-08:22:49'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:49'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nRNASeqOutput\nTSVFiles\nUncompressedSamples',
#       'time': '2023-04-08:22:49'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:49'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'input\niplant\noutput',
#       'time': '2023-04-08:22:49'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd output/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:49'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ms',
#       'stderr': '/home/jovyan/.offline.sh: line 354: cd: ms: No such file or directory',
#       'stdout': '',
#       'time': '2023-04-08:22:49'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:49'},
#      {'command': 'pico',
#       'diff_l': 2,
#       'diff_wc': 2,
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'new_l': 2,
#       'new_wc': 2,
#       'old_l': 0,
#       'old_wc': 0,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:50',
#       'total_time(s)': 60},
#      {'command': 'pico',
#       'diff_l': 2,
#       'diff_wc': 3,
#       'file': 'goodbye beautiful\nworld',
#       'filename': 'goodbye.txt',
#       'new_l': 2,
#       'new_wc': 3,
#       'old_l': 0,
#       'old_wc': 0,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:22:56',
#       'total_time(s)': 26},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'goodbye.txt\nhello.txt\nmisc_child',
#       'time': '2023-04-08:23:20'},
#      {'command': 'nano',
#       'diff_l': 0,
#       'diff_wc': 0,
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'new_l': 2,
#       'new_wc': 2,
#       'old_l': 2,
#       'old_wc': 2,
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-08:23:21',
#       'total_time(s)': 13},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'goodbye.txt\nhello.txt\nmisc_child',
#       'time': '2023-04-08:23:22'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-04-08:23:22'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt',
#       'stderr': '',
#       'stdout': 'Hello\nWorld',
#       'time': '2023-04-08:23:22'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt',
#       'stderr': '',
#       'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld',
#       'time': '2023-04-08:23:22'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat',
#       'stderr': '',
#       'stdout': 'abc\ndef',
#       'time': '2023-04-08:23:23'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat',
#       'stderr': '',
#       'stdout': 'goodbye.txt',
#       'time': '2023-04-08:23:25'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat',
#       'stderr': '',
#       'stdout': 'abc\nddd\nasdf\nadsf',
#       'time': '2023-04-08:23:27'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt',
#       'stderr': '',
#       'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld',
#       'time': '2023-04-08:23:27'},
#      {'command': 'cat',
#       'file': 'goodbye beautiful\nworld',
#       'filename': 'goodbye.txt',
#       'full_command': 'cat goodbye.txt hello.txt',
#       'stderr': '',
#       'stdout': 'goodbye beautiful\nworld\nHello\nWorld',
#       'time': '2023-04-08:23:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'goodbye.txt\nhello.txt\nmisc_child',
#       'time': '2023-04-09:00:36'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-04-09:00:36'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls > ls.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:00:36'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:00:36'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:02:51'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:02:51'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld\ngoodbye beautiful\nworld',
#       'filename': 'hello_goodbye.txt',
#       'full_command': 'cat hello_goodbye.txt',
#       'stderr': '',
#       'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld',
#       'time': '2023-04-09:02:51'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:02:52'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-04-09:02:52'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat < hello.txt',
#       'stderr': '',
#       'stdout': 'Hello\nWorld',
#       'time': '2023-04-09:02:52'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat > cat.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:02:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:02:53'},
#      {'command': 'cat',
#       'file': 'This is cat input\nMore cat input',
#       'filename': 'cat.out',
#       'full_command': 'cat cat.out',
#       'stderr': '',
#       'stdout': 'This is cat input\nMore cat input',
#       'time': '2023-04-09:02:53'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:02:58'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:02:58'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld\ngoodbye beautiful\nworld',
#       'filename': 'hello_goodbye.txt',
#       'full_command': 'cat hello_goodbye.txt',
#       'stderr': '',
#       'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld',
#       'time': '2023-04-09:02:58'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:02:59'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-04-09:02:59'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo "hello world"',
#       'stderr': '',
#       'stdout': 'hello world',
#       'time': '2023-04-09:02:59'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “hello world” > misc_child/echo.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:02:59'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:03:00'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc_child/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:03:00'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'echo.out\nmisc_child_child',
#       'time': '2023-04-09:03:00'},
#      {'command': 'cat',
#       'file': '“hello world”',
#       'filename': 'echo.out',
#       'full_command': 'cat echo.out',
#       'stderr': '',
#       'stdout': '“hello world”',
#       'time': '2023-04-09:03:00'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “goodbye world” > misc_child/echo_output.txt',
#       'stderr': '/home/jovyan/.offline.sh: line 368: misc_child/echo_output.txt: No such file or directory',
#       'stdout': '',
#       'time': '2023-04-09:03:01'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'echo.out\nmisc_child_child',
#       'time': '2023-04-09:03:01'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:03:01'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:03:01'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-04-09:03:01'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “goodbye world” > misc_child/echo_output.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:03:01'},
#      {'command': 'cat',
#       'file': '“goodbye world”',
#       'filename': 'misc_child/echo_output.txt',
#       'full_command': 'cat misc_child/echo_output.txt',
#       'stderr': '',
#       'stdout': '“goodbye world”',
#       'time': '2023-04-09:03:02'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “hello world” >> misc_child/echo_output.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:03:02'},
#      {'command': 'cat',
#       'file': '“goodbye world”\n“hello world”',
#       'filename': 'misc_child/echo_output.txt',
#       'full_command': 'cat misc_child/echo_output.txt',
#       'stderr': '',
#       'stdout': '“goodbye world”\n“hello world”',
#       'time': '2023-04-09:03:02'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat ~/data-store/data/output/misc/*',
#       'stderr': 'cat: /home/jovyan/data-store/data/output/misc/misc_child: Is a directory',
#       'stdout': 'This is cat input\nMore cat input\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:03:03'},
#      {'command': 'cat',
#       'file': 'This is cat input\nMore cat input',
#       'filename': 'cat.out',
#       'full_command': 'cat cat.out goodbye.txt hello_goodbye.txt hello.txt ls.out misc_child',
#       'stderr': 'cat: misc_child: Is a directory',
#       'stdout': 'This is cat input\nMore cat input\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:03:03'},
#      {'command': 'cat',
#       'file': 'goodbye beautiful\nworld',
#       'filename': 'goodbye.txt',
#       'full_command': 'cat goodbye.txt hello_goodbye.txt hello.txt',
#       'stderr': '',
#       'stdout': 'goodbye beautiful\nworld\nHello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld',
#       'time': '2023-04-09:03:03'},
#      {'command': 'cat',
#       'file': 'Hello\nWorld\ngoodbye beautiful\nworld',
#       'filename': 'hello_goodbye.txt',
#       'full_command': 'cat hello_goodbye.txt hello.txt',
#       'stderr': '',
#       'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld',
#       'time': '2023-04-09:03:03'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2023-04-09:03:46'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data-store/data/output/misc',
#       'time': '2023-04-09:03:46'},
#      {'command': 'cp',
#       'file': 'goodbye beautiful\nworld',
#       'filename': 'goodbye.txt',
#       'full_command': 'cp goodbye.txt copied_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-04-09:03:47'},
#      {'command': 'ls',
# ...
#       'time': '2022-12-01:20:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l ./data/input/RNA_SEQ_SAMPLES stderr.txt',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': 'stderr.txt\n\n./data/input/RNA_SEQ_SAMPLES:\nDrug_A\nDrug_B',
#       'time': '2022-12-01:20:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l ./data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': 'total 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B',
#       'time': '2022-12-01:20:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l ./data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#       'stderr': '',
#       'stdout': '-rw-r--r-- 1 jovyan jovyan 0 Dec 1 20:17 stderr.txt\n\n./data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B',
#       'time': '2022-12-01:20:18'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l -R data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': 'data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B\n\ndata/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 0\n-r-------- 1 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-------- 1 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-------- 1 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\ndata/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 0\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#       'time': '2022-12-01:20:18'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd data/input/RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:20'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input/RNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:20'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2022-12-01:20:20'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:20'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#       'time': '2022-12-01:20:20'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:20'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input/RNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:20'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:21'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input',
#       'time': '2022-12-01:20:21'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:21'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd RNA_SEQ_SAMPLES/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:21'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2022-12-01:20:21'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:21'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#       'time': '2022-12-01:20:21'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'time': '2022-12-01:20:21'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:23'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data/input/RNA_SEQ_SAMPLES/Dcd ~/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '/home/jovyan/.offline.sh: line 354: cd: too many arguments',
#       'stdout': '',
#       'time': '2022-12-01:20:23'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:23'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/data/input/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:24'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:24'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:25'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '../Drug_B/',
#       'full_command': 'cd ../Drug_B/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:25'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '../../',
#       'full_command': 'cd ../../',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:25'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:25'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -a',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:25'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:25'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#       'time': '2022-12-01:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -a',
#       'stderr': '',
#       'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#       'time': '2022-12-01:20:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': './../Drug_A',
#       'full_command': 'cd ./../Drug_A',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#       'time': '2022-12-01:20:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A\nDrug_B',
#       'time': '2022-12-01:20:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#       'time': '2022-12-01:20:26'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Bash/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:26'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/data/input/Bash',
#       'time': '2022-12-01:20:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-12-01:20:31'}]},
#    'log_id': '6406489831cdc8e2baabf1bb55c770db7402111997feddd153a0e115eec30373',
#    'log_type': 'Bash',
#    'machine_id': 'a1294',
#    'session_id': 'None',
#    'timestamp': '2022-12-02 20:42:31.293563'},
#   {'_id': 'Bash:3fa3ecc9-2ca6-4544-b77c-1f763cfd7176',
#    '_rev': '1-05f5cf7f3f1702cf9601ceadf336bc72',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2021-04-19 20:09:11.280509',
#    'log': {'commands': []},
#    'log_id': 'cd331cc2dcb8b51a7df9149fc10796d6f6900f73138dbdee956002c53a3f2940',
#    'log_type': 'Bash',
#    'machine_id': 'a32d05df',
#    'session_id': 'None',
#    'timestamp': '2021-04-19 20:09:11.280509'},
#   {'_id': 'Bash:4057e82c-5c4d-42fd-98c6-6fb2af80eaff',
#    '_rev': '1-d38617ee70b01b1734e741e1e3cc19a6',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2021-03-29 19:24:00.493392',
#    'log': {'commands': []},
#    'log_id': 'd68fbeae1f4dad2ad7d8f9e884eab5f79716a9cb320427e5dde6aff5ec1b2801',
#    'log_type': 'Bash',
#    'machine_id': '728b8dda',
#    'session_id': 'None',
#    'timestamp': '2021-03-29 19:24:00.493392'},
#   {'_id': 'Bash:43b0138f-3362-4c98-bf59-d74eea1af652',
#    '_rev': '957-89d2403c603a34a48b44e73eb7471335',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2021-04-21 20:31:36.281316',
#    'log': {'commands': [{'command': 'nano',
#       'diff_l': 0,
#       'diff_wc': 0,
#       'file': '',
#       'filename': 'test.txt',
#       'new_l': 0,
#       'new_wc': 0,
#       'old_l': 0,
#       'old_wc': 0,
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-21:20:31',
#       'total_time(s)': 4},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'SuperShell\nstderr.txt\nstdout.txt\ntest.txt',
#       'time': '2021-04-21:20:31'},
#      {'command': 'rm',
#       'diff_l': 0,
#       'diff_wc': 0,
#       'file': '',
#       'filename': '-i',
#       'new_l': 0,
#       'new_wc': 0,
#       'old_l': 0,
#       'old_wc': 0,
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-21:20:31',
#       'total_time(s)': 1},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'SuperShell\nstderr.txt\nstdout.txt',
#       'time': '2021-04-21:20:31'},
#      {'command': 'touch',
#       'file': '',
#       'filename': 'test.txt',
#       'full_command': 'touch test.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-21:20:34'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'SuperShell\nstderr.txt\nstdout.txt',
#       'time': '2021-04-21:20:34'}]},
#    'log_id': '586def0e79609c5554f12ed168ac1962c0d12e7d9ef87a91fdd02406c65dcd24',
#    'log_type': 'Bash',
#    'machine_id': '39d81881',
#    'session_id': 'None',
#    'timestamp': '2021-04-23 02:32:21.019715'},
#   {'_id': 'Bash:456fa543-f2c3-4325-a765-641bbadfd353',
#    '_rev': '1-5a1101b0489b6539a12582d563177be1',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2021-04-08 17:36:41.627823',
#    'log': {'commands': []},
#    'log_id': '4a52c0a8d32d5282810915c4110d1e52357da36b211fbd09d60c97ea68764b1a',
#    'log_type': 'Bash',
#    'machine_id': 'b6f24a4f',
#    'session_id': 'None',
#    'timestamp': '2021-04-08 17:36:41.627823'},
#   {'_id': 'Bash:45e056b3-9fa5-4b1d-92f8-9abfbf597a80',
#    '_rev': '33-243aa986026265b6f15e0cd455341f3d',
#    'course_id': 'Cyverse-RNA-Tutorial',
#    'created_timestamp': '2023-01-19 13:59:22.693349',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#       'time': '2023-01-19:14:29'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir bin',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:29'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd work/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:30'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:30'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir Bash',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:32'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Bash/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:32'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/work/Bash',
#       'time': '2023-01-19:14:32'},
#      {'command': 'clear',
#       'file': '',
#       'filename': '',
#       'full_command': 'clear',
#       'stderr': '',
#       'stdout': '\x1b[H\x1b[2J\x1b[3J',
#       'time': '2023-01-19:14:33'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:33'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/work/Bash',
#       'time': '2023-01-19:14:33'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/work/Bash',
#       'time': '2023-01-19:14:34'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls ~/data-store/data/input/Discovery/TSVFiles/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2023-01-19:14:39'},
#      {'command': 'touch',
#       'file': '',
#       'filename': '~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#       'full_command': 'touch ~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#       'stderr': "touch: cannot touch '/home/jovyan/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv': Permission denied",
#       'stdout': '',
#       'time': '2023-01-19:14:40'}]},
#    'log_id': 'f310fbeac6853eb621fdec11fbf18b37d4c3a6aa9e7f33f41f54ebfa00f38515',
#    'log_type': 'Bash',
#    'machine_id': 'a5cc4',
#    'session_id': 'sdgeorge',
#    'timestamp': '2023-01-19 14:42:18.120106'}]}

# %%
#Iterate and load all files in a folder
loaded = []
for i in os.listdir(data_folder):
    with open(data_folder + i, "r+") as f:
        load = json.load(f)
        loaded.append(load)
loaded
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-858a45791095> in <module>
#       3 for i in os.listdir(data_folder):
#       4     with open(data_folder + i, "r+") as f:
# ----> 5         load = json.load(f)
#       6         loaded.append(load)
#       7 loaded
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xaf in position 571: invalid start byte

# %% [markdown]
# # Process Data

# %% [markdown]
# ## Build Command Records - Array of JSON Objects

# %%
what_it_expects = [{"Animal": "Cat", "Size": "Medium"}, {"Animal": "Dog", "Size": "Large"}]
pd.DataFrame.from_records(what_it_expects)
# Out:
#   Animal    Size
# 0    Cat  Medium
# 1    Dog   Large

# %%
raw_records = []
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    machine_id = i['machine_id']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        #Build the common columns for all events
        to_add = {
            "Log ID": log_id, 
            "Course": course, 
            "Log Type": log_type,
        }
        
        #add to dict with equal
        to_add['Machine ID'] = machine_id
        
        #Add each command to array and update 
        to_add.update(event)
        
        #Sometimes processing type prior to building frame is easiest
        #For example, pandas can understand datetime, but right now it is a string. 
        #Convert the time into a string using this datetime function.
        to_add['time'] = datetime.strptime(to_add['time'], "%Y-%m-%d:%H:%M")
        
        raw_records.append(to_add)

#Look at the records we have made
raw_records[0:1]
# Out:
# [{'Log ID': '490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519e3a41d8fbd2f2af05e',
#   'Course': 'Comp-512-Test',
#   'Log Type': 'Bash',
#   'Machine ID': '10bcd15c',
#   'command': 'ls',
#   'file': '',
#   'filename': '',
#   'full_command': 'ls',
#   'stderr': '',
#   'stdout': 'SuperShell\nstderr.txt',
#   'time': datetime.datetime(2021, 4, 19, 19, 34)}]

# %%
## Convert to Pandas Dataframe 
pd_records = pd.DataFrame.from_records(raw_records)
pd_records.head()
# Out:
#                                               Log ID         Course Log Type  \
# 0  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 1  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 2  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 3  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 4  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
#
#   Machine ID command file filename                 full_command  \
# 0   10bcd15c      ls                                         ls
# 1   10bcd15c  export                         export $TEST=Hello
# 2   10bcd15c  export                       export $TEST='Hello'
# 3   10bcd15c  export                export PATH=$PATH:$HOME/bin
# 4   10bcd15c  export                 export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#                  time  diff_l  diff_wc  new_l  new_wc  old_l  old_wc  \
# 0 2021-04-19 19:34:00     NaN      NaN    NaN     NaN    NaN     NaN
# 1 2021-04-19 19:35:00     NaN      NaN    NaN     NaN    NaN     NaN
# 2 2021-04-19 19:35:00     NaN      NaN    NaN     NaN    NaN     NaN
# 3 2021-04-19 19:36:00     NaN      NaN    NaN     NaN    NaN     NaN
# 4 2021-04-19 19:36:00     NaN      NaN    NaN     NaN    NaN     NaN
#
#    total_time(s)
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
print(max(pd_records['time']))
pd_records.info()
# Out:
# 2023-04-09 15:53:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Log ID         1070 non-null   object
#  1   Course         1070 non-null   object
#  2   Log Type       1070 non-null   object
#  3   Machine ID     1070 non-null   object
#  4   command        1070 non-null   object
#  5   file           1070 non-null   object
#  6   filename       1070 non-null   object
#  7   full_command   1049 non-null   object
#  8   stderr         1070 non-null   object
#  9   stdout         1070 non-null   object
#  10  time           1070 non-null   datetime64[ns]
#  11  diff_l         21 non-null     float64
#  12  diff_wc        21 non-null     float64
#  13  new_l          21 non-null     float64
#  14  new_wc         21 non-null     float64
#  15  old_l          21 non-null     float64
#  16  old_wc         21 non-null     float64
#  17  total_time(s)  21 non-null     float64
# dtypes: datetime64[ns](1), float64(7), object(10)
# memory usage: 150.6+ KB

# %% [markdown]
# ## Build Command Records - JSON of Arrays

# %%
high_level_json = {
    "Log ID": [],
    "Course": [],
    "Log Type": [], 
    "command": [],
    "file": [],
    "filename": [], 
    "full_command": [],
    "stderr": [],
    "stdout": [],
    "time": []
}
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        #Build the common columns for all events
        high_level_json['Log ID'].append(log_id)
        high_level_json['Course'].append(course)
        high_level_json['Log Type'].append(log_type)
        
        for i in event: 
            high_level_json[i].append(event[i])
        
        #Note it is a little more difficult to convert these strings here.
        #You could do an if in the for i in event statement 
        #We will leverage Pandas datetime function to do this for us. 
        

#Look at the JSON
high_level_json
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e85c11f36819> in <module>
#      26
#      27         for i in event:
# ---> 28             high_level_json[i].append(event[i])
#      29
#      30         #Note it is a little more difficult to convert these strings here.
#
# KeyError: 'diff_l'

# %%
## Convert to Dataframe 
pd_from_json = pd.DataFrame.from_dict(high_level_json)
pd_from_json.head()
# Out:
#                                               Log ID                Course  \
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 1  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 2  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 3  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 4  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
#
#   Log Type command file filename full_command  \
# 0     Bash      ls                         ls
# 1     Bash      ls             .         ls .
# 2     Bash   clear                      clear
# 3     Bash      cd                    cd Bash
# 4     Bash      cd                    cd home
#
#                                               stderr  \
# 0
# 1
# 2
# 3  /home/jovyan/.offline.sh: line 354: cd: Bash: ...
# 4
#
#                                stdout              time
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:19
# 1  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:20
# 2                           2022-09-29:19:20
# 3                                      2022-09-29:19:24
# 4                                      2022-09-29:19:24

# %%
## Notice Types 
pd_from_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Log ID        27 non-null     object
#  1   Course        27 non-null     object
#  2   Log Type      27 non-null     object
#  3   command       27 non-null     object
#  4   file          27 non-null     object
#  5   filename      27 non-null     object
#  6   full_command  27 non-null     object
#  7   stderr        27 non-null     object
#  8   stdout        27 non-null     object
#  9   time          27 non-null     object
# dtypes: object(10)
# memory usage: 2.2+ KB

# %%
## Time is an object, we want these to be datetimes, can do this in pandas 
pd_from_json['Timestamp'] = pd.to_datetime(pd_from_json['time'], format="%Y-%m-%d:%H:%M")
print(max(pd_from_json['time']))
print(max(pd_from_json['Timestamp']))
pd_from_json.info()
# Out:
# 2022-10-14:00:23
# 2022-10-14 00:23:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Log ID        27 non-null     object
#  1   Course        27 non-null     object
#  2   Log Type      27 non-null     object
#  3   command       27 non-null     object
#  4   file          27 non-null     object
#  5   filename      27 non-null     object
#  6   full_command  27 non-null     object
#  7   stderr        27 non-null     object
#  8   stdout        27 non-null     object
#  9   time          27 non-null     object
#  10  Timestamp     27 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 2.4+ KB

# %% [markdown]
# ## Build Command Records - DataFrame Hybrid

# %%
base_frame = pd.DataFrame()
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        
        #Build a dataframe for the smallest unit
        subframe = pd.DataFrame.from_records([event])
        
        #Add common fields to subframe 
        subframe['Log ID'] = log_id
        subframe['Course'] = course
        subframe['Log Type'] = log_type
        
        if base_frame.shape[0] == 0:
            base_frame = subframe
            # breaks out of for loop 
            # a nifty command
            continue 
            
        base_frame = pd.concat([base_frame, subframe])
        

base_frame.head()
# Out:
#   command file filename full_command  \
# 0      ls                         ls
# 0      ls             .         ls .
# 0   clear                      clear
# 0      cd                    cd Bash
# 0      cd                    cd home
#
#                                               stderr  \
# 0
# 0
# 0
# 0  /home/jovyan/.offline.sh: line 354: cd: Bash: ...
# 0
#
#                                stdout              time  \
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:19
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:20
# 0                           2022-09-29:19:20
# 0                                      2022-09-29:19:24
# 0                                      2022-09-29:19:24
#
#                                               Log ID                Course  \
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
#
#   Log Type
# 0     Bash
# 0     Bash
# 0     Bash
# 0     Bash
# 0     Bash

# %%
## Clean up again 
## Time is an object, we want these to be datetimes, can do this in pandas 
base_frame['Timestamp'] = pd.to_datetime(base_frame['time'], format="%Y-%m-%d:%H:%M")
base_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 0
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   command       27 non-null     object
#  1   file          27 non-null     object
#  2   filename      27 non-null     object
#  3   full_command  27 non-null     object
#  4   stderr        27 non-null     object
#  5   stdout        27 non-null     object
#  6   time          27 non-null     object
#  7   Log ID        27 non-null     object
#  8   Course        27 non-null     object
#  9   Log Type      27 non-null     object
#  10  Timestamp     27 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 2.5+ KB

# %% [markdown]
# # Export Dataframe

# %%
#This will allow you to manipulate what you export and not effect pd_records
to_export = pd_records.copy()

#Some column manipulation can be useful 
column_list = list(to_export.columns)

#You can reorder like so 
column_list.remove('time')
column_list = ["time"] + column_list
print(column_list)

#Rearrange columns, time is now the first column
to_export = to_export[column_list]
to_export.head()
# Out:
# ['time', 'Log ID', 'Course', 'Log Type', 'Machine ID', 'command', 'file', 'filename', 'full_command', 'stderr', 'stdout', 'diff_l', 'diff_wc', 'new_l', 'new_wc', 'old_l', 'old_wc', 'total_time(s)']
#                  time                                             Log ID  \
# 0 2021-04-19 19:34:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 1 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 2 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 3 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 4 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
#
#           Course Log Type Machine ID command file filename  \
# 0  Comp-512-Test     Bash   10bcd15c      ls
# 1  Comp-512-Test     Bash   10bcd15c  export
# 2  Comp-512-Test     Bash   10bcd15c  export
# 3  Comp-512-Test     Bash   10bcd15c  export
# 4  Comp-512-Test     Bash   10bcd15c  export
#
#                   full_command  \
# 0                           ls
# 1           export $TEST=Hello
# 2         export $TEST='Hello'
# 3  export PATH=$PATH:$HOME/bin
# 4   export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#    diff_l  diff_wc  new_l  new_wc  old_l  old_wc  total_time(s)
# 0     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 3     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN            NaN

# %%
# Make sure to add the suffix to the file name. You can also give path 
to_export.to_csv(output_dir + "response4.csv")

# %%
# If you are going to import to pandas later, I suggest pickle file 
# This will preserve types such as datetimes 
to_export.to_pickle(output_dir + "response4.pki")

# %% [markdown]
# # Read Back to Check

# %%
reloaded = pd.read_pickle(output_dir + "response2.pki")
reloaded.head()
# Out:
#                  time                                             Log ID  \
# 0 2021-04-19 19:34:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 1 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 2 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 3 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 4 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
#
#           Course Log Type Machine ID command file filename  \
# 0  Comp-512-Test     Bash   10bcd15c      ls
# 1  Comp-512-Test     Bash   10bcd15c  export
# 2  Comp-512-Test     Bash   10bcd15c  export
# 3  Comp-512-Test     Bash   10bcd15c  export
# 4  Comp-512-Test     Bash   10bcd15c  export
#
#                   full_command  \
# 0                           ls
# 1           export $TEST=Hello
# 2         export $TEST='Hello'
# 3  export PATH=$PATH:$HOME/bin
# 4   export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#    diff_l  diff_wc  new_l  new_wc  old_l  old_wc  total_time(s)
# 0     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 3     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN            NaN

# %%
reloaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           333 non-null    datetime64[ns]
#  1   Log ID         333 non-null    object
#  2   Course         333 non-null    object
#  3   Log Type       333 non-null    object
#  4   Machine ID     333 non-null    object
#  5   command        333 non-null    object
#  6   file           333 non-null    object
#  7   filename       333 non-null    object
#  8   full_command   326 non-null    object
#  9   stderr         333 non-null    object
#  10  stdout         333 non-null    object
#  11  diff_l         7 non-null      float64
#  12  diff_wc        7 non-null      float64
#  13  new_l          7 non-null      float64
#  14  new_wc         7 non-null      float64
#  15  old_l          7 non-null      float64
#  16  old_wc         7 non-null      float64
#  17  total_time(s)  7 non-null      float64
# dtypes: datetime64[ns](1), float64(7), object(10)
# memory usage: 47.0+ KB
