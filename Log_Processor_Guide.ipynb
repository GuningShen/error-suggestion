# %% [markdown]
# # Import Packages

# %%
import json
import os
import pandas as pd
from datetime import datetime

# %% [markdown]
# # Example JSON Load

# %%
sample = {
    "col1": {
        "Layer2":[{
            "Layer3"
        }]
    }, 
    "col2": "Hello"
}

# %%
pd.DataFrame.from_dict(sample)
# Out:
#               col1   col2
# Layer2  [{Layer3}]  Hello

# %% [markdown]
# # Load Data

# %%
data_folder = "raw_data/"
output_dir = "output_data/"
file = "response3.json"
raw_json = None

#Handy for making an output dir inline if needed. 
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

#I always read JSON in as JSON first and then parse. 
with open(data_folder + file, "r+") as f:
    raw_json = json.load(f)
raw_json
# Out:
# {'logs': [{'_id': 'Bash:032b6289-1f8d-4337-9393-872984d701a4',
#    '_rev': '6-204aab77ecdd05e3ccaa4396be8397d3',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2021-04-19 19:34:29.171635',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'SuperShell\nstderr.txt',
#       'time': '2021-04-19:19:34'},
#      {'command': 'export',
#       'file': '',
#       'filename': '',
#       'full_command': 'export $TEST=Hello',
#       'stderr': "/home/supershell/.offline.sh: line 358: export: `=Hello': not a valid identifier",
#       'stdout': '',
#       'time': '2021-04-19:19:35'},
#      {'command': 'export',
#       'file': '',
#       'filename': '',
#       'full_command': "export $TEST='Hello'",
#       'stderr': "/home/supershell/.offline.sh: line 358: export: `=Hello': not a valid identifier",
#       'stdout': '',
#       'time': '2021-04-19:19:35'},
#      {'command': 'export',
#       'file': '',
#       'filename': '',
#       'full_command': 'export PATH=$PATH:$HOME/bin',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-19:19:36'},
#      {'command': 'export',
#       'file': '',
#       'filename': '',
#       'full_command': 'export PATH=$PATH:test/bin',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-19:19:36'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo $PATH',
#       'stderr': '',
#       'stdout': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#       'time': '2021-04-19:19:36'}]},
#    'log_id': '490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519e3a41d8fbd2f2af05e',
#    'log_type': 'Bash',
#    'machine_id': '10bcd15c',
#    'session_id': 'None',
#    'timestamp': '2021-04-19 19:39:33.510650'},
#   {'_id': 'Bash:1cdff25a-20e0-451d-872c-fa1f3347fe1c',
#    '_rev': '16-2a2d9b576b9a78e94a6618476e2b1f45',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2022-09-29 18:48:21.614863',
#    'log': {'commands': [{'command': 'clear',
#       'file': '',
#       'filename': '',
#       'full_command': 'clear',
#       'stderr': '',
#       'stdout': '\x1b[H\x1b[2J\x1b[3J',
#       'time': '2022-09-29:18:52'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan',
#       'time': '2022-09-29:18:53'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo $PATH',
#       'stderr': '',
#       'stdout': '/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/bin/TDM-GCC-64/bin',
#       'time': '2022-09-29:18:53'},
#      {'command': 'hostname',
#       'file': '',
#       'filename': '',
#       'full_command': 'hostname',
#       'stderr': '',
#       'stdout': 'ac9d01872',
#       'time': '2022-09-29:18:54'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan',
#       'time': '2022-09-29:18:54'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#       'time': '2022-09-29:18:56'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls /home/jovyan',
#       'stderr': '',
#       'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#       'time': '2022-09-29:18:57'},
#      {'command': 'clear',
#       'file': '',
#       'filename': '',
#       'full_command': 'clear',
#       'stderr': '',
#       'stdout': '\x1b[H\x1b[2J\x1b[3J',
#       'time': '2022-09-29:19:00'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#       'time': '2022-09-29:19:00'}]},
#    'log_id': '33bb76e6130caab90d89f35542de42c1be3a0f364190f6e3645cd8f03613c1ab',
#    'log_type': 'Bash',
#    'machine_id': 'ac9d0',
#    'session_id': 'None',
#    'timestamp': '2022-09-29 19:08:35.385449'},
#   {'_id': 'Bash:1f7831cd-e4cd-4581-96a0-b14d6d5a4926',
#    '_rev': '2329-5bb0415640b734fbc344a310b9b02dd7',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2022-09-11 18:18:13.523764',
#    'log': {'commands': [{'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls /home/jovyan',
#       'stderr': '',
#       'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#       'time': '2022-09-11:18:18'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#       'time': '2022-09-11:18:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '..',
#       'full_command': 'ls ..',
#       'stderr': '',
#       'stdout': 'jovyan',
#       'time': '2022-09-11:18:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls /home/jovyan/RNA_SEQ_SAMPLES',
#       'stderr': "ls: cannot access '/home/jovyan/RNA_SEQ_SAMPLES': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:18:27'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#       'time': '2022-09-11:18:28'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd home',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:18:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:18:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls /gunings/RNA_SEQ_SAMPLES',
#       'stderr': "ls: cannot access '/gunings/RNA_SEQ_SAMPLES': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:18:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:18:29'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd gunings',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:18:29'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#       'time': '2022-09-11:18:29'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:18:30'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:18:30'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd shared',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:18:30'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd sdgeorge',
#       'stderr': '/home/jovyan/.offline.sh: line 344: cd: sdgeorge: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:18:30'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'aegis\naes\nag2pi_workshop\nAG2PI_Workshop_May2021\napp_data\naraport\nAstrolabe\nazgs\nbighorn_fire\nBioinformatics_Resource_Centers\nBioViz\nBotany2020NMGWorkshop\nBrassica_dwarf\nc3c4\nCAP_TCN\nCHEESEHEAD\ncnoutsos_evo_seminar\ncommons_repo\ncsb472\ncyverse_training\ndanforth_center\ndigbio\ndillpicl\nearthenv_dem_data\nEarVision_maize_kernel_image_data\neDNA_Explorer\neht\nfrnakenseq_approved\ngea\nG-OnRamp_hubs\nGoreLab\nimicrobe\niplant_assembly_test_data\niplant_cbp_sample_data\niplantcollaborative\niplant_DNA_subway\niplant_kobas\niplant_public_test\niplant_training\niplant_uk_training\niVirus\nKBase_staging\nLegume_Federation\nlegume_wgd\nmagnoliagrandiFLORA\nNAM\nnappn\nNASA_GeneLab_data\nncsu-plantreplication\nNEON\nNEON_aop_workshop\nNEON_Pilot\nofo\nonekp_pilot\nosm\nosu-entangled-genomes\npanzea\npcc_tcn\nphytooracle\nplanetmicrobe\nplant_phenotype_ontology_data\nplantreplication2\npublictemp\nsanta_cruz_river\nsbl_sdsc\nscRNA-Seq_Working_Group\nSEPA_microbiome_2016\nsoynomics\nsrer-wgew\nsyngenta_sim\nTCIA\nterraref\ntonikazic\nTrinity_transdecoder_trinotate_databases\nual\nuk_data_commons\numn-zed\nuncc-wings\nunc_phyto_isolates\nUNLPlantVision\nUSD_teaching_materials\nusgs\nvirome_subject\nvisualization-working-group\nwalia_rice_salt\nworkshop_material',
#       'time': '2022-09-11:18:30'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '..',
#       'full_command': 'ls ..',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:18:32'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:18:32'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:18:32'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:18:32'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:18:32'},
#      {'command': 'ls',
#       'file': '',
#       'filename': 'stdout,txt.',
#       'full_command': 'ls stdout,txt.',
#       'stderr': "ls: cannot access 'stdout,txt.': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:18:33'},
#      {'command': 'ls',
#       'file': 'stdout.txt',
#       'filename': 'stdout.txt',
#       'full_command': 'ls stdout.txt',
#       'stderr': '',
#       'stdout': 'stdout.txt',
#       'time': '2022-09-11:18:33'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls RNAt',
#       'stderr': "ls: cannot access 'RNAt': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:18:35'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls RNA',
#       'stderr': "ls: cannot access 'RNA': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:18:37'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls RNA^t',
#       'stderr': "ls: cannot access 'RNA^t': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:18:37'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls RNA^t',
#       'stderr': "ls: cannot access 'RNA^t': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:18:51'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:18:51'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd home',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:18:51'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:18:51'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd gunings',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:18:51'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#       'time': '2022-09-11:18:51'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l Discovery/',
#       'stderr': '',
#       'stdout': 'total 0\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 FilteredSortedOutput\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 RNASequenceOutput\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 TSVFiles\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 UncompressedSamples',
#       'time': '2022-09-11:18:52'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls Discovery/TSVFiles',
#       'stderr': '',
#       'stdout': 'A_1_abundance.tsv\nA_2_abundance.tsv\nB_1_abundance.tsv\nB_2_abundance.tsv',
#       'time': '2022-09-11:18:53'},
#      {'command': 'history',
#       'file': '',
#       'filename': '',
#       'full_command': 'history',
#       'stderr': '',
#       'stdout': ' 1 ls /home/jovyan\n 2 ls\n 3 ls ..\n 4 ls /home/jovyan/RNA_SEQ_SAMPLES\n 5 ls\n 6 cd home\n 7 ls\n 8 ls /gunings/RNA_SEQ_SAMPLES\n 9 shelp\n 10 ls\n 11 cd gunings\n 12 ls\n 13 cd ..\n 14 ls\n 15 cd shared\n 16 cd sdgeorge\n 17 ls\n 18 ls ..\n 19 cd ..\n 20 ls\n 21 cd ..\n 22 ls\n 23 ls stdout,txt.\n 24 ls stdout.txt\n 25 ls RNAt\n 26 ls RNA\n 27 ls RNA^t\n 28 ls RNA^t\n 29 ls\n 30 cd home\n 31 ls\n 32 cd gunings\n 33 ls\n 34 ls -l Discovery/\n 35 ls Discovery/TSVFiles\n 36 history',
#       'time': '2022-09-11:18:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#       'time': '2022-09-11:18:54'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:18:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l',
#       'stderr': '',
#       'stdout': 'total 0\ndrwx------ 1 jovyan 1000 0 Sep 7 20:26 analyses\ndrwx------ 1 jovyan 1000 0 Sep 8 23:45 Bash\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 Discovery\ndrwx------ 1 jovyan 1000 0 Sep 7 13:55 DNASubway',
#       'time': '2022-09-11:18:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l stdout.txt',
#       'stderr': "ls: cannot access '–l': No such file or directory\nls: cannot access 'stdout.txt': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-11:19:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#       'time': '2022-09-11:19:17'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:19:17'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:19:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l stdout.txt',
#       'stderr': "ls: cannot access '–l': No such file or directory",
#       'stdout': 'stdout.txt',
#       'time': '2022-09-11:19:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l stdout.txt',
#       'stderr': '',
#       'stdout': '-rw-r--r-- 1 jovyan 1000 0 Sep 11 19:17 stdout.txt',
#       'time': '2022-09-11:19:17'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:19:19'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd SuperShell',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:19'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'add_interactive.sh\ncodehelper.sh\nconsent.txt\ncourseid.txt\ncyverse_install.sh\ndisable_help.sh\ndocker_install.sh\nenable_help.sh\nflowchart.png\nimages\ninstall.sh\ninteractive.txt\nLICENSE\nlinux_install.sh\nmac_install.sh\nmail.txt\noffline.sh\noffline_with_online.sh\npush_events.sh\nREADME.md\nruledir.txt\nshell2.sh\nshell.sh\nStatParam\nsupershellhelpmessage.txt\nsupershellhelp.txt\nSuperShellHistory\nsupershellinfo.txt\nSuperShellRules\nTestSender2.jar\nTestSender.jar\ntitle.txt\nTowards a Helpful Shell_ Scenarios and Commands.pdf',
#       'time': '2022-09-11:19:19'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd images',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:38'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan',
#       'time': '2022-09-11:19:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd SuperShell',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd St',
#       'stderr': '/home/jovyan/.offline.sh: line 344: cd: St: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:19:38'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd S^t',
#       'stderr': '/home/jovyan/.offline.sh: line 344: cd: S^t: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:19:39'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'add_interactive.sh\ncodehelper.sh\nconsent.txt\ncourseid.txt\ncyverse_install.sh\ndisable_help.sh\ndocker_install.sh\nenable_help.sh\nflowchart.png\nimages\ninstall.sh\ninteractive.txt\nLICENSE\nlinux_install.sh\nmac_install.sh\nmail.txt\noffline.sh\noffline_with_online.sh\npush_events.sh\nREADME.md\nruledir.txt\nshell2.sh\nshell.sh\nStatParam\nsupershellhelpmessage.txt\nsupershellhelp.txt\nSuperShellHistory\nsupershellinfo.txt\nSuperShellRules\nTestSender2.jar\nTestSender.jar\ntitle.txt\nTowards a Helpful Shell_ Scenarios and Commands.pdf',
#       'time': '2022-09-11:19:39'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/SuperShell',
#       'time': '2022-09-11:19:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd /home/jovyan/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '/home/jovyan/.offline.sh: line 344: cd: /home/jovyan/RNA_SEQ_SAMPLES/Drug_B: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:19:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:46'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:19:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd /home/gunings/RNA_SEQ_SAMPLES/Drug_B',
#       'stderr': '/home/jovyan/.offline.sh: line 344: cd: /home/gunings/RNA_SEQ_SAMPLES/Drug_B: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:19:46'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:19:46'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd home',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:47'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:19:47'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd gunings',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:47'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#       'time': '2022-09-11:19:47'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd DNASubway',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:47'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'project-8866',
#       'time': '2022-09-11:19:47'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which ls',
#       'stderr': '',
#       'stdout': '/bin/ls',
#       'time': '2022-09-11:19:49'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:50'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which which',
#       'stderr': '',
#       'stdout': '/usr/bin/which',
#       'time': '2022-09-11:19:50'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which pwd',
#       'stderr': '',
#       'stdout': '/bin/pwd',
#       'time': '2022-09-11:19:50'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which echo',
#       'stderr': '',
#       'stdout': '/bin/echo',
#       'time': '2022-09-11:19:51'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'project-8866',
#       'time': '2022-09-11:19:51'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:51'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:51'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:19:51'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd SuperShell',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:52'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd SuperShellHistory',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:52'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'start.json\nSuperShellHistory-2022-09-11.json',
#       'time': '2022-09-11:19:52'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:19:53'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd home',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'gunings\nshared',
#       'time': '2022-09-11:19:53'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd gunings',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#       'time': '2022-09-11:19:53'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd DNASubway',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:19:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'project-8866',
#       'time': '2022-09-11:19:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'project-8866',
#       'time': '2022-09-11:20:02'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:02'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:02'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:20:02'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd SuperShell',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:02'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'add_interactive.sh\ncodehelper.sh\nconsent.txt\ncourseid.txt\ncyverse_install.sh\ndisable_help.sh\ndocker_install.sh\nenable_help.sh\nflowchart.png\nimages\ninstall.sh\ninteractive.txt\nLICENSE\nlinux_install.sh\nmac_install.sh\nmail.txt\noffline.sh\noffline_with_online.sh\npush_events.sh\nREADME.md\nruledir.txt\nshell2.sh\nshell.sh\nStatParam\nsupershellhelpmessage.txt\nsupershellhelp.txt\nSuperShellHistory\nsupershellinfo.txt\nSuperShellRules\nTestSender2.jar\nTestSender.jar\ntitle.txt\nTowards a Helpful Shell_ Scenarios and Commands.pdf',
#       'time': '2022-09-11:20:02'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:03'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:20:03'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd /home/gunings',
#       'stderr': '/home/jovyan/.offline.sh: line 344: cd: /home/gunings: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:20:03'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd home/gunings',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:03'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#       'time': '2022-09-11:20:03'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd Bash',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:03'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:04'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc',
#       'time': '2022-09-11:20:04'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:04'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:04'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child/misc_child_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:04'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child',
#       'time': '2022-09-11:20:05'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:05'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child_child',
#       'time': '2022-09-11:20:05'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir misc_child_child/misc_child_child_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:05'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child_child',
#       'time': '2022-09-11:20:05'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc_child_child',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:05'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc_child_child_child',
#       'time': '2022-09-11:20:05'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '../../../',
#       'full_command': 'cd ../../../',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:06'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc',
#       'time': '2022-09-11:20:06'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:06'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan',
#       'time': '2022-09-11:20:06'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:20:06'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd home/gunings/Bash',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:06'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'misc',
#       'time': '2022-09-11:20:06'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir UncompressedSamples',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:06'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir FilteredSortedOutput',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:07'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir TSVFiles',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:07'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir PermissionsTest',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:07'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir bin',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:07'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nTSVFiles\nUncompressedSamples',
#       'time': '2022-09-11:20:07'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd FilteredSortedOutput',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:08'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:08'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir Advanced',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:08'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:08'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd PermissionsTest',
#       'stderr': '/home/jovyan/.offline.sh: line 344: cd: PermissionsTest: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:20:08'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#       'time': '2022-09-11:20:08'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd home/gunings/Bash',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:08'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nTSVFiles\nUncompressedSamples',
#       'time': '2022-09-11:20:08'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd PermissionsTest',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:08'},
#      {'command': 'mkdir',
#       'file': '',
#       'filename': '',
#       'full_command': 'mkdir PermissionsChild',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:09'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'PermissionsChild',
#       'time': '2022-09-11:20:09'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:09'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nTSVFiles\nUncompressedSamples',
#       'time': '2022-09-11:20:09'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:09'},
#      {'command': 'pico',
#       'diff_l': 2,
#       'diff_wc': 2,
#       'file': 'hello\nworld',
#       'filename': 'hello.txt',
#       'new_l': 2,
#       'new_wc': 2,
#       'old_l': 0,
#       'old_wc': 0,
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:11',
#       'total_time(s)': 104},
#      {'command': 'pico',
#       'diff_l': 2,
#       'diff_wc': 3,
#       'file': 'goodbye beautiful\nworld',
#       'filename': 'goobye.txt',
#       'new_l': 2,
#       'new_wc': 3,
#       'old_l': 0,
#       'old_wc': 0,
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:11',
#       'total_time(s)': 21},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/home/gunings/Bash/misc',
#       'time': '2022-09-11:20:12'},
#      {'command': 'cat',
#       'file': 'hello\nworld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt',
#       'stderr': '',
#       'stdout': 'hello\nworld',
#       'time': '2022-09-11:20:13'},
#      {'command': 'cat',
#       'file': 'hello\nworld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt',
#       'stderr': 'cat: goodbye.txt: No such file or directory',
#       'stdout': 'hello\nworld',
#       'time': '2022-09-11:20:13'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'goobye.txt\nhello.txt\nmisc_child',
#       'time': '2022-09-11:20:13'},
#      {'command': 'cat',
#       'file': 'hello\nworld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goobye.txt',
#       'stderr': '',
#       'stdout': 'hello\nworld\ngoodbye beautiful\nworld',
#       'time': '2022-09-11:20:13'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat',
#       'stderr': '',
#       'stdout': 'abc\n\ndef',
#       'time': '2022-09-11:20:20'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls > ls.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:22'},
#      {'command': 'cat',
#       'file': 'hello\nworld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#       'stderr': 'cat: goodbye.txt: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:20:23'},
#      {'command': 'cat',
#       'file': 'hello\nworld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goobye.txt > hello_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:24'},
#      {'command': 'hello.txt',
#       'file': '',
#       'filename': 'goodbye.txt',
#       'full_command': 'hello.txt goodbye.txt',
#       'stderr': '/home/jovyan/.offline.sh: line 358: hello.txt: command not found',
#       'stdout': '',
#       'time': '2022-09-11:20:24'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'goobye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2022-09-11:20:24'},
#      {'command': 'hello_goodbye.txt',
#       'file': '',
#       'filename': '',
#       'full_command': 'hello_goodbye.txt',
#       'stderr': '/home/jovyan/.offline.sh: line 358: hello_goodbye.txt: command not found',
#       'stdout': '',
#       'time': '2022-09-11:20:24'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat < hello.txt',
#       'stderr': '',
#       'stdout': 'hello\nworld',
#       'time': '2022-09-11:20:24'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat > cat.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:25'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoobye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2022-09-11:20:25'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat < hello.txt > hello_copy.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-11:20:26'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoobye.txt\nhello_copy.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2022-09-11:20:26'},
#      {'command': 'cat',
#       'file': 'hello\nworld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#       'stderr': 'cat: goodbye.txt: No such file or directory',
#       'stdout': '',
#       'time': '2022-09-11:20:28'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ngoobye.txt\nhello_copy.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2022-09-11:20:39'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd misc_child/cd ..',
#       'stderr': '/home/jovyan/.offline.sh: line 344: cd: too many arguments',
#       'stdout': '',
#       'time': '2022-09-13:13:25'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/home/gunings/Bash/misc',
#       'time': '2022-09-13:13:26'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “hello world”',
#       'stderr': '',
#       'stdout': '“hello world”',
#       'time': '2022-09-13:13:26'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo 1 2',
#       'stderr': '',
#       'stdout': '1 2',
#       'time': '2022-09-13:13:26'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “hello world” > misc_child/echo.out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-13:13:26'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “goodbye world” > misc_child/echo_output.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-13:13:28'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '',
#       'full_command': 'echo “hello world” >> misc_child/echo_output.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-13:13:32'},
#      {'command': 'cat',
#       'file': 'hello\nworld',
#       'filename': 'hello.txt',
#       'full_command': 'cat hello.txt goodbye.txt hello_goodbye.txt ls.out cat',
#       'stderr': 'cat: goodbye.txt: No such file or directory\ncat: cat: No such file or directory',
#       'stdout': 'hello\nworld\nhello\nworld\ngoobye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2022-09-13:13:32'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat ~/Bash/misc/*',
#       'stderr': "cat: '/home/jovyan/Bash/misc/*': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-13:13:33'},
#      {'command': 'cat',
#       'file': 'This is cat input\nMore cat input',
#       'filename': 'cat.out',
#       'full_command': 'cat cat.out goobye.txt hello_copy.txt hello_goodbye.txt hello.txt ls.out misc_child',
#       'stderr': 'cat: misc_child: Is a directory',
#       'stdout': 'This is cat input\nMore cat input\ngoodbye beautiful\nworld\nhello\nworld\nhello\nworld\nhello\nworld\ngoobye.txt\nhello.txt\nls.out\nmisc_child',
#       'time': '2022-09-13:13:33'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/home/gunings/Bash/misc',
#       'time': '2022-09-13:13:33'},
#      {'command': 'cat',
#       'file': 'goodbye beautiful\nworld',
#       'filename': 'goobye.txt',
#       'full_command': 'cat goobye.txt hello_copy.txt hello_goodbye.txt hello.txt',
#       'stderr': '',
#       'stdout': 'goodbye beautiful\nworld\nhello\nworld\nhello\nworld\nhello\nworld',
#       'time': '2022-09-13:13:34'},
#      {'command': 'cat',
#       'file': 'hello\nworld',
#       'filename': 'hello_copy.txt',
#       'full_command': 'cat hello_copy.txt hello_goodbye.txt hello.txt',
#       'stderr': '',
#       'stdout': 'hello\nworld\nhello\nworld\nhello\nworld',
#       'time': '2022-09-13:13:34'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls –l ~/*.log',
#       'stderr': "ls: cannot access '–l': No such file or directory\nls: cannot access '/home/jovyan/*.log': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-13:13:35'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l ~/*.log',
#       'stderr': "ls: cannot access '/home/jovyan/*.log': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-13:13:35'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/home/gunings/Bash/misc',
#       'time': '2022-09-13:13:35'},
#      {'command': 'echo',
#       'file': 'This is cat input\nMore cat input',
#       'filename': 'cat.out',
#       'full_command': 'echo cat.out goobye.txt hello_copy.txt hello_goodbye.txt hello.txt ls.out misc_child',
#       'stderr': '',
#       'stdout': 'cat.out goobye.txt hello_copy.txt hello_goodbye.txt hello.txt ls.out misc_child',
#       'time': '2022-09-13:13:35'},
#      {'command': 'echo',
#       'file': '',
#       'filename': '~/*.txt',
#       'full_command': 'echo ~/*.txt',
#       'stderr': '',
#       'stdout': '/home/jovyan/allsuggestions.txt /home/jovyan/numberedsuggestions.txt /home/jovyan/stderr.txt /home/jovyan/tmpsuggestions.txt',
#       'time': '2022-09-13:13:36'},
#      {'command': 'cp',
#       'file': '',
#       'filename': 'goodbye.txt',
#       'full_command': 'cp goodbye.txt copied_ goodbye.txt',
#       'stderr': "cp: target 'goodbye.txt' is not a directory",
#       'stdout': '',
#       'time': '2022-09-13:13:51'},
#      {'command': 'cp',
#       'file': 'goodbye beautiful\nworld',
#       'filename': 'goobye.txt',
#       'full_command': 'cp goobye.txt copied_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-13:13:51'},
#      {'command': 'mv',
#       'file': '',
#       'filename': 'goobye.txt',
#       'full_command': 'mv goobye.txt renamed_goodbye.txt',
#       'stderr': '',
#       'stdout': '',
#       'time': '2022-09-13:13:54'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'cat.out\ncopied_goodbye.txt\nhello_copy.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child\nrenamed_goodbye.txt',
#       'time': '2022-09-13:13:55'},
#      {'command': 'mv',
#       'file': '',
#       'filename': 'goodbye.txt',
#       'full_command': 'mv goodbye.txt misc_child',
#       'stderr': "mv: cannot stat 'goodbye.txt': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-13:13:55'},
#      {'command': 'ln',
#       'file': '',
#       'filename': '',
#       'full_command': 'ln –s hello.txt linked _hello.txt',
#       'stderr': "ln: target '_hello.txt' is not a directory",
#       'stdout': '',
#       'time': '2022-09-13:13:56'},
#      {'command': 'cp',
#       'file': '',
#       'filename': '',
#       'full_command': 'cp -r misc_child copied misc_child',
#       'stderr': "cp: cannot copy a directory, 'misc_child', into itself, 'misc_child/misc_child'\ncp: cannot stat 'copied': No such file or directory",
#       'stdout': '',
#       'time': '2022-09-13:14:04'}]},
#    'log_id': '8067d36662ba1f8b6d7e2281fb338c35f016d2f2e72b2e09bb010bd323e89970',
#    'log_type': 'Bash',
#    'machine_id': 'a80ca',
#    'session_id': 'None',
#    'timestamp': '2022-09-13 20:28:44.531450'},
#   {'_id': 'Bash:20c6e72c-a559-4f43-bd51-23d7d06db805',
#    '_rev': '1-0a164ffd08ceeaca41ce69784dda066a',
# ...
#       'time': '2021-04-17:13:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -l -r',
#       'stderr': '',
#       'stdout': 'total 28\n-rw-r--r-- 1 jovyan 1000 24 Apr 16 23:20 renamed_goodbye.txt\ndrwxr-sr-x 2 jovyan 1000 4096 Apr 16 22:56 misc_child\n-rw-r--r-- 1 jovyan 1000 51 Apr 16 18:56 ls_out.txt\nlrwxrwxrwx 1 jovyan 1000 11 Apr 16 22:44 linked_goodbye.txt -> goodbye.txt\n-rw-r--r-- 1 jovyan 1000 12 Apr 16 18:53 hello.txt\n-rw-r--r-- 1 jovyan 1000 36 Apr 16 18:55 hello_goodbye.txt\n-rw-r--r-- 1 jovyan 1000 24 Apr 16 23:17 copied_goodbye.txt\n-rw-r--r-- 1 jovyan 1000 33 Apr 16 21:34 cat_out.txt',
#       'time': '2021-04-17:13:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -R',
#       'stderr': '',
#       'stdout': '.:\ncat_out.txt\ncopied_goodbye.txt\nhello_goodbye.txt\nhello.txt\nlinked_goodbye.txt\nls_out.txt\nmisc_child\nrenamed_goodbye.txt\n\n./misc_child:\ngoodbye.txt',
#       'time': '2021-04-17:13:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls ~',
#       'stderr': '',
#       'stdout': 'Bash\nDiscovery\nDNASubway\ndownloads.stderr.log\ndownloads.stdout.log\nRNA_SEQ_SAMPLES\nstderr.txt\nstdout.txt\nSuperShell',
#       'time': '2021-04-17:14:38'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls ~/Bash',
#       'stderr': '',
#       'stdout': 'Jupyter_RNA_Notebook_analysis1-2021-04-07-19-24-53.7\nJupyter_RNA_Notebook_analysis1-2021-04-08-21-28-09.6\nJupyter_RNA_Notebook_analysis1-2021-04-10-19-14-38.9\nmisc',
#       'time': '2021-04-17:14:38'},
#      {'command': 'which',
#       'file': '',
#       'filename': '',
#       'full_command': 'which pwd',
#       'stderr': '',
#       'stdout': '/bin/pwd',
#       'time': '2021-04-17:19:46'},
#      {'command': 'cat',
#       'file': '',
#       'filename': '',
#       'full_command': 'cat /bin/pwd | head -4',
#       'stderr': '',
#       'stdout': '\x7fELF\x02\x01\x01\x03>\x01\x1d@��@8\t@\x1c\x1b\x06\x05@@@�\x01�\x01\x08\x03\x048\x028\x028\x02\x1c\x1c\x01\x01\x05htht \x01\x06�z�z �z �\x050\x07 \x02\x06�{�{ �{ �\x01�\x01\x08\x04\x04T\x02T\x02T\x02DD\x04P�td\x04\x04f\x04f\x04fl\x02l\x02\x04Q�td\x06\x10R�td\x04�z�z �z \x10\x05\x10\x05\x01/lib64/ld-linux-x86-64.so.2\x04\x10\x01GNU\x03\x02\x04\x14\x03GNUYv<�X\x1a=\x1e�v��>�H6��k�\x03A\x02\x07\x12\x01�$\x12)\x08V`A\x0e AEL\x04�&�(\x1d�\x1c\x10�M#�MB#�Pv��K������F-���,cr�bA�9�\x1c2��\x12*Ը�\x1c�c*?\x04K�N\x01\x12x\x01\x12M\x02\x12�\x12�\x129\x124\x03 �\x12�\x01\x12p\x12\r\x02\x128\x01\x12b\x01\x12\t\x02\x12P\x12�\x12�\x12�\x12d\x12u\x12�\x01\x121\x12H\x12+\x01\x12�\x12�\x01\x12�\x01\x129\x01\x12Z\x12\x1f\x02\x12\x0f\x01\x12>\x02\x12�\x12\x18\x02\x121\x02\x12P\x03 1\x01\x12�\x01\x12\x01\x02\x12\x1f\x12?\x01\x12\x0b\x12V\x01\x12�\x12�\x01\x12\x7f\x01\x12c\x12�\x12�\x01\x12\'\x12\x12\x12j\x12�\x01\x127\x02\x12m\x02\x12�\x12�\x01\x12\x16\x01\x12_\x03 F\x01\x12�\x12�"�\x12j\x01\x12z\x02\x11\x18 � 8$\x01\x11\x19�� \x08�\x02\x11\x10 b(�\x02\x11\x15�{ XR\x02\x11\x19�� \x08�\x02\x11\x10@X\x04�!\x19�� \x08�\x02\x11\x18\x18� \x04]\x02\x11\x19�� \x08�\x01!\x19�� \x08�\x01\x11\x19�� \x08A\x11\x19�� \x04�\x02\x11\x18\x10� \x08�\x02\x11\x19�� \x08�\x02\x11\x10�e/libc.so.6fflush__printf_chkreaddirsetlocalembrtowcstrncmpoptindstrrchrdcgettextclosedirfchdirerrorputs__stack_chk_fail__lxstatiswprintreallocabort_exitprogram_invocation_name__ctype_get_mb_cur_maxcallocstrlenungetcmemsetstrstr__errno_locationmemcmp__fprintf_chkstdoutlseekmemcpyfclosemallocmbsinit__uflownl_langinfoopendir__ctype_b_locgetenv__freadingstderrfscanfgetopt_long__fxstatfilenogetcwdfwrite__fpendingprogram_invocation_short_namefdopen__cxa_finalize__xstatbindtextdomainstrcmp__libc_start_maindirfdfseekofputs_unlockedfree__progname__progname_full__cxa_atexitquote_quoting_optionsVersion_IO_stdin_usedquoting_style_valsquoting_style_argsexit_failureprogram_nameversion_etc_copyrightGLIBC_2.3GLIBC_2.3.4GLIBC_2.14GLIBC_2.4GLIBC_2.2.5_ITM_deregisterTMCloneTable__gmon_start___ITM_registerTMCloneTableii\r\x06�\x02\x10t\x19i\t\x05\x07\x03\x10���\x06\x04\x13\x03\x10\x14ii\r\x03\x1e\x03\x10u\x1ai\t\x02(\x03�z \x08\x1e�z \x08�\x1d{ \x08�Y { \x08�Y@{ \x08�Y`{ \x08�Y�{ \x08�]�{ \x08�]�{ \x08�]�{ \x08�]�{ \x08�]�{ \x08�]�{ \x08�]�{ \x08�]�{ \x08bY�{ \x08�]\x08� \x08\x08� \x10� \x08\x0b]`� \x08p� x� \x08� �\x7f \x06\x07�\x7f \x06\x1e�\x7f \x06$�\x7f \x06;�\x7f \x06>�� \x05E�� \x05B�� \x05L�� \x05I�� \x05K~ \x07\x01\x08~ \x07\x02\x10~ \x07\x03\x18~ \x07\x04 ~ \x07\x05(~ \x07\x060~ \x07\x088~ \x07\t@~ \x07\nH~ \x07\x0bP~ \x07\x0cX~ \x07\r`~ \x07\x0eh~ \x07\x0fp~ \x07\x10x~ \x07\x11�~ \x07\x12�~ \x07\x13�~ \x07\x14�~ \x07\x15�~ \x07\x16�~ \x07\x17�~ \x07\x18�~ \x07\x19�~ \x07\x1a�~ \x07\x1b�~ \x07\x1c�~ \x07\x1d�~ \x07\x1f�~ \x07 �~ \x07!�~ \x07"\x7f \x07#\x08\x7f \x07%\x10\x7f \x07&\x18\x7f \x07\' \x7f \x07((\x7f \x07)0\x7f \x07*8\x7f \x07+@\x7f \x07,H\x7f \x07-P\x7f \x07.X\x7f \x07/`\x7f \x070h\x7f \x071p\x7f \x072x\x7f \x073�\x7f \x074�\x7f \x075�\x7f \x076�\x7f \x077�\x7f \x078�\x7f \x079�\x7f \x07:�\x7f \x07<�\x7f \x07=�\x7f \x07?�\x7f \x07@H��\x08H�\x05�h H��t\x02��H��\x08��5zf �%|f \x0f\x1f@�%zf h������%rf h\x01������%jf h\x02������%bf h\x03�����%Zf h\x04�����%Rf h\x05�����%Jf h\x06�����%Bf h\x07�p����%:f h\x08�`����%2f h\t�P����%*f h\n�@����%"f h\x0b�0����%\x1af h\x0c� ����%\x12f h\r�\x10����%\nf h\x0e�����%\x02f h\x0f������%�e h\x10������%�e h\x11������%�e h\x12������%�e h\x13�����%�e h\x14�����%�e h\x15�����%�e h\x16�����%�e h\x17�p����%�e h\x18�`����%�e h\x19�P����%�e h\x1a�@����%�e h\x1b�0����%�e h\x1c� ����%�e h\x1d�\x10����%�e h\x1e�����%�e h\x1f����� ...
#       'time': '2021-04-17:19:47'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/Bash/misc',
#       'time': '2021-04-17:19:53'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Jupyter_RNA_Notebook_analysis1-2021-04-07-19-24-53.7\nJupyter_RNA_Notebook_analysis1-2021-04-08-21-28-09.6\nJupyter_RNA_Notebook_analysis1-2021-04-10-19-14-38.9\nmisc',
#       'time': '2021-04-17:19:53'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Jupyter_RNA_Notebook_analysis1-2021-04-07-19-24-53.7\nJupyter_RNA_Notebook_analysis1-2021-04-08-21-28-09.6\nJupyter_RNA_Notebook_analysis1-2021-04-10-19-14-38.9\nmisc',
#       'time': '2021-04-17:19:54'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls ~/DNASubway/',
#       'stderr': '',
#       'stdout': 'project-5974\nWT_rep1-tophat_fastqc.html',
#       'time': '2021-04-17:19:54'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd ~/DNASubway/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:54'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'project-5974\nWT_rep1-tophat_fastqc.html',
#       'time': '2021-04-17:19:55'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls -R ~/DNASubway/',
#       'stderr': '',
#       'stdout': '/home/jovyan/DNASubway/:\nproject-5974\nWT_rep1-tophat_fastqc.html\n\n/home/jovyan/DNASubway/project-5974:\njob-48632\njob-48633\njob-48634\njob-48635\njob-49052\njob-49070\n\n/home/jovyan/DNASubway/project-5974/job-48632:\n_15881.env\n_15881.variables\nfastx_out\nfx48632.err\nfx48632.out\nfx48632.pid\n\n/home/jovyan/DNASubway/project-5974/job-48632/fastx_out:\nDrug_A_1-tophat_fastqc.html\nDrug_A_1-tophat_fastqc.zip\nDrug_A_1-tophat.fastq.gz\n\n/home/jovyan/DNASubway/project-5974/job-48633:\n_16481.env\n_16481.variables\nfastx_out\nfx48633.err\nfx48633.out\nfx48633.pid\n\n/home/jovyan/DNASubway/project-5974/job-48633/fastx_out:\nDrug_A_2-tophat_fastqc.html\nDrug_A_2-tophat_fastqc.zip\nDrug_A_2-tophat.fastq.gz\n\n/home/jovyan/DNASubway/project-5974/job-48634:\n_17006.env\n_17006.variables\nfastx_out\nfx48634.err\nfx48634.out\nfx48634.pid\n\n/home/jovyan/DNASubway/project-5974/job-48634/fastx_out:\nDrug_B_1-tophat_fastqc.html\nDrug_B_1-tophat_fastqc.zip\nDrug_B_1-tophat.fastq.gz\n\n/home/jovyan/DNASubway/project-5974/job-48635:\n_17597.env\n_17597.variables\nfastx_out\nfx48635.err\nfx48635.out\nfx48635.pid\n\n/home/jovyan/DNASubway/project-5974/job-48635/fastx_out:\nDrug_B_2-tophat_fastqc.html\nDrug_B_2-tophat_fastqc.zip\nDrug_B_2-tophat.fastq.gz\n\n/home/jovyan/DNASubway/project-5974/job-49052:\n64522597449052\nbams\nenvs\nkallisto49052.err\nkallisto49052.out\nkallisto49052.pid\nks-output\nsignificant.csv\nsleuth_object.so\n\n/home/jovyan/DNASubway/project-5974/job-49052/64522597449052:\napp.R\ndata\nrsconnect\nwww\n\n/home/jovyan/DNASubway/project-5974/job-49052/64522597449052/data:\nsleuth_object.so\n\n/home/jovyan/DNASubway/project-5974/job-49052/64522597449052/rsconnect:\nshinyapps.io\n\n/home/jovyan/DNASubway/project-5974/job-49052/64522597449052/rsconnect/shinyapps.io:\ndnalc\n\n/home/jovyan/DNASubway/project-5974/job-49052/64522597449052/rsconnect/shinyapps.io/dnalc:\n64522597449052.dcf\n\n/home/jovyan/DNASubway/project-5974/job-49052/64522597449052/www:\ndnasubway-icon.png\n\n/home/jovyan/DNASubway/project-5974/job-49052/bams:\n\n/home/jovyan/DNASubway/project-5974/job-49052/ks-output:\nA_1_abundance.h5\nA_2_abundance.h5\nB_1_abundance.h5\nB_2_abundance.h5\nks-downloadable-output.tar.gz\n\n/home/jovyan/DNASubway/project-5974/job-49070:\n64522597449070\nbams\nenvs\nkallisto49070.err\nkallisto49070.out\nkallisto49070.pid\nks-output\nsignificant.csv\nsleuth_object.so\n\n/home/jovyan/DNASubway/project-5974/job-49070/64522597449070:\napp.R\ndata\nrsconnect\nwww\n\n/home/jovyan/DNASubway/project-5974/job-49070/64522597449070/data:\nsleuth_object.so\n\n/home/jovyan/DNASubway/project-5974/job-49070/64522597449070/rsconnect:\nshinyapps.io\n\n/home/jovyan/DNASubway/project-5974/job-49070/64522597449070/rsconnect/shinyapps.io:\ndnalc\n\n/home/jovyan/DNASubway/project-5974/job-49070/64522597449070/rsconnect/shinyapps.io/dnalc:\n64522597449070.dcf\n\n/home/jovyan/DNASubway/project-5974/job-49070/64522597449070/www:\ndnasubway-icon.png\n\n/home/jovyan/DNASubway/project-5974/job-49070/bams:\n\n/home/jovyan/DNASubway/project-5974/job-49070/ks-output:\nA_1_abundance.h5\nA_1_abundance.tsv\nA_2_abundance.h5\nA_2_abundance.tsv\nB_1_abundance.h5\nB_1_abundance.tsv\nB_2_abundance.h5\nB_2_abundance.tsv\nks-downloadable-output.tar.gz',
#       'time': '2021-04-17:19:55'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/DNASubway',
#       'time': '2021-04-17:19:55'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'project-5974\nWT_rep1-tophat_fastqc.html',
#       'time': '2021-04-17:19:55'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd project-5974/',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:55'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'job-48632\njob-48633\njob-48634\njob-48635\njob-49052\njob-49070',
#       'time': '2021-04-17:19:55'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd job-49070',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:56'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '64522597449070\nbams\nenvs\nkallisto49070.err\nkallisto49070.out\nkallisto49070.pid\nks-output\nsignificant.csv\nsleuth_object.so',
#       'time': '2021-04-17:19:56'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:56'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'job-48632\njob-48633\njob-48634\njob-48635\njob-49052\njob-49070',
#       'time': '2021-04-17:19:56'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd job-48632',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:56'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '_15881.env\n_15881.variables\nfastx_out\nfx48632.err\nfx48632.out\nfx48632.pid',
#       'time': '2021-04-17:19:56'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/DNASubway/project-5974/job-48632',
#       'time': '2021-04-17:19:56'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '_15881.env\n_15881.variables\nfastx_out\nfx48632.err\nfx48632.out\nfx48632.pid',
#       'time': '2021-04-17:19:56'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd fastx_out',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'Drug_A_1-tophat_fastqc.html\nDrug_A_1-tophat_fastqc.zip\nDrug_A_1-tophat.fastq.gz',
#       'time': '2021-04-17:19:57'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': '_15881.env\n_15881.variables\nfastx_out\nfx48632.err\nfx48632.out\nfx48632.pid',
#       'time': '2021-04-17:19:57'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '..',
#       'full_command': 'cd ..',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:57'},
#      {'command': 'ls',
#       'file': '',
#       'filename': '',
#       'full_command': 'ls',
#       'stderr': '',
#       'stdout': 'job-48632\njob-48633\njob-48634\njob-48635\njob-49052\njob-49070',
#       'time': '2021-04-17:19:57'},
#      {'command': 'pwd',
#       'file': '',
#       'filename': '',
#       'full_command': 'pwd',
#       'stderr': '',
#       'stdout': '/home/jovyan/DNASubway/project-5974',
#       'time': '2021-04-17:19:57'},
#      {'command': 'cd',
#       'file': '',
#       'filename': '',
#       'full_command': 'cd job-49070',
#       'stderr': '',
#       'stdout': '',
#       'time': '2021-04-17:19:57'}]},
#    'log_id': '00206cd4bdc39bab7e2908eb900370094d721883f30148868ba32abb8cdf28b3',
#    'log_type': 'Bash',
#    'machine_id': '612c4dc4-ce35-4571-952d-cfedc92809d3-5fbf7c6db6-n',
#    'session_id': 'None',
#    'timestamp': '2021-04-17 19:57:30.849377'},
#   {'_id': 'Bash:5486f51b-fbad-4d6c-86ec-dbd246fdc32c',
#    '_rev': '1-94793270cfd84c69d8dda29946186dcc',
#    'course_id': 'Comp-512-Test',
#    'created_timestamp': '2021-04-21 20:29:17.605916',
#    'log': {'commands': []},
#    'log_id': '257cb7be4e0de36e2a120784c063236baaff47d324947f5b908d59910cafa6a7',
#    'log_type': 'Bash',
#    'machine_id': '3237ad20',
#    'session_id': 'None',
#    'timestamp': '2021-04-21 20:29:17.605916'}]}

# %%
#Iterate and load all files in a folder
loaded = []
for i in os.listdir(data_folder):
    with open(data_folder + i, "r+") as f:
        load = json.load(f)
        loaded.append(load)
loaded
# Out:
# [{'logs': [{'_id': 'Bash:032b6289-1f8d-4337-9393-872984d701a4',
#     '_rev': '6-204aab77ecdd05e3ccaa4396be8397d3',
#     'course_id': 'Comp-512-Test',
#     'created_timestamp': '2021-04-19 19:34:29.171635',
#     'log': {'commands': [{'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'SuperShell\nstderr.txt',
#        'time': '2021-04-19:19:34'},
#       {'command': 'export',
#        'file': '',
#        'filename': '',
#        'full_command': 'export $TEST=Hello',
#        'stderr': "/home/supershell/.offline.sh: line 358: export: `=Hello': not a valid identifier",
#        'stdout': '',
#        'time': '2021-04-19:19:35'},
#       {'command': 'export',
#        'file': '',
#        'filename': '',
#        'full_command': "export $TEST='Hello'",
#        'stderr': "/home/supershell/.offline.sh: line 358: export: `=Hello': not a valid identifier",
#        'stdout': '',
#        'time': '2021-04-19:19:35'},
#       {'command': 'export',
#        'file': '',
#        'filename': '',
#        'full_command': 'export PATH=$PATH:$HOME/bin',
#        'stderr': '',
#        'stdout': '',
#        'time': '2021-04-19:19:36'},
#       {'command': 'export',
#        'file': '',
#        'filename': '',
#        'full_command': 'export PATH=$PATH:test/bin',
#        'stderr': '',
#        'stdout': '',
#        'time': '2021-04-19:19:36'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo $PATH',
#        'stderr': '',
#        'stdout': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#        'time': '2021-04-19:19:36'}]},
#     'log_id': '490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519e3a41d8fbd2f2af05e',
#     'log_type': 'Bash',
#     'machine_id': '10bcd15c',
#     'session_id': 'None',
#     'timestamp': '2021-04-19 19:39:33.510650'},
#    {'_id': 'Bash:1cdff25a-20e0-451d-872c-fa1f3347fe1c',
#     '_rev': '16-2a2d9b576b9a78e94a6618476e2b1f45',
#     'course_id': 'Comp-512-Test',
#     'created_timestamp': '2022-09-29 18:48:21.614863',
#     'log': {'commands': [{'command': 'clear',
#        'file': '',
#        'filename': '',
#        'full_command': 'clear',
#        'stderr': '',
#        'stdout': '\x1b[H\x1b[2J\x1b[3J',
#        'time': '2022-09-29:18:52'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan',
#        'time': '2022-09-29:18:53'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo $PATH',
#        'stderr': '',
#        'stdout': '/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/bin/TDM-GCC-64/bin',
#        'time': '2022-09-29:18:53'},
#       {'command': 'hostname',
#        'file': '',
#        'filename': '',
#        'full_command': 'hostname',
#        'stderr': '',
#        'stdout': 'ac9d01872',
#        'time': '2022-09-29:18:54'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan',
#        'time': '2022-09-29:18:54'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#        'time': '2022-09-29:18:56'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /home/jovyan',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-29:18:57'},
#       {'command': 'clear',
#        'file': '',
#        'filename': '',
#        'full_command': 'clear',
#        'stderr': '',
#        'stdout': '\x1b[H\x1b[2J\x1b[3J',
#        'time': '2022-09-29:19:00'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-29:19:00'}]},
#     'log_id': '33bb76e6130caab90d89f35542de42c1be3a0f364190f6e3645cd8f03613c1ab',
#     'log_type': 'Bash',
#     'machine_id': 'ac9d0',
#     'session_id': 'None',
#     'timestamp': '2022-09-29 19:08:35.385449'},
#    {'_id': 'Bash:1f7831cd-e4cd-4581-96a0-b14d6d5a4926',
#     '_rev': '2329-5bb0415640b734fbc344a310b9b02dd7',
#     'course_id': 'Comp-512-Test',
#     'created_timestamp': '2022-09-11 18:18:13.523764',
#     'log': {'commands': [{'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /home/jovyan',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-11:18:18'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#        'time': '2022-09-11:18:27'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '..',
#        'full_command': 'ls ..',
#        'stderr': '',
#        'stdout': 'jovyan',
#        'time': '2022-09-11:18:27'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /home/jovyan/RNA_SEQ_SAMPLES',
#        'stderr': "ls: cannot access '/home/jovyan/RNA_SEQ_SAMPLES': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:18:27'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#        'time': '2022-09-11:18:28'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:18:28'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:18:28'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /gunings/RNA_SEQ_SAMPLES',
#        'stderr': "ls: cannot access '/gunings/RNA_SEQ_SAMPLES': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:18:28'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:18:29'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd gunings',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:18:29'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#        'time': '2022-09-11:18:29'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '..',
#        'full_command': 'cd ..',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:18:30'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:18:30'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd shared',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:18:30'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd sdgeorge',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: sdgeorge: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:18:30'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'aegis\naes\nag2pi_workshop\nAG2PI_Workshop_May2021\napp_data\naraport\nAstrolabe\nazgs\nbighorn_fire\nBioinformatics_Resource_Centers\nBioViz\nBotany2020NMGWorkshop\nBrassica_dwarf\nc3c4\nCAP_TCN\nCHEESEHEAD\ncnoutsos_evo_seminar\ncommons_repo\ncsb472\ncyverse_training\ndanforth_center\ndigbio\ndillpicl\nearthenv_dem_data\nEarVision_maize_kernel_image_data\neDNA_Explorer\neht\nfrnakenseq_approved\ngea\nG-OnRamp_hubs\nGoreLab\nimicrobe\niplant_assembly_test_data\niplant_cbp_sample_data\niplantcollaborative\niplant_DNA_subway\niplant_kobas\niplant_public_test\niplant_training\niplant_uk_training\niVirus\nKBase_staging\nLegume_Federation\nlegume_wgd\nmagnoliagrandiFLORA\nNAM\nnappn\nNASA_GeneLab_data\nncsu-plantreplication\nNEON\nNEON_aop_workshop\nNEON_Pilot\nofo\nonekp_pilot\nosm\nosu-entangled-genomes\npanzea\npcc_tcn\nphytooracle\nplanetmicrobe\nplant_phenotype_ontology_data\nplantreplication2\npublictemp\nsanta_cruz_river\nsbl_sdsc\nscRNA-Seq_Working_Group\nSEPA_microbiome_2016\nsoynomics\nsrer-wgew\nsyngenta_sim\nTCIA\nterraref\ntonikazic\nTrinity_transdecoder_trinotate_databases\nual\nuk_data_commons\numn-zed\nuncc-wings\nunc_phyto_isolates\nUNLPlantVision\nUSD_teaching_materials\nusgs\nvirome_subject\nvisualization-working-group\nwalia_rice_salt\nworkshop_material',
#        'time': '2022-09-11:18:30'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '..',
#        'full_command': 'ls ..',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:18:32'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '..',
#        'full_command': 'cd ..',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:18:32'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:18:32'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '..',
#        'full_command': 'cd ..',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:18:32'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:18:32'},
#       {'command': 'ls',
#        'file': '',
#        'filename': 'stdout,txt.',
#        'full_command': 'ls stdout,txt.',
#        'stderr': "ls: cannot access 'stdout,txt.': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:18:33'},
#       {'command': 'ls',
#        'file': 'stdout.txt',
#        'filename': 'stdout.txt',
#        'full_command': 'ls stdout.txt',
#        'stderr': '',
#        'stdout': 'stdout.txt',
#        'time': '2022-09-11:18:33'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls RNAt',
#        'stderr': "ls: cannot access 'RNAt': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:18:35'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls RNA',
#        'stderr': "ls: cannot access 'RNA': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:18:37'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls RNA^t',
#        'stderr': "ls: cannot access 'RNA^t': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:18:37'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls RNA^t',
#        'stderr': "ls: cannot access 'RNA^t': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:18:51'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:18:51'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:18:51'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:18:51'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd gunings',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:18:51'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#        'time': '2022-09-11:18:51'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls -l Discovery/',
#        'stderr': '',
#        'stdout': 'total 0\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 FilteredSortedOutput\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 RNASequenceOutput\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 TSVFiles\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 UncompressedSamples',
#        'time': '2022-09-11:18:52'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls Discovery/TSVFiles',
#        'stderr': '',
#        'stdout': 'A_1_abundance.tsv\nA_2_abundance.tsv\nB_1_abundance.tsv\nB_2_abundance.tsv',
#        'time': '2022-09-11:18:53'},
#       {'command': 'history',
#        'file': '',
#        'filename': '',
#        'full_command': 'history',
#        'stderr': '',
#        'stdout': ' 1 ls /home/jovyan\n 2 ls\n 3 ls ..\n 4 ls /home/jovyan/RNA_SEQ_SAMPLES\n 5 ls\n 6 cd home\n 7 ls\n 8 ls /gunings/RNA_SEQ_SAMPLES\n 9 shelp\n 10 ls\n 11 cd gunings\n 12 ls\n 13 cd ..\n 14 ls\n 15 cd shared\n 16 cd sdgeorge\n 17 ls\n 18 ls ..\n 19 cd ..\n 20 ls\n 21 cd ..\n 22 ls\n 23 ls stdout,txt.\n 24 ls stdout.txt\n 25 ls RNAt\n 26 ls RNA\n 27 ls RNA^t\n 28 ls RNA^t\n 29 ls\n 30 cd home\n 31 ls\n 32 cd gunings\n 33 ls\n 34 ls -l Discovery/\n 35 ls Discovery/TSVFiles\n 36 history',
#        'time': '2022-09-11:18:53'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#        'time': '2022-09-11:18:54'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls –l',
#        'stderr': "ls: cannot access '–l': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:18:57'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls -l',
#        'stderr': '',
#        'stdout': 'total 0\ndrwx------ 1 jovyan 1000 0 Sep 7 20:26 analyses\ndrwx------ 1 jovyan 1000 0 Sep 8 23:45 Bash\ndrwx------ 1 jovyan 1000 0 Sep 9 00:02 Discovery\ndrwx------ 1 jovyan 1000 0 Sep 7 13:55 DNASubway',
#        'time': '2022-09-11:18:57'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls –l stdout.txt',
#        'stderr': "ls: cannot access '–l': No such file or directory\nls: cannot access 'stdout.txt': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-11:19:17'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#        'time': '2022-09-11:19:17'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '..',
#        'full_command': 'cd ..',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:17'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:19:17'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '..',
#        'full_command': 'cd ..',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:17'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:19:17'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls –l stdout.txt',
#        'stderr': "ls: cannot access '–l': No such file or directory",
#        'stdout': 'stdout.txt',
#        'time': '2022-09-11:19:17'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls -l stdout.txt',
#        'stderr': '',
#        'stdout': '-rw-r--r-- 1 jovyan 1000 0 Sep 11 19:17 stdout.txt',
#        'time': '2022-09-11:19:17'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:19:19'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd SuperShell',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:19'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'add_interactive.sh\ncodehelper.sh\nconsent.txt\ncourseid.txt\ncyverse_install.sh\ndisable_help.sh\ndocker_install.sh\nenable_help.sh\nflowchart.png\nimages\ninstall.sh\ninteractive.txt\nLICENSE\nlinux_install.sh\nmac_install.sh\nmail.txt\noffline.sh\noffline_with_online.sh\npush_events.sh\nREADME.md\nruledir.txt\nshell2.sh\nshell.sh\nStatParam\nsupershellhelpmessage.txt\nsupershellhelp.txt\nSuperShellHistory\nsupershellinfo.txt\nSuperShellRules\nTestSender2.jar\nTestSender.jar\ntitle.txt\nTowards a Helpful Shell_ Scenarios and Commands.pdf',
#        'time': '2022-09-11:19:19'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd images',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:38'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:38'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan',
#        'time': '2022-09-11:19:38'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd SuperShell',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:38'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd St',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: St: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:19:38'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd S^t',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: S^t: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:19:39'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'add_interactive.sh\ncodehelper.sh\nconsent.txt\ncourseid.txt\ncyverse_install.sh\ndisable_help.sh\ndocker_install.sh\nenable_help.sh\nflowchart.png\nimages\ninstall.sh\ninteractive.txt\nLICENSE\nlinux_install.sh\nmac_install.sh\nmail.txt\noffline.sh\noffline_with_online.sh\npush_events.sh\nREADME.md\nruledir.txt\nshell2.sh\nshell.sh\nStatParam\nsupershellhelpmessage.txt\nsupershellhelp.txt\nSuperShellHistory\nsupershellinfo.txt\nSuperShellRules\nTestSender2.jar\nTestSender.jar\ntitle.txt\nTowards a Helpful Shell_ Scenarios and Commands.pdf',
#        'time': '2022-09-11:19:39'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan/SuperShell',
#        'time': '2022-09-11:19:46'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:46'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:46'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd /home/jovyan/RNA_SEQ_SAMPLES/Drug_B',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: /home/jovyan/RNA_SEQ_SAMPLES/Drug_B: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:19:46'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:46'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:19:46'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd /home/gunings/RNA_SEQ_SAMPLES/Drug_B',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: /home/gunings/RNA_SEQ_SAMPLES/Drug_B: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:19:46'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:19:46'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:47'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:19:47'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd gunings',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:47'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#        'time': '2022-09-11:19:47'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd DNASubway',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:47'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'project-8866',
#        'time': '2022-09-11:19:47'},
#       {'command': 'which',
#        'file': '',
#        'filename': '',
#        'full_command': 'which ls',
#        'stderr': '',
#        'stdout': '/bin/ls',
#        'time': '2022-09-11:19:49'},
#       {'command': 'which',
#        'file': '',
#        'filename': '',
#        'full_command': 'which cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:50'},
#       {'command': 'which',
#        'file': '',
#        'filename': '',
#        'full_command': 'which which',
#        'stderr': '',
#        'stdout': '/usr/bin/which',
#        'time': '2022-09-11:19:50'},
#       {'command': 'which',
#        'file': '',
#        'filename': '',
#        'full_command': 'which pwd',
#        'stderr': '',
#        'stdout': '/bin/pwd',
#        'time': '2022-09-11:19:50'},
#       {'command': 'which',
#        'file': '',
#        'filename': '',
#        'full_command': 'which echo',
#        'stderr': '',
#        'stdout': '/bin/echo',
#        'time': '2022-09-11:19:51'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'project-8866',
#        'time': '2022-09-11:19:51'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:51'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:51'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:19:51'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd SuperShell',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:52'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd SuperShellHistory',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:52'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'start.json\nSuperShellHistory-2022-09-11.json',
#        'time': '2022-09-11:19:52'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:53'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:19:53'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:53'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-09-11:19:53'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd gunings',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:53'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#        'time': '2022-09-11:19:53'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd DNASubway',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:19:53'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'project-8866',
#        'time': '2022-09-11:19:53'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'project-8866',
#        'time': '2022-09-11:20:02'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:02'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:02'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:20:02'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd SuperShell',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:02'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'add_interactive.sh\ncodehelper.sh\nconsent.txt\ncourseid.txt\ncyverse_install.sh\ndisable_help.sh\ndocker_install.sh\nenable_help.sh\nflowchart.png\nimages\ninstall.sh\ninteractive.txt\nLICENSE\nlinux_install.sh\nmac_install.sh\nmail.txt\noffline.sh\noffline_with_online.sh\npush_events.sh\nREADME.md\nruledir.txt\nshell2.sh\nshell.sh\nStatParam\nsupershellhelpmessage.txt\nsupershellhelp.txt\nSuperShellHistory\nsupershellinfo.txt\nSuperShellRules\nTestSender2.jar\nTestSender.jar\ntitle.txt\nTowards a Helpful Shell_ Scenarios and Commands.pdf',
#        'time': '2022-09-11:20:02'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:03'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:20:03'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd /home/gunings',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: /home/gunings: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:20:03'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home/gunings',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:03'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'analyses\nBash\nDiscovery\nDNASubway',
#        'time': '2022-09-11:20:03'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd Bash',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:03'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir misc',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:04'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'misc',
#        'time': '2022-09-11:20:04'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd misc',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:04'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir misc_child',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:04'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir misc_child/misc_child_child',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:04'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'misc_child',
#        'time': '2022-09-11:20:05'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd misc_child',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:05'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'misc_child_child',
#        'time': '2022-09-11:20:05'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir misc_child_child/misc_child_child_child',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:05'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'misc_child_child',
#        'time': '2022-09-11:20:05'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd misc_child_child',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:05'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'misc_child_child_child',
#        'time': '2022-09-11:20:05'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '../../../',
#        'full_command': 'cd ../../../',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:06'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'misc',
#        'time': '2022-09-11:20:06'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:06'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan',
#        'time': '2022-09-11:20:06'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:20:06'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home/gunings/Bash',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:06'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'misc',
#        'time': '2022-09-11:20:06'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir UncompressedSamples',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:06'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir FilteredSortedOutput',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:07'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir TSVFiles',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:07'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir PermissionsTest',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:07'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir bin',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:07'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nTSVFiles\nUncompressedSamples',
#        'time': '2022-09-11:20:07'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd FilteredSortedOutput',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:08'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:08'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir Advanced',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:08'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:08'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd PermissionsTest',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: PermissionsTest: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:20:08'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'allsuggestions.txt\ndata\nhome\nnumberedsuggestions.txt\nstderr.txt\nstdout.txt\nSuperShell\ntmpsuggestions.txt',
#        'time': '2022-09-11:20:08'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home/gunings/Bash',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:08'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nTSVFiles\nUncompressedSamples',
#        'time': '2022-09-11:20:08'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd PermissionsTest',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:08'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir PermissionsChild',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:09'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'PermissionsChild',
#        'time': '2022-09-11:20:09'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '..',
#        'full_command': 'cd ..',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:09'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nTSVFiles\nUncompressedSamples',
#        'time': '2022-09-11:20:09'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd misc',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:09'},
#       {'command': 'pico',
#        'diff_l': 2,
#        'diff_wc': 2,
#        'file': 'hello\nworld',
#        'filename': 'hello.txt',
#        'new_l': 2,
#        'new_wc': 2,
#        'old_l': 0,
#        'old_wc': 0,
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:11',
#        'total_time(s)': 104},
#       {'command': 'pico',
#        'diff_l': 2,
#        'diff_wc': 3,
#        'file': 'goodbye beautiful\nworld',
#        'filename': 'goobye.txt',
#        'new_l': 2,
#        'new_wc': 3,
#        'old_l': 0,
#        'old_wc': 0,
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:11',
#        'total_time(s)': 21},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan/home/gunings/Bash/misc',
#        'time': '2022-09-11:20:12'},
#       {'command': 'cat',
#        'file': 'hello\nworld',
#        'filename': 'hello.txt',
#        'full_command': 'cat hello.txt',
#        'stderr': '',
#        'stdout': 'hello\nworld',
#        'time': '2022-09-11:20:13'},
#       {'command': 'cat',
#        'file': 'hello\nworld',
#        'filename': 'hello.txt',
#        'full_command': 'cat hello.txt goodbye.txt',
#        'stderr': 'cat: goodbye.txt: No such file or directory',
#        'stdout': 'hello\nworld',
#        'time': '2022-09-11:20:13'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'goobye.txt\nhello.txt\nmisc_child',
#        'time': '2022-09-11:20:13'},
#       {'command': 'cat',
#        'file': 'hello\nworld',
#        'filename': 'hello.txt',
#        'full_command': 'cat hello.txt goobye.txt',
#        'stderr': '',
#        'stdout': 'hello\nworld\ngoodbye beautiful\nworld',
#        'time': '2022-09-11:20:13'},
#       {'command': 'cat',
#        'file': '',
#        'filename': '',
#        'full_command': 'cat',
#        'stderr': '',
#        'stdout': 'abc\n\ndef',
#        'time': '2022-09-11:20:20'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls > ls.out',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:22'},
#       {'command': 'cat',
#        'file': 'hello\nworld',
#        'filename': 'hello.txt',
#        'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#        'stderr': 'cat: goodbye.txt: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:20:23'},
#       {'command': 'cat',
#        'file': 'hello\nworld',
#        'filename': 'hello.txt',
#        'full_command': 'cat hello.txt goobye.txt > hello_goodbye.txt',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:24'},
#       {'command': 'hello.txt',
#        'file': '',
#        'filename': 'goodbye.txt',
#        'full_command': 'hello.txt goodbye.txt',
#        'stderr': '/home/jovyan/.offline.sh: line 358: hello.txt: command not found',
#        'stdout': '',
#        'time': '2022-09-11:20:24'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'goobye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#        'time': '2022-09-11:20:24'},
#       {'command': 'hello_goodbye.txt',
#        'file': '',
#        'filename': '',
#        'full_command': 'hello_goodbye.txt',
#        'stderr': '/home/jovyan/.offline.sh: line 358: hello_goodbye.txt: command not found',
#        'stdout': '',
#        'time': '2022-09-11:20:24'},
#       {'command': 'cat',
#        'file': '',
#        'filename': '',
#        'full_command': 'cat < hello.txt',
#        'stderr': '',
#        'stdout': 'hello\nworld',
#        'time': '2022-09-11:20:24'},
#       {'command': 'cat',
#        'file': '',
#        'filename': '',
#        'full_command': 'cat > cat.out',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:25'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'cat.out\ngoobye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#        'time': '2022-09-11:20:25'},
#       {'command': 'cat',
#        'file': '',
#        'filename': '',
#        'full_command': 'cat < hello.txt > hello_copy.txt',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-11:20:26'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'cat.out\ngoobye.txt\nhello_copy.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#        'time': '2022-09-11:20:26'},
#       {'command': 'cat',
#        'file': 'hello\nworld',
#        'filename': 'hello.txt',
#        'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#        'stderr': 'cat: goodbye.txt: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-11:20:28'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'cat.out\ngoobye.txt\nhello_copy.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#        'time': '2022-09-11:20:39'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd misc_child/cd ..',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: too many arguments',
#        'stdout': '',
#        'time': '2022-09-13:13:25'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan/home/gunings/Bash/misc',
#        'time': '2022-09-13:13:26'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo “hello world”',
#        'stderr': '',
#        'stdout': '“hello world”',
#        'time': '2022-09-13:13:26'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo 1 2',
#        'stderr': '',
#        'stdout': '1 2',
#        'time': '2022-09-13:13:26'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo “hello world” > misc_child/echo.out',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-13:13:26'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo “goodbye world” > misc_child/echo_output.txt',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-13:13:28'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo “hello world” >> misc_child/echo_output.txt',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-13:13:32'},
#       {'command': 'cat',
#        'file': 'hello\nworld',
#        'filename': 'hello.txt',
#        'full_command': 'cat hello.txt goodbye.txt hello_goodbye.txt ls.out cat',
#        'stderr': 'cat: goodbye.txt: No such file or directory\ncat: cat: No such file or directory',
#        'stdout': 'hello\nworld\nhello\nworld\ngoobye.txt\nhello.txt\nls.out\nmisc_child',
#        'time': '2022-09-13:13:32'},
#       {'command': 'cat',
#        'file': '',
#        'filename': '',
#        'full_command': 'cat ~/Bash/misc/*',
#        'stderr': "cat: '/home/jovyan/Bash/misc/*': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-13:13:33'},
#       {'command': 'cat',
#        'file': 'This is cat input\nMore cat input',
#        'filename': 'cat.out',
#        'full_command': 'cat cat.out goobye.txt hello_copy.txt hello_goodbye.txt hello.txt ls.out misc_child',
#        'stderr': 'cat: misc_child: Is a directory',
#        'stdout': 'This is cat input\nMore cat input\ngoodbye beautiful\nworld\nhello\nworld\nhello\nworld\nhello\nworld\ngoobye.txt\nhello.txt\nls.out\nmisc_child',
#        'time': '2022-09-13:13:33'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan/home/gunings/Bash/misc',
#        'time': '2022-09-13:13:33'},
#       {'command': 'cat',
#        'file': 'goodbye beautiful\nworld',
#        'filename': 'goobye.txt',
#        'full_command': 'cat goobye.txt hello_copy.txt hello_goodbye.txt hello.txt',
#        'stderr': '',
#        'stdout': 'goodbye beautiful\nworld\nhello\nworld\nhello\nworld\nhello\nworld',
#        'time': '2022-09-13:13:34'},
#       {'command': 'cat',
#        'file': 'hello\nworld',
#        'filename': 'hello_copy.txt',
#        'full_command': 'cat hello_copy.txt hello_goodbye.txt hello.txt',
#        'stderr': '',
#        'stdout': 'hello\nworld\nhello\nworld\nhello\nworld',
#        'time': '2022-09-13:13:34'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls –l ~/*.log',
#        'stderr': "ls: cannot access '–l': No such file or directory\nls: cannot access '/home/jovyan/*.log': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-13:13:35'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls -l ~/*.log',
#        'stderr': "ls: cannot access '/home/jovyan/*.log': No such file or directory",
#        'stdout': '',
#        'time': '2022-09-13:13:35'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan/home/gunings/Bash/misc',
#        'time': '2022-09-13:13:35'},
#       {'command': 'echo',
#        'file': 'This is cat input\nMore cat input',
#        'filename': 'cat.out',
#        'full_command': 'echo cat.out goobye.txt hello_copy.txt hello_goodbye.txt hello.txt ls.out misc_child',
#        'stderr': '',
#        'stdout': 'cat.out goobye.txt hello_copy.txt hello_goodbye.txt hello.txt ls.out misc_child',
#        'time': '2022-09-13:13:35'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '~/*.txt',
#        'full_command': 'echo ~/*.txt',
#        'stderr': '',
#        'stdout': '/home/jovyan/allsuggestions.txt /home/jovyan/numberedsuggestions.txt /home/jovyan/stderr.txt /home/jovyan/tmpsuggestions.txt',
#        'time': '2022-09-13:13:36'},
#       {'command': 'cp',
#        'file': '',
#        'filename': 'goodbye.txt',
#        'full_command': 'cp goodbye.txt copied_ goodbye.txt',
#        'stderr': "cp: target 'goodbye.txt' is not a directory",
#        'stdout': '',
#        'time': '2022-09-13:13:51'},
#       {'command': 'cp',
#        'file': 'goodbye beautiful\nworld',
#        'filename': 'goobye.txt',
#        'full_command': 'cp goobye.txt copied_goodbye.txt',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-13:13:51'},
#       {'command': 'mv',
#        'file': '',
#        'filename': 'goobye.txt',
#        'full_command': 'mv goobye.txt renamed_goodbye.txt',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-13:13:54'},
# ...
#        'time': '2021-04-19:14:17'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan/Bash/RNASeqOutput/Drug_A',
#        'time': '2021-04-19:14:28'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls -l ~/Discovery',
#        'stderr': '',
#        'stdout': 'total 0\ndrwxr-sr-x 2 jovyan 1000 37 Apr 18 15:37 FilteredSortedOutput\ndrwxr-sr-x 4 jovyan 1000 46 Apr 18 15:37 RNASequenceOutput\ndrwxr-sr-x 2 jovyan 1000 126 Apr 18 15:37 TSVFiles\ndrwxr-sr-x 4 jovyan 1000 46 Apr 18 15:37 UncompressedSamples',
#        'time': '2021-04-19:14:29'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd ~/Bash',
#        'stderr': '',
#        'stdout': '',
#        'time': '2021-04-19:20:55'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'bin\nFilteredSortedOutput\nJupyter_RNA_Notebook_analysis1-2021-04-07-19-24-53.7\nJupyter_RNA_Notebook_analysis1-2021-04-08-21-28-09.6\nJupyter_RNA_Notebook_analysis1-2021-04-10-19-14-38.9\nJupyter_RNA_Notebook_analysis1-2021-04-16-00-34-12.7\nRNASeqOutput\nTSVFiles\nUncompressedSamples',
#        'time': '2021-04-19:20:55'},
#       {'command': 'history',
#        'file': '',
#        'filename': '',
#        'full_command': 'history',
#        'stderr': '',
#        'stdout': ' 1 pwd\n 2 cd Bash\n 3 pwd\n 4 cd RNASeqOutput/\n 5 ls\n 6 mkdir Drug_A\n 7 mkdir Drug_B\n 8 fastx_trimmer < ~/Bash/UncompressedSamples/Drug_A/Drug_A_1.fastq > ~/Bash/RNASeqOutput/Drug_A/Drug_A_1.fq.trimmed\n 9 fastx_trimmer -m 20 -f 1 < ~/Bash/UncompressedSamples/Drug_A/Drug_A_1.fastq > ~/Bash/RNASeqOutput/Drug_A/Drug_A_1.fq.trimmed\n 10 pwd\n 11 cd Drug_A\n 12 ls\n 13 fastq_quality_filter -q 50 < Drug_A_1.fq.trimmed > Drug_A_1.fq.filtered\n 14 ls\n 15 ls -l\n 16 pwd\n 17 ls -l ~/Discovery\n 18 cd ~/Bash\n 19 ls\n 20 history',
#        'time': '2021-04-19:23:56'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd Bash',
#        'stderr': '/home/jovyan/.offline.sh: line 344: cd: Bash: No such file or directory',
#        'stdout': '',
#        'time': '2021-04-19:23:57'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan/Bash',
#        'time': '2021-04-19:23:57'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd bin',
#        'stderr': '',
#        'stdout': '',
#        'time': '2021-04-19:23:57'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'directory_grep_head_tail\nEchoCounts\ngrep_head_tail\nReadLoop.sh',
#        'time': '2021-04-19:23:57'},
#       {'command': 'nano',
#        'diff_l': 1,
#        'diff_wc': 12,
#        'file': '',
#        'filename': 'my_fast_x',
#        'new_l': 1,
#        'new_wc': 12,
#        'old_l': 0,
#        'old_wc': 0,
#        'stderr': '',
#        'stdout': '',
#        'time': '2021-04-20:00:04',
#        'total_time(s)': 242},
#       {'command': 'mv',
#        'file': '',
#        'filename': '',
#        'full_command': 'mv my_fast_x my_fastx',
#        'stderr': '',
#        'stdout': '',
#        'time': '2021-04-20:00:04'},
#       {'command': 'chmod',
#        'file': '',
#        'filename': '',
#        'full_command': 'chmod a+x my_fastx',
#        'stderr': '',
#        'stdout': '',
#        'time': '2021-04-20:00:04'}]},
#     'log_id': '2f3c04c9be3cc02268104e419f0c962bc674e4e7411c8c0f67b34f11f89fc398',
#     'log_type': 'Bash',
#     'machine_id': '96f9246a-4423-42ce-a9d9-4d8c7e170714-dfb488dcc-g',
#     'session_id': 'None',
#     'timestamp': '2021-04-20 00:08:03.958314'},
#    {'_id': 'Bash:2854020a-98a3-45ef-a36d-001aad8a1102',
#     '_rev': '1-489abf81c72d0a778038e6ac47fd0301',
#     'course_id': 'Comp-512-Test',
#     'created_timestamp': '2021-04-19 19:42:23.349876',
#     'log': {'commands': []},
#     'log_id': 'c652a90be593a87cfcc9fad6503c2ae8c79d4cfeda4017d68460a145723a3d1f',
#     'log_type': 'Bash',
#     'machine_id': '97495cb2',
#     'session_id': 'None',
#     'timestamp': '2021-04-19 19:42:23.349876'},
#    {'_id': 'Bash:288983ec-cc25-4ca4-b97d-8be747d8fff8',
#     '_rev': '13-b68d118c2e8438890db40949b2b3f9b5',
#     'course_id': 'Comp-512-Test',
#     'created_timestamp': '2022-09-29 18:53:13.401079',
#     'log': {'commands': [{'command': 'clear',
#        'file': '',
#        'filename': '',
#        'full_command': 'clear',
#        'stderr': '',
#        'stdout': '\x1b[H\x1b[2J\x1b[3J',
#        'time': '2022-09-29:18:52'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan',
#        'time': '2022-09-29:18:53'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo $PATH',
#        'stderr': '',
#        'stdout': '/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/bin/TDM-GCC-64/bin',
#        'time': '2022-09-29:18:53'},
#       {'command': 'hostname',
#        'file': '',
#        'filename': '',
#        'full_command': 'hostname',
#        'stderr': '',
#        'stdout': 'ac9d01872',
#        'time': '2022-09-29:18:54'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan',
#        'time': '2022-09-29:18:54'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#        'time': '2022-09-29:18:56'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /home/jovyan',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-29:18:57'},
#       {'command': 'clear',
#        'file': '',
#        'filename': '',
#        'full_command': 'clear',
#        'stderr': '',
#        'stdout': '\x1b[H\x1b[2J\x1b[3J',
#        'time': '2022-09-29:19:00'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-29:19:00'}]},
#     'log_id': 'd255305150a0d892434887745e969de6e48e7d48bc7f84a362951001d7f6c31c',
#     'log_type': 'Bash',
#     'machine_id': 'ac9d0',
#     'session_id': 'None',
#     'timestamp': '2022-09-29 19:09:24.195806'},
#    {'_id': 'Bash:299a5913-486e-4c51-ba7d-d35fe5599a5a',
#     '_rev': '3-07830c12e1d9254d0addc2a31c960999',
#     'course_id': 'Comp-512-Test',
#     'created_timestamp': '2021-04-19 19:50:28.064418',
#     'log': {'commands': []},
#     'log_id': 'ec8cf037d8327a21f8206985d7f0cf00f83804975934c584e0112c133050673d',
#     'log_type': 'Bash',
#     'machine_id': '1ad8463d',
#     'session_id': 'None',
#     'timestamp': '2021-04-19 19:52:29.849498'},
#    {'_id': 'Bash:36a00980-8870-4dd6-9ba7-184a817d48a6',
#     '_rev': '13-b4559a53f6032c745af5d2a9b60e3280',
#     'course_id': 'Comp-512-Test',
#     'created_timestamp': '2022-09-29 18:53:02.067400',
#     'log': {'commands': [{'command': 'clear',
#        'file': '',
#        'filename': '',
#        'full_command': 'clear',
#        'stderr': '',
#        'stdout': '\x1b[H\x1b[2J\x1b[3J',
#        'time': '2022-09-29:18:52'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan',
#        'time': '2022-09-29:18:53'},
#       {'command': 'echo',
#        'file': '',
#        'filename': '',
#        'full_command': 'echo $PATH',
#        'stderr': '',
#        'stdout': '/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/bin/TDM-GCC-64/bin',
#        'time': '2022-09-29:18:53'},
#       {'command': 'hostname',
#        'file': '',
#        'filename': '',
#        'full_command': 'hostname',
#        'stderr': '',
#        'stdout': 'ac9d01872',
#        'time': '2022-09-29:18:54'},
#       {'command': 'pwd',
#        'file': '',
#        'filename': '',
#        'full_command': 'pwd',
#        'stderr': '',
#        'stdout': '/home/jovyan',
#        'time': '2022-09-29:18:54'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#        'time': '2022-09-29:18:56'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /home/jovyan',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-29:18:57'},
#       {'command': 'clear',
#        'file': '',
#        'filename': '',
#        'full_command': 'clear',
#        'stderr': '',
#        'stdout': '\x1b[H\x1b[2J\x1b[3J',
#        'time': '2022-09-29:19:00'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-29:19:00'}]},
#     'log_id': '8a0d5bed0152303242b9094ce32098e117fc8f1a7169e69df2cee99ad9d8ec3c',
#     'log_type': 'Bash',
#     'machine_id': 'ac9d0',
#     'session_id': 'None',
#     'timestamp': '2022-09-29 19:09:34.624279'}]},
#  {'logs': [{'_id': 'Bash:cb24ee90-447c-4119-9973-6c2305e12abe',
#     '_rev': '292-261a171d16df8e4785c061f2f1ca4dca',
#     'course_id': 'Cyverse-RNA-Tutorial',
#     'created_timestamp': '2022-09-29 19:20:08.685273',
#     'log': {'commands': [{'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-29:19:19'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '.',
#        'full_command': 'ls .',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-09-29:19:20'},
#       {'command': 'clear',
#        'file': '',
#        'filename': '',
#        'full_command': 'clear',
#        'stderr': '',
#        'stdout': '\x1b[H\x1b[2J\x1b[3J',
#        'time': '2022-09-29:19:20'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd Bash',
#        'stderr': '/home/jovyan/.offline.sh: line 354: cd: Bash: No such file or directory',
#        'stdout': '',
#        'time': '2022-09-29:19:24'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-29:19:24'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'sdgeorge\nshared',
#        'time': '2022-09-29:19:24'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '..',
#        'full_command': 'cd ..',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-29:19:25'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd data',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-29:19:25'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'input\niplant\noutput',
#        'time': '2022-09-29:19:25'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd input/',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-29:19:25'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#        'time': '2022-09-29:19:25'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd Bash',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-29:19:25'},
#       {'command': 'mkdir',
#        'file': '',
#        'filename': '',
#        'full_command': 'mkdir mschild',
#        'stderr': 'mkdir: cannot create directory ‘mschild’: Permission denied',
#        'stdout': '',
#        'time': '2022-09-29:19:27'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-09-29:19:27'}]},
#     'log_id': '6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353411be02043e60902e7',
#     'log_type': 'Bash',
#     'machine_id': 'a9321',
#     'session_id': 'None',
#     'timestamp': '2022-09-30 01:51:00.512308'},
#    {'_id': 'Bash:f5aed48e-a496-4e85-a508-948584d96f8e',
#     '_rev': '32-48e371b7e24328081573b967ca97b9ac',
#     'course_id': 'Cyverse-RNA-Tutorial',
#     'created_timestamp': '2022-10-13 23:59:31.851513',
#     'log': {'commands': [{'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /home/jovyan',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-10-13:23:59'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-10-14:00:01'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /home/jovyan/RNA_SEQ_SAMPLES',
#        'stderr': "ls: cannot access '/home/jovyan/RNA_SEQ_SAMPLES': No such file or directory",
#        'stdout': '',
#        'time': '2022-10-14:00:01'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls home',
#        'stderr': '',
#        'stdout': 'gunings\nshared',
#        'time': '2022-10-14:00:22'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls gunings/RNA_SEQ_SAMPLES',
#        'stderr': "ls: cannot access 'gunings/RNA_SEQ_SAMPLES': No such file or directory",
#        'stdout': '',
#        'time': '2022-10-14:00:22'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls /gunings/RNA_SEQ_SAMPLES',
#        'stderr': "ls: cannot access '/gunings/RNA_SEQ_SAMPLES': No such file or directory",
#        'stdout': '',
#        'time': '2022-10-14:00:22'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls gunings',
#        'stderr': "ls: cannot access 'gunings': No such file or directory",
#        'stdout': '',
#        'time': '2022-10-14:00:22'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd gunings',
#        'stderr': '/home/jovyan/.offline.sh: line 354: cd: gunings: No such file or directory',
#        'stdout': '',
#        'time': '2022-10-14:00:22'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#        'time': '2022-10-14:00:23'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd home/gunings',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-10-14:00:23'},
#       {'command': 'ls',
#        'file': '',
#        'filename': '',
#        'full_command': 'ls',
#        'stderr': '',
#        'stdout': 'analyses\nBash\nDiscovery\nDNASubway\nPermissionsTest',
#        'time': '2022-10-14:00:23'},
#       {'command': 'cd',
#        'file': '',
#        'filename': '',
#        'full_command': 'cd',
#        'stderr': '',
#        'stdout': '',
#        'time': '2022-10-14:00:23'},
#       {'command': 'ls',
#        'file': '',
#        'filename': 'Stdout.txt',
#        'full_command': 'ls Stdout.txt',
#        'stderr': "ls: cannot access 'Stdout.txt': No such file or directory",
#        'stdout': '',
#        'time': '2022-10-14:00:23'}]},
#     'log_id': '3a15d2c2e44e3c8d8ff99321addf6374e8c7966cbd98d83ad9c159b9e65b4d38',
#     'log_type': 'Bash',
#     'machine_id': 'a8c71',
#     'session_id': 'None',
#     'timestamp': '2022-10-14 00:41:19.065604'}]}]

# %% [markdown]
# # Process Data

# %% [markdown]
# ## Build Command Records - Array of JSON Objects

# %%
what_it_expects = [{"Animal": "Cat", "Size": "Medium"}, {"Animal": "Dog", "Size": "Large"}]
pd.DataFrame.from_records(what_it_expects)
# Out:
#   Animal    Size
# 0    Cat  Medium
# 1    Dog   Large

# %%
raw_records = []
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    machine_id = i['machine_id']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        #Build the common columns for all events
        to_add = {
            "Log ID": log_id, 
            "Course": course, 
            "Log Type": log_type,
        }
        
        #add to dict with equal
        to_add['Machine ID'] = machine_id
        
        #Add each command to array and update 
        to_add.update(event)
        
        #Sometimes processing type prior to building frame is easiest
        #For example, pandas can understand datetime, but right now it is a string. 
        #Convert the time into a string using this datetime function.
        to_add['time'] = datetime.strptime(to_add['time'], "%Y-%m-%d:%H:%M")
        
        raw_records.append(to_add)

#Look at the records we have made
raw_records[0:1]
# Out:
# [{'Log ID': '490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519e3a41d8fbd2f2af05e',
#   'Course': 'Comp-512-Test',
#   'Log Type': 'Bash',
#   'Machine ID': '10bcd15c',
#   'command': 'ls',
#   'file': '',
#   'filename': '',
#   'full_command': 'ls',
#   'stderr': '',
#   'stdout': 'SuperShell\nstderr.txt',
#   'time': datetime.datetime(2021, 4, 19, 19, 34)}]

# %%
## Convert to Pandas Dataframe 
pd_records = pd.DataFrame.from_records(raw_records)
pd_records.head()
# Out:
#                                               Log ID         Course Log Type  \
# 0  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 1  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 2  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 3  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 4  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
#
#   Machine ID command file filename                 full_command  \
# 0   10bcd15c      ls                                         ls
# 1   10bcd15c  export                         export $TEST=Hello
# 2   10bcd15c  export                       export $TEST='Hello'
# 3   10bcd15c  export                export PATH=$PATH:$HOME/bin
# 4   10bcd15c  export                 export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#                  time  diff_l  diff_wc  new_l  new_wc  old_l  old_wc  \
# 0 2021-04-19 19:34:00     NaN      NaN    NaN     NaN    NaN     NaN
# 1 2021-04-19 19:35:00     NaN      NaN    NaN     NaN    NaN     NaN
# 2 2021-04-19 19:35:00     NaN      NaN    NaN     NaN    NaN     NaN
# 3 2021-04-19 19:36:00     NaN      NaN    NaN     NaN    NaN     NaN
# 4 2021-04-19 19:36:00     NaN      NaN    NaN     NaN    NaN     NaN
#
#    total_time(s)
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
print(max(pd_records['time']))
pd_records.info()
# Out:
# 2022-09-29 19:00:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Log ID         473 non-null    object
#  1   Course         473 non-null    object
#  2   Log Type       473 non-null    object
#  3   Machine ID     473 non-null    object
#  4   command        473 non-null    object
#  5   file           473 non-null    object
#  6   filename       473 non-null    object
#  7   full_command   455 non-null    object
#  8   stderr         473 non-null    object
#  9   stdout         473 non-null    object
#  10  time           473 non-null    datetime64[ns]
#  11  diff_l         18 non-null     float64
#  12  diff_wc        18 non-null     float64
#  13  new_l          18 non-null     float64
#  14  new_wc         18 non-null     float64
#  15  old_l          18 non-null     float64
#  16  old_wc         18 non-null     float64
#  17  total_time(s)  18 non-null     float64
# dtypes: datetime64[ns](1), float64(7), object(10)
# memory usage: 66.6+ KB

# %% [markdown]
# ## Build Command Records - JSON of Arrays

# %%
high_level_json = {
    "Log ID": [],
    "Course": [],
    "Log Type": [], 
    "command": [],
    "file": [],
    "filename": [], 
    "full_command": [],
    "stderr": [],
    "stdout": [],
    "time": []
}
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        #Build the common columns for all events
        high_level_json['Log ID'].append(log_id)
        high_level_json['Course'].append(course)
        high_level_json['Log Type'].append(log_type)
        
        for i in event: 
            high_level_json[i].append(event[i])
        
        #Note it is a little more difficult to convert these strings here.
        #You could do an if in the for i in event statement 
        #We will leverage Pandas datetime function to do this for us. 
        

#Look at the JSON
high_level_json
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-e85c11f36819> in <module>
#      26
#      27         for i in event:
# ---> 28             high_level_json[i].append(event[i])
#      29
#      30         #Note it is a little more difficult to convert these strings here.
#
# KeyError: 'diff_l'

# %%
## Convert to Dataframe 
pd_from_json = pd.DataFrame.from_dict(high_level_json)
pd_from_json.head()
# Out:
#                                               Log ID                Course  \
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 1  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 2  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 3  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 4  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
#
#   Log Type command file filename full_command  \
# 0     Bash      ls                         ls
# 1     Bash      ls             .         ls .
# 2     Bash   clear                      clear
# 3     Bash      cd                    cd Bash
# 4     Bash      cd                    cd home
#
#                                               stderr  \
# 0
# 1
# 2
# 3  /home/jovyan/.offline.sh: line 354: cd: Bash: ...
# 4
#
#                                stdout              time
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:19
# 1  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:20
# 2                           2022-09-29:19:20
# 3                                      2022-09-29:19:24
# 4                                      2022-09-29:19:24

# %%
## Notice Types 
pd_from_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Log ID        27 non-null     object
#  1   Course        27 non-null     object
#  2   Log Type      27 non-null     object
#  3   command       27 non-null     object
#  4   file          27 non-null     object
#  5   filename      27 non-null     object
#  6   full_command  27 non-null     object
#  7   stderr        27 non-null     object
#  8   stdout        27 non-null     object
#  9   time          27 non-null     object
# dtypes: object(10)
# memory usage: 2.2+ KB

# %%
## Time is an object, we want these to be datetimes, can do this in pandas 
pd_from_json['Timestamp'] = pd.to_datetime(pd_from_json['time'], format="%Y-%m-%d:%H:%M")
print(max(pd_from_json['time']))
print(max(pd_from_json['Timestamp']))
pd_from_json.info()
# Out:
# 2022-10-14:00:23
# 2022-10-14 00:23:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Log ID        27 non-null     object
#  1   Course        27 non-null     object
#  2   Log Type      27 non-null     object
#  3   command       27 non-null     object
#  4   file          27 non-null     object
#  5   filename      27 non-null     object
#  6   full_command  27 non-null     object
#  7   stderr        27 non-null     object
#  8   stdout        27 non-null     object
#  9   time          27 non-null     object
#  10  Timestamp     27 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 2.4+ KB

# %% [markdown]
# ## Build Command Records - DataFrame Hybrid

# %%
base_frame = pd.DataFrame()
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        
        #Build a dataframe for the smallest unit
        subframe = pd.DataFrame.from_records([event])
        
        #Add common fields to subframe 
        subframe['Log ID'] = log_id
        subframe['Course'] = course
        subframe['Log Type'] = log_type
        
        if base_frame.shape[0] == 0:
            base_frame = subframe
            # breaks out of for loop 
            # a nifty command
            continue 
            
        base_frame = pd.concat([base_frame, subframe])
        

base_frame.head()
# Out:
#   command file filename full_command  \
# 0      ls                         ls
# 0      ls             .         ls .
# 0   clear                      clear
# 0      cd                    cd Bash
# 0      cd                    cd home
#
#                                               stderr  \
# 0
# 0
# 0
# 0  /home/jovyan/.offline.sh: line 354: cd: Bash: ...
# 0
#
#                                stdout              time  \
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:19
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:20
# 0                           2022-09-29:19:20
# 0                                      2022-09-29:19:24
# 0                                      2022-09-29:19:24
#
#                                               Log ID                Course  \
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
#
#   Log Type
# 0     Bash
# 0     Bash
# 0     Bash
# 0     Bash
# 0     Bash

# %%
## Clean up again 
## Time is an object, we want these to be datetimes, can do this in pandas 
base_frame['Timestamp'] = pd.to_datetime(base_frame['time'], format="%Y-%m-%d:%H:%M")
base_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 0
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   command       27 non-null     object
#  1   file          27 non-null     object
#  2   filename      27 non-null     object
#  3   full_command  27 non-null     object
#  4   stderr        27 non-null     object
#  5   stdout        27 non-null     object
#  6   time          27 non-null     object
#  7   Log ID        27 non-null     object
#  8   Course        27 non-null     object
#  9   Log Type      27 non-null     object
#  10  Timestamp     27 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 2.5+ KB

# %% [markdown]
# # Export Dataframe

# %%
#This will allow you to manipulate what you export and not effect pd_records
to_export = pd_records.copy()

#Some column manipulation can be useful 
column_list = list(to_export.columns)

#You can reorder like so 
column_list.remove('time')
column_list = ["time"] + column_list
print(column_list)

#Rearrange columns, time is now the first column
to_export = to_export[column_list]
to_export.head()
# Out:
# ['time', 'Log ID', 'Course', 'Log Type', 'Machine ID', 'command', 'file', 'filename', 'full_command', 'stderr', 'stdout', 'diff_l', 'diff_wc', 'new_l', 'new_wc', 'old_l', 'old_wc', 'total_time(s)']
#                  time                                             Log ID  \
# 0 2021-04-19 19:34:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 1 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 2 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 3 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 4 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
#
#           Course Log Type Machine ID command file filename  \
# 0  Comp-512-Test     Bash   10bcd15c      ls
# 1  Comp-512-Test     Bash   10bcd15c  export
# 2  Comp-512-Test     Bash   10bcd15c  export
# 3  Comp-512-Test     Bash   10bcd15c  export
# 4  Comp-512-Test     Bash   10bcd15c  export
#
#                   full_command  \
# 0                           ls
# 1           export $TEST=Hello
# 2         export $TEST='Hello'
# 3  export PATH=$PATH:$HOME/bin
# 4   export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#    diff_l  diff_wc  new_l  new_wc  old_l  old_wc  total_time(s)
# 0     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 3     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN            NaN

# %%
# Make sure to add the suffix to the file name. You can also give path 
to_export.to_csv(output_dir + "response3.csv")

# %%
# If you are going to import to pandas later, I suggest pickle file 
# This will preserve types such as datetimes 
to_export.to_pickle(output_dir + "response3.pki")

# %% [markdown]
# # Read Back to Check

# %%
reloaded = pd.read_pickle(output_dir + "response2.pki")
reloaded.head()
# Out:
#                  time                                             Log ID  \
# 0 2021-04-19 19:34:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 1 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 2 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 3 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 4 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
#
#           Course Log Type Machine ID command file filename  \
# 0  Comp-512-Test     Bash   10bcd15c      ls
# 1  Comp-512-Test     Bash   10bcd15c  export
# 2  Comp-512-Test     Bash   10bcd15c  export
# 3  Comp-512-Test     Bash   10bcd15c  export
# 4  Comp-512-Test     Bash   10bcd15c  export
#
#                   full_command  \
# 0                           ls
# 1           export $TEST=Hello
# 2         export $TEST='Hello'
# 3  export PATH=$PATH:$HOME/bin
# 4   export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#    diff_l  diff_wc  new_l  new_wc  old_l  old_wc  total_time(s)
# 0     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 3     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN            NaN

# %%
reloaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           333 non-null    datetime64[ns]
#  1   Log ID         333 non-null    object
#  2   Course         333 non-null    object
#  3   Log Type       333 non-null    object
#  4   Machine ID     333 non-null    object
#  5   command        333 non-null    object
#  6   file           333 non-null    object
#  7   filename       333 non-null    object
#  8   full_command   326 non-null    object
#  9   stderr         333 non-null    object
#  10  stdout         333 non-null    object
#  11  diff_l         7 non-null      float64
#  12  diff_wc        7 non-null      float64
#  13  new_l          7 non-null      float64
#  14  new_wc         7 non-null      float64
#  15  old_l          7 non-null      float64
#  16  old_wc         7 non-null      float64
#  17  total_time(s)  7 non-null      float64
# dtypes: datetime64[ns](1), float64(7), object(10)
# memory usage: 47.0+ KB
