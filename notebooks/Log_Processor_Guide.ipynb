# %% [markdown]
# # Import Packages

# %%
import json
import os
import pandas as pd
from datetime import datetime
# Out:
# /var/folders/q8/7tsylxls0kbbt_gql150b1jh0000gn/T/ipykernel_51974/2701838198.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Example JSON Load

# %%
sample = {
    "col1": {
        "Layer2":[{
            "Layer3"
        }]
    }, 
    "col2": "Hello"
}

# %%
pd.DataFrame.from_dict(sample)
# Out:
#               col1   col2
# Layer2  [{Layer3}]  Hello

# %% [markdown]
# # Load Data

# %%
data_folder = "logs/"
output_dir = "output_data/"
file = "zwy324.json"
raw_json = None

#Handy for making an output dir inline if needed. 
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

#I always read JSON in as JSON first and then parse. 
with open(data_folder + file, "r+") as f:
    raw_json = json.load(f)
raw_json
# Out:
# {'_id': {'$oid': '65b3fa448490e9aa28588599'},
#  'timestamp': '2024-01-26 19:55:50.198',
#  'log_id': '094fb05870c08e0da848c72af3c1d51b412c77ce0a45deecd86f9cee12a0ed37',
#  'machine_id': 'aeb29',
#  'session_id': 'zwy324',
#  'course_id': 'Cyverse-RNA-Tutorial',
#  'log_type': 'Bash',
#  'log': {'commands': [{'time': '2024-01-26:18:33',
#     'command': 'ls',
#     'full_command': 'ls /home/jovyan',
#     'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:35',
#     'command': 'ls',
#     'full_command': 'ls .',
#     'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '.',
#     'file': ''},
#    {'time': '2024-01-26:18:35',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:36',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:36',
#     'command': 'ls',
#     'full_command': 'ls ..',
#     'stdout': 'jovyan\nshiny',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:18:36',
#     'command': 'ls',
#     'full_command': 'ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#     'stdout': 'Drug_A\nDrug_B',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:36',
#     'command': 'ls',
#     'full_command': 'ls ./data-store/data/input/RNA_SEQ_SAMPLES',
#     'stdout': 'Drug_A\nDrug_B',
#     'stderr': '',
#     'filename': './data-store/data/input/RNA_SEQ_SAMPLES',
#     'file': ''},
#    {'time': '2024-01-26:18:36',
#     'command': 'ls',
#     'full_command': 'ls stderr.txt',
#     'stdout': 'stderr.txt',
#     'stderr': '',
#     'filename': 'stderr.txt',
#     'file': ''},
#    {'time': '2024-01-26:18:37',
#     'command': 'ls',
#     'full_command': 'ls Stderr.txt',
#     'stdout': '',
#     'stderr': "ls: cannot access 'Stderr.txt': No such file or directory",
#     'filename': 'Stderr.txt',
#     'file': ''},
#    {'time': '2024-01-26:18:38',
#     'command': 'ls',
#     'full_command': 'ls d^t',
#     'stdout': '',
#     'stderr': "ls: cannot access 'd^t': No such file or directory",
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:39',
#     'command': 'ls',
#     'full_command': 'ls data-store/data/input/Discovery/',
#     'stdout': 'FilteredSortedOutput\nRNASequenceOutput\nTSVFiles\nUncompressedSamples',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:39',
#     'command': 'ls',
#     'full_command': 'ls -l data-store/data/input/Discovery/',
#     'stdout': 'total 0\ndr-x------ 0 jovyan jovyan 0 Jan 26 18:04 FilteredSortedOutput\ndr-x------ 0 jovyan jovyan 0 Jan 26 18:04 RNASequenceOutput\ndr-x------ 0 jovyan jovyan 0 Jan 26 18:07 TSVFiles\ndr-x------ 0 jovyan jovyan 0 Jan 26 18:04 UncompressedSamples',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:40',
#     'command': 'ls',
#     'full_command': 'ls -l data-store/data/input/Discovery/TSVFiles',
#     'stdout': 'total 24272\n-r-x------ 0 jovyan jovyan 6237689 Jan 26 17:12 A_1_abundance.tsv\n-r-x------ 0 jovyan jovyan 6135948 Jan 26 17:11 A_2_abundance.tsv\n-r-x------ 0 jovyan jovyan 6237909 Jan 26 17:11 B_1_abundance.tsv\n-r-x------ 0 jovyan jovyan 6237909 Jan 26 17:11 B_2_abundance.tsv',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:40',
#     'command': 'history',
#     'full_command': 'history',
#     'stdout': ' 1 ls /home/jovyan\n 2 ls .\n 3 pwd\n 4 ls\n 5 ls ..\n 6 ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 7 ls ./data-store/data/input/RNA_SEQ_SAMPLES\n 8 ls stderr.txt\n 9 ls Stderr.txt\n 10 ls d^t\n 11 ls data-store/data/input/Discovery/\n 12 ls -l data-store/data/input/Discovery/\n 13 ls -l data-store/data/input/Discovery/TSVFiles\n 14 history',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:41',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:41',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:41',
#     'command': 'ls',
#     'full_command': 'ls SuperShell/',
#     'stdout': 'add_interactive.sh\ncodehelper.sh\nconsent.txt\ncourseid.txt\ncyverse_install.sh\ndisable_help.sh\ndocker_install.sh\nenable_help.sh\nflowchart.png\nimages\ninstall.sh\ninstall_supershell.sh\ninteractive.txt\nLICENSE\nlinux_install.sh\nmac_install.sh\nmail.txt\noffline.sh\noffline_with_online.sh\npush_events.sh\nREADME.md\nruledir.txt\nsession_extract.sh\nshell2.sh\nshell.sh\nStatParam\nsupershellhelpmessage.txt\nsupershellhelp.txt\nSuperShellHistory\nsupershellinfo.txt\nSuperShellRules\nTestSender2.jar\nTestSender.jar\ntitle.txt\nTowards a Helpful Shell_ Scenarios and Commands.pdf',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:42',
#     'command': 'ls',
#     'full_command': 'ls -l',
#     'stdout': 'total 0\ndrwxrwsrwx 3 root jovyan 42 Jan 26 18:29 data-store\n-rw-r--r-- 1 jovyan users 0 Jan 26 18:42 stderr.txt\ndrwxr-sr-x 1 jovyan users 39 Oct 25 17:57 SuperShell\ndrwsrwsr-x 2 jovyan users 10 Mar 20 2023 work',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:44',
#     'command': 'ls',
#     'full_command': 'ls -l stderr.txt',
#     'stdout': '-rw-r--r-- 1 jovyan users 0 Jan 26 18:44 stderr.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:44',
#     'command': 'ls',
#     'full_command': 'ls -l ./data-store/data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#     'stdout': '-rw-r--r-- 1 jovyan users 0 Jan 26 18:44 stderr.txt\n\n./data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_B',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:45',
#     'command': 'ls',
#     'full_command': 'ls -l -R ./data-store/data/input/RNA_SEQ_SAMPLES/',
#     'stdout': './data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_B\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 9024\n-r-x------ 0 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-x------ 0 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-x------ 0 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-x------ 0 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 9392\n-r-x------ 0 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-x------ 0 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-x------ 0 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-x------ 0 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:45',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:45',
#     'command': 'ls',
#     'full_command': 'ls -l',
#     'stdout': 'total 0\ndrwxrwsrwx 3 root jovyan 42 Jan 26 18:29 data-store\n-rw-r--r-- 1 jovyan users 0 Jan 26 18:45 stderr.txt\ndrwxr-sr-x 1 jovyan users 39 Oct 25 17:57 SuperShell\ndrwsrwsr-x 2 jovyan users 10 Mar 20 2023 work',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:46',
#     'command': 'ls',
#     'full_command': 'ls ..',
#     'stdout': 'jovyan\nshiny',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:18:47',
#     'command': 'ls',
#     'full_command': 'ls -l SuperShell/',
#     'stdout': 'total 60364\n-rwxr-xr-x 1 jovyan users 47 Oct 25 17:57 add_interactive.sh\n-rwxr-xr-x 1 jovyan users 7154 Oct 25 17:57 codehelper.sh\n-rwxr-xr-x 1 jovyan users 9953 Oct 25 17:57 consent.txt\n-rwxr-xr-x 1 jovyan users 20 Oct 25 17:57 courseid.txt\n-rwxr-xr-x 1 jovyan users 440 Oct 25 17:57 cyverse_install.sh\n-rwxr-xr-x 1 jovyan users 82 Oct 25 17:57 disable_help.sh\n-rwxr-xr-x 1 jovyan users 493 Oct 25 17:57 docker_install.sh\n-rwxr-xr-x 1 jovyan users 83 Oct 25 17:57 enable_help.sh\n-rwxr-xr-x 1 jovyan users 256548 Oct 25 17:57 flowchart.png\ndrwxr-sr-x 2 jovyan users 239 Oct 25 17:57 images\n-rwxr-xr-x 1 jovyan users 449 Oct 25 17:57 install.sh\n-rwxr-xr-x 1 jovyan users 71 Oct 25 17:57 install_supershell.sh\n-rwxr-xr-x 1 jovyan users 25 Oct 25 17:57 interactive.txt\n-rwxr-xr-x 1 jovyan users 1074 Oct 25 17:57 LICENSE\n-rwxr-xr-x 1 jovyan users 678 Oct 25 17:57 linux_install.sh\n-rwxr-xr-x 1 jovyan users 699 Oct 25 17:57 mac_install.sh\n-rwxr-xr-x 1 jovyan users 0 Oct 25 17:57 mail.txt\n-rwxr-xr-x 1 jovyan users 39814 Oct 25 17:57 offline.sh\n-rwxr-xr-x 1 jovyan users 18137 Oct 25 17:57 offline_with_online.sh\n-rwxr-xr-x 1 jovyan users 2001 Oct 25 17:57 push_events.sh\n-rwxr-xr-x 1 jovyan users 3446 Oct 25 17:57 README.md\n-rwxr-xr-x 1 jovyan users 15 Oct 25 17:57 ruledir.txt\n-rwxr-xr-x 1 jovyan users 339 Oct 25 17:57 session_extract.sh\n-rwxr-xr-x 1 jovyan users 6105 Oct 25 17:57 shell2.sh\n-rwxr-xr-x 1 jovyan users 6101 Oct 25 17:57 shell.sh\ndrwxr-sr-x 2 jovyan users 71 Oct 25 17:57 StatParam\n-rwxr-xr-x 1 jovyan users 62 Oct 25 17:57 supershellhelpmessage.txt\n-rwxr-xr-x 1 jovyan users 3 Oct 25 17:57 supershellhelp.txt\ndrwxr-sr-x 1 jovyan users 47 Jan 26 18:30 SuperShellHistory\n-rwxr-xr-x 1 jovyan users 2118 Oct 25 17:57 supershellinfo.txt\ndrwxr-sr-x 3 jovyan users 144 Oct 25 17:57 SuperShellRules\n-rwxr-xr-x 1 jovyan users 30522687 Oct 25 17:57 TestSender2.jar\n-rwxr-xr-x 1 jovyan users 30523328 Oct 25 17:57 TestSender.jar\n-rwxr-xr-x 1 jovyan users 1195 Oct 25 17:57 title.txt\n-rwxr-xr-x 1 jovyan users 326139 Oct 25 17:57 Towards a Helpful Shell_ Scenarios and Commands.pdf',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:51',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:51',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'cd',
#     'full_command': 'cd data-store/data/input/RNA_SEQ_SAMPLES/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'Drug_A\nDrug_B',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'cd',
#     'full_command': 'cd Drug_A',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:18:52',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/input',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:53',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:18:53',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:53',
#     'command': 'cd',
#     'full_command': 'cd /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:53',
#     'command': 'cd',
#     'full_command': 'cd ~',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:53',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:53',
#     'command': 'cd',
#     'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:53',
#     'command': 'cd',
#     'full_command': 'cd',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:54',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data-store\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:55',
#     'command': 'cd',
#     'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES//Drug_A',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:55',
#     'command': 'cd',
#     'full_command': 'cd',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:55',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:55',
#     'command': 'cd',
#     'full_command': 'cd SuperShell/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:55',
#     'command': 'cd',
#     'full_command': 'cd i',
#     'stdout': '',
#     'stderr': '/home/jovyan/.offline.sh: line 354: cd: i: No such file or directory',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:55',
#     'command': 'cd',
#     'full_command': 'cd images',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:56',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/SuperShell/images',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:56',
#     'command': 'cd',
#     'full_command': 'cd',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:57',
#     'command': 'which',
#     'full_command': 'which ls',
#     'stdout': '/usr/bin/ls',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:57',
#     'command': 'which',
#     'full_command': 'which cd',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:57',
#     'command': 'cd',
#     'full_command': 'cd pwd',
#     'stdout': '',
#     'stderr': '/home/jovyan/.offline.sh: line 354: cd: pwd: No such file or directory',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:57',
#     'command': 'which',
#     'full_command': 'which pwd',
#     'stdout': '/usr/bin/pwd',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:57',
#     'command': 'which',
#     'full_command': 'which cd',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:58',
#     'command': 'which',
#     'full_command': 'which which',
#     'stdout': '/usr/bin/which',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:58',
#     'command': 'which',
#     'full_command': 'which echo',
#     'stdout': '/usr/bin/echo',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:58',
#     'command': 'cd',
#     'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES//Drug_A',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:58',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES/Drug_A',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:59',
#     'command': 'cd',
#     'full_command': 'cd ../Drug_B',
#     'stdout': '',
#     'stderr': '',
#     'filename': '../Drug_B',
#     'file': ''},
#    {'time': '2024-01-26:18:59',
#     'command': 'cd',
#     'full_command': 'cd ../..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '../..',
#     'file': ''},
#    {'time': '2024-01-26:18:59',
#     'command': 'cd',
#     'full_command': 'cd RNA_SEQ_SAMPLES/Drug_B',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:18:59',
#     'command': 'ls',
#     'full_command': 'ls -a',
#     'stdout': '.\n..\nDrug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:00',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:00',
#     'command': 'cd',
#     'full_command': 'cd ./../Drug_A',
#     'stdout': '',
#     'stderr': '',
#     'filename': './../Drug_A',
#     'file': ''},
#    {'time': '2024-01-26:19:01',
#     'command': 'cd',
#     'full_command': 'cd /home/jovyan/data-store/data/output',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:01',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/output',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:01',
#     'command': 'mkdir',
#     'full_command': 'mkdir misc',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:01',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'misc',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:01',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/output',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:01',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'misc',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'input\niplant\noutput',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data\nhome\nuser',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data\nhome\nuser',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'cd',
#     'full_command': 'cd data/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'input\niplant\noutput',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'cd',
#     'full_command': 'cd output/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'misc',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:02',
#     'command': 'cd',
#     'full_command': 'cd misc/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'mkdir',
#     'full_command': 'mkdir misc_child',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'misc_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'mkdir',
#     'full_command': 'mkdir misc_child/misc_child_child',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'ls',
#     'full_command': 'ls misc_child/',
#     'stdout': 'misc_child_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'cd',
#     'full_command': 'cd misc_child/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'misc_child_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'cd',
#     'full_command': 'cd misc_child_child/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/output/misc/misc_child/misc_child_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'mkdir',
#     'full_command': 'mkdir misc_child_child_child.',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'misc_child_child_child.',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/output/misc/misc_child/misc_child_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:03',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'misc_child_child_child.',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'cd',
#     'full_command': 'cd ../../../..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '../../../..',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'cd',
#     'full_command': 'cd output/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'misc',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'mkdir',
#     'full_command': 'mkdir UncompressedSamples',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'mkdir',
#     'full_command': 'mkdir FilteredSortedOutput',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'mkdir',
#     'full_command': 'mkdir TSVFiles',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'mkdir',
#     'full_command': 'mkdir PermissionsTest',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'mkdir',
#     'full_command': 'mkdir RNASeqOutput',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:04',
#     'command': 'mkdir',
#     'full_command': 'mkdir bin',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:05',
#     'command': 'ls',
#     'full_command': 'ls -l',
#     'stdout': 'total 0\ndrwx------ 0 jovyan jovyan 0 Jan 26 19:04 bin\ndrwx------ 0 jovyan jovyan 0 Jan 26 19:04 FilteredSortedOutput\ndrwx------ 0 jovyan jovyan 0 Jan 26 19:01 misc\ndrwx------ 0 jovyan jovyan 0 Jan 26 19:04 PermissionsTest\ndrwx------ 0 jovyan jovyan 0 Jan 26 19:04 RNASeqOutput\ndrwx------ 0 jovyan jovyan 0 Jan 26 19:04 TSVFiles\ndrwx------ 0 jovyan jovyan 0 Jan 26 19:04 UncompressedSamples',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:05',
#     'command': 'cd',
#     'full_command': 'cd RNASeqOutput/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:05',
#     'command': 'mkdir',
#     'full_command': 'mkdir Advanced',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:05',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:19:05',
#     'command': 'cd',
#     'full_command': 'cd PermissionsTest/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:05',
#     'command': 'mkdir',
#     'full_command': 'mkdir PermissionsChild',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:06',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/output/PermissionsTest',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:06',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:19:06',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/output',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:06',
#     'command': 'cd',
#     'full_command': 'cd misc/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:07',
#     'command': 'pico',
#     'filename': 'hello.txt',
#     'old_wc': 0,
#     'new_wc': 2,
#     'old_l': 0,
#     'new_l': 2,
#     'diff_wc': 2,
#     'diff_l': 2,
#     'total_time(s)': 45,
#     'stdout': '',
#     'stderr': '',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:08',
#     'command': 'pico',
#     'filename': 'goodbye.txt',
#     'old_wc': 0,
#     'new_wc': 3,
#     'old_l': 0,
#     'new_l': 2,
#     'diff_wc': 3,
#     'diff_l': 2,
#     'total_time(s)': 41,
#     'stdout': '',
#     'stderr': '',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:08',
#     'command': 'cat',
#     'full_command': 'cat hello.txt',
#     'stdout': 'Hello\nWorld',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:08',
#     'command': 'cat',
#     'full_command': 'cat hello.txt goodbye.txt',
#     'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:09',
#     'command': 'cat',
#     'full_command': 'cat',
#     'stdout': 'abc\ndef',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:12',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/data-store/data/output/misc',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:13',
#     'command': 'ls',
#     'full_command': 'ls > ls.out',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:13',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'goodbye.txt\nhello.txt\nls.out\nmisc_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:13',
#     'command': 'cat',
#     'full_command': 'cat ls.out',
#     'stdout': 'goodbye.txt\nhello.txt\nls.out\nmisc_child',
#     'stderr': '',
#     'filename': 'ls.out',
#     'file': 'goodbye.txt\nhello.txt\nls.out\nmisc_child'},
#    {'time': '2024-01-26:19:13',
#     'command': 'cat',
#     'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:13',
#     'command': 'cat',
#     'full_command': 'cat hello_goodbye.txt',
#     'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld',
#     'stderr': '',
#     'filename': 'hello_goodbye.txt',
#     'file': 'Hello\nWorld\ngoodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:14',
#     'command': 'cat',
#     'full_command': 'cat < hello.txt',
#     'stdout': 'Hello\nWorld',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:15',
#     'command': 'cat',
#     'full_command': 'cat > cat.out',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:15',
#     'command': 'cat',
#     'full_command': 'cat cat.out',
#     'stdout': 'This is cat input\nMore cat input',
#     'stderr': '',
#     'filename': 'cat.out',
#     'file': 'This is cat input\nMore cat input'},
#    {'time': '2024-01-26:19:17',
#     'command': 'echo',
#     'full_command': 'echo "hello world\'',
#     'stdout': '',
#     'stderr': '/home/jovyan/.offline.sh: eval: line 368: unexpected EOF while looking for matching `"\'\n/home/jovyan/.offline.sh: eval: line 369: syntax error: unexpected end of file',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:17',
#     'command': 'echo',
#     'full_command': 'echo "hello world"',
#     'stdout': 'hello world',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:17',
#     'command': 'echo',
#     'full_command': 'echo 1 2',
#     'stdout': '1 2',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:19',
#     'command': 'echo',
#     'full_command': 'echo "hello world" > misc_child/echo.out',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:19',
#     'command': 'cat',
#     'full_command': 'cat misc_child/echo.out',
#     'stdout': 'hello world',
#     'stderr': '',
#     'filename': 'misc_child/echo.out',
#     'file': 'hello world'},
#    {'time': '2024-01-26:19:20',
#     'command': 'echo',
#     'full_command': 'echo "goodbye world" > misc_child/echo_output.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:20',
#     'command': 'cat',
#     'full_command': 'cat misc_child/echo_output.txt',
#     'stdout': 'goodbye world',
#     'stderr': '',
#     'filename': 'misc_child/echo_output.txt',
#     'file': 'goodbye world'},
#    {'time': '2024-01-26:19:20',
#     'command': 'echo',
#     'full_command': 'echo "hello world" >> misc_child/echo_output.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:21',
#     'command': 'cat',
#     'full_command': 'cat misc_child/echo_output.txt',
#     'stdout': 'goodbye world\nhello world',
#     'stderr': '',
#     'filename': 'misc_child/echo_output.txt',
#     'file': 'goodbye world\nhello world'},
#    {'time': '2024-01-26:19:21',
#     'command': 'cat',
#     'full_command': 'cat cat.out goodbye.txt hello_goodbye.txt hello.txt ls.out misc_child',
#     'stdout': 'This is cat input\nMore cat input\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye.txt\nhello.txt\nls.out\nmisc_child',
#     'stderr': 'cat: misc_child: Is a directory',
#     'filename': 'cat.out',
#     'file': 'This is cat input\nMore cat input'},
#    {'time': '2024-01-26:19:22',
#     'command': 'cat',
#     'full_command': 'cat goodbye.txt hello_goodbye.txt hello.txt',
#     'stdout': 'goodbye beautiful\nworld\nHello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld',
#     'stderr': '',
#     'filename': 'goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:22',
#     'command': 'cat',
#     'full_command': 'cat hello_goodbye.txt hello.txt',
#     'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld',
#     'stderr': '',
#     'filename': 'hello_goodbye.txt',
#     'file': 'Hello\nWorld\ngoodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:22',
#     'command': 'cat',
#     'full_command': 'cat hello_goodbye.txt hello.txt',
#     'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld',
#     'stderr': '',
#     'filename': 'hello_goodbye.txt',
#     'file': 'Hello\nWorld\ngoodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:23',
#     'command': 'ls',
#     'full_command': 'ls -l ~/*.txt',
#     'stdout': '-rw-r--r-- 1 jovyan users 0 Jan 26 19:23 /home/jovyan/stderr.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:23',
#     'command': 'echo',
#     'full_command': 'echo cat.out goodbye.txt hello_goodbye.txt hello.txt ls.out misc_child',
#     'stdout': 'cat.out goodbye.txt hello_goodbye.txt hello.txt ls.out misc_child',
#     'stderr': '',
#     'filename': 'cat.out',
#     'file': 'This is cat input\nMore cat input'},
#    {'time': '2024-01-26:19:23',
#     'command': 'echo',
#     'full_command': 'echo ~/*.txt',
#     'stdout': '/home/jovyan/stderr.txt',
#     'stderr': '',
#     'filename': '~/*.txt',
#     'file': ''},
#    {'time': '2024-01-26:19:25',
#     'command': 'cp',
#     'full_command': 'cp goodbye.txt copied_goodbye.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:25',
#     'command': 'cat',
#     'full_command': 'cat copied_goodbye.txt',
#     'stdout': 'goodbye beautiful\nworld',
#     'stderr': '',
#     'filename': 'copied_goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:26',
#     'command': 'cp',
#     'full_command': 'cp goodbye.txt misc_child/copied_goodbye.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:26',
#     'command': 'cat',
#     'full_command': 'cat misc_child/copied_goodbye.txt',
#     'stdout': 'goodbye beautiful\nworld',
#     'stderr': '',
#     'filename': 'misc_child/copied_goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:26',
#     'command': 'cp',
#     'full_command': 'cp goodbye.txt misc_child',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:26',
#     'command': 'cat',
#     'full_command': 'cat misc_child/goodbye.txt',
#     'stdout': 'goodbye beautiful\nworld',
#     'stderr': '',
#     'filename': 'misc_child/goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:27',
#     'command': 'mv',
#     'full_command': 'mv goodbye.txt renamed_goodbye.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'goodbye.txt',
#     'file': ''},
#    {'time': '2024-01-26:19:27',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child\nrenamed_goodbye.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:27',
#     'command': 'cat',
#     'full_command': 'cat renamed_goodbye.txt',
#     'stdout': 'goodbye beautiful\nworld',
#     'stderr': '',
#     'filename': 'renamed_goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:27',
#     'command': 'mv',
#     'full_command': 'mv renamed_goodbye.txt misc_child/',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'renamed_goodbye.txt',
#     'file': ''},
#    {'time': '2024-01-26:19:27',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:27',
#     'command': 'cat',
#     'full_command': 'cat misc_child/renamed_goodbye.txt',
#     'stdout': 'goodbye beautiful\nworld',
#     'stderr': '',
#     'filename': 'misc_child/renamed_goodbye.txt',
#     'file': 'goodbye beautiful\nworld'},
#    {'time': '2024-01-26:19:28',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:28',
#     'command': 'mv',
#     'full_command': 'mv hello.txt ~',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': ''},
#    {'time': '2024-01-26:19:28',
#     'command': 'cd',
#     'full_command': 'cd',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:28',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data-store\nhello.txt\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:29',
#     'command': 'ln',
#     'full_command': 'ln -s hello.txt linked_hello.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:29',
#     'command': 'cat',
#     'full_command': 'cat linked_hello.txt',
#     'stdout': 'Hello\nWorld',
#     'stderr': '',
#     'filename': 'linked_hello.txt',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:29',
#     'command': 'ls',
#     'full_command': 'ls -l linked_hello.txt',
#     'stdout': 'lrwxrwxrwx 1 jovyan users 9 Jan 26 19:29 linked_hello.txt -> hello.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:30',
#     'command': 'mkdir',
#     'full_command': 'mkdir link_test',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:30',
#     'command': 'ln',
#     'full_command': 'ln -s hello.txt link_test/hello.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:31',
#     'command': 'cd',
#     'full_command': 'cd link_test/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:31',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'hello.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:31',
#     'command': 'cat',
#     'full_command': 'cat hello.txt',
#     'stdout': '',
#     'stderr': 'cat: hello.txt: Too many levels of symbolic links',
#     'filename': 'hello.txt',
#     'file': ''},
#    {'time': '2024-01-26:19:31',
#     'command': 'ls',
#     'full_command': 'ls -l hello.txt',
#     'stdout': 'lrwxrwxrwx 1 jovyan users 9 Jan 26 19:30 hello.txt -> hello.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:31',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/link_test',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'ln',
#     'full_command': 'ln -s ../hello.txt hello.txt',
#     'stdout': '',
#     'stderr': "ln: failed to create symbolic link 'hello.txt': File exists",
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/link_test',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data-store\nhello.txt\nlinked_hello.txt\nlink_test\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'cd',
#     'full_command': 'cd link_test/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'ln',
#     'full_command': 'ln -s ../hello.txt hello.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:32',
#     'command': 'cat',
#     'full_command': 'cat hello.txt',
#     'stdout': 'Hello\nWorld',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:33',
#     'command': 'ls',
#     'full_command': 'ls -l hello.txt',
#     'stdout': 'lrwxrwxrwx 1 jovyan users 12 Jan 26 19:32 hello.txt -> ../hello.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:33',
#     'command': 'cd',
#     'full_command': 'cd',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:34',
#     'command': 'lx',
#     'full_command': 'lx',
#     'stdout': '',
#     'stderr': '/home/jovyan/.offline.sh: line 368: lx: command not found',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:34',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'data-store\nhello.txt\nlinked_hello.txt\nlink_test\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:34',
#     'command': 'cp',
#     'full_command': 'cp hello.txt copied_hello.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:34',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'copied_hello.txt\ndata-store\nhello.txt\nlinked_hello.txt\nlink_test\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:34',
#     'command': 'pico',
#     'filename': 'hello.txt',
#     'old_wc': 2,
#     'new_wc': 2,
#     'old_l': 2,
#     'new_l': 2,
#     'diff_wc': 0,
#     'diff_l': 0,
#     'total_time(s)': 19,
#     'stdout': '',
#     'stderr': '',
#     'file': 'Hello\nuniverse'},
#    {'time': '2024-01-26:19:35',
#     'command': 'cat',
#     'full_command': 'cat hello.txt',
#     'stdout': 'Hello\nuniverse',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': 'Hello\nuniverse'},
#    {'time': '2024-01-26:19:35',
#     'command': 'cat',
#     'full_command': 'cat linked_hello.txt',
#     'stdout': 'Hello\nuniverse',
#     'stderr': '',
#     'filename': 'linked_hello.txt',
#     'file': 'Hello\nuniverse'},
#    {'time': '2024-01-26:19:35',
#     'command': 'cat',
#     'full_command': 'cat copied_hello.txt',
#     'stdout': 'Hello\nWorld',
#     'stderr': '',
#     'filename': 'copied_hello.txt',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:35',
#     'command': 'diff',
#     'full_command': 'diff hello.txt copied_hello.txt',
#     'stdout': '2c2\n< universe\n---\n> World',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': 'Hello\nuniverse'},
#    {'time': '2024-01-26:19:36',
#     'command': 'diff',
#     'full_command': 'diff copied_hello.txt hello.txt',
#     'stdout': '2c2\n< World\n---\n> universe',
#     'stderr': '',
#     'filename': 'copied_hello.txt',
#     'file': 'Hello\nWorld'},
#    {'time': '2024-01-26:19:36',
#     'command': 'diff',
#     'full_command': 'diff hello.txt linked_hello.txt',
#     'stdout': '',
#     'stderr': '',
#     'filename': 'hello.txt',
#     'file': 'Hello\nuniverse'},
#    {'time': '2024-01-26:19:37',
#     'command': 'cp',
#     'full_command': 'cp ~/data-store/data/output/misc ~/misc',
#     'stdout': '',
#     'stderr': "cp: -r not specified; omitting directory '/home/jovyan/data-store/data/output/misc'",
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:37',
#     'command': 'cp',
#     'full_command': 'cp -r ~/data-store/data/output/misc ~/misc',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:37',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'copied_hello.txt\ndata-store\nhello.txt\nlinked_hello.txt\nlink_test\nmisc\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:37',
#     'command': 'cd',
#     'full_command': 'cd misc/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:37',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nls.out\nmisc_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:38',
#     'command': 'cd',
#     'full_command': 'cd misc_child/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:38',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'copied_goodbye.txt\necho.out\necho_output.txt\ngoodbye.txt\nmisc_child_child\nrenamed_goodbye.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:38',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:19:38',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:19:38',
#     'command': 'cd',
#     'full_command': 'cd misc/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:38',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/misc',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:38',
#     'command': 'mv',
#     'full_command': 'mv misc_child renamed_misc_child',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:38',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nls.out\nrenamed_misc_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:39',
#     'command': 'ln',
#     'full_command': 'ln -s renamed_misc_child linked_misc_child',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:39',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nlinked_misc_child\nls.out\nrenamed_misc_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:39',
#     'command': 'cd',
#     'full_command': 'cd renamed_misc_child/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:39',
#     'command': 'mkdir',
#     'full_command': 'mkdir misc_child_another_child',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:39',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'copied_goodbye.txt\necho.out\necho_output.txt\ngoodbye.txt\nmisc_child_another_child\nmisc_child_child\nrenamed_goodbye.txt',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:40',
#     'command': 'cd',
#     'full_command': 'cd ..',
#     'stdout': '',
#     'stderr': '',
#     'filename': '..',
#     'file': ''},
#    {'time': '2024-01-26:19:40',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nlinked_misc_child\nls.out\nrenamed_misc_child',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:41',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/misc',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:41',
#     'command': 'rm',
#     'filename': '-i',
#     'old_wc': 2,
#     'new_wc': 0,
#     'old_l': 2,
#     'new_l': 0,
#     'diff_wc': -2,
#     'diff_l': -2,
#     'total_time(s)': 0,
#     'stdout': '',
#     'stderr': '',
#     'file': ''},
#    {'time': '2024-01-26:19:41',
#     'command': 'rm',
#     'filename': '-i',
#     'old_wc': 2,
#     'new_wc': 0,
#     'old_l': 2,
#     'new_l': 0,
#     'diff_wc': -2,
#     'diff_l': -2,
#     'total_time(s)': 0,
#     'stdout': '',
#     'stderr': '',
#     'file': ''},
#    {'time': '2024-01-26:19:42',
#     'command': 'rm',
#     'filename': '-i',
#     'old_wc': 2,
#     'new_wc': 0,
#     'old_l': 2,
#     'new_l': 0,
#     'diff_wc': -2,
#     'diff_l': -2,
#     'total_time(s)': 0,
#     'stdout': '',
#     'stderr': '',
#     'file': ''},
#    {'time': '2024-01-26:19:48',
#     'command': '/bin/ls',
#     'full_command': '/bin/ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES/',
#     'stdout': 'Drug_A\nDrug_B',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:48',
#     'command': '/usr/bin/which',
#     'full_command': '/usr/bin/which ls',
#     'stdout': '/usr/bin/ls',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:49',
#     'command': 'echo',
#     'full_command': 'echo $PATH',
#     'stdout': '/opt/conda/bin:/opt/conda/condabin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/local/go/bin:/opt/gocommands',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:50',
#     'command': 'echo',
#     'full_command': 'echo PATH',
#     'stdout': 'PATH',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:50',
#     'command': 'echo',
#     'full_command': 'echo $HOME',
#     'stdout': '/home/jovyan',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:50',
#     'command': 'cd',
#     'full_command': 'cd',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:50',
#     'command': 'mkdir',
#     'full_command': 'mkdir bin',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:50',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'bin\ncopied_hello.txt\ndata-store\nhello.txt\nlinked_hello.txt\nlink_test\nmisc\nstderr.txt\nSuperShell\nwork',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:51',
#     'command': 'export',
#     'full_command': 'export PATH="$PATH:$HOME/bin"',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:52',
#     'command': 'cd',
#     'full_command': 'cd work/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:52',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:52',
#     'command': 'mkdir',
#     'full_command': 'mkdir Bash',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:52',
#     'command': 'cd',
#     'full_command': 'cd Bash/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:52',
#     'command': 'pwd',
#     'full_command': 'pwd',
#     'stdout': '/home/jovyan/work/Bash',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:53',
#     'command': 'ls',
#     'full_command': 'ls ~/data-store/data/input/Discover',
#     'stdout': '',
#     'stderr': "ls: cannot access '/home/jovyan/data-store/data/input/Discover': No such file or directory",
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:53',
#     'command': 'ls',
#     'full_command': 'ls ~/data-store/data/input/Discovery',
#     'stdout': 'FilteredSortedOutput\nRNASequenceOutput\nTSVFiles\nUncompressedSamples',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:53',
#     'command': 'ls',
#     'full_command': 'ls ~/data-store/data/input/Discovery/TSVFiles/',
#     'stdout': 'A_1_abundance.tsv\nA_2_abundance.tsv\nB_1_abundance.tsv\nB_2_abundance.tsv',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:54',
#     'command': 'mkdir',
#     'full_command': 'mkdir TSVFiles',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:55',
#     'command': 'ln',
#     'full_command': 'ln -s ~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv A_1_abundance.tsv',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:55',
#     'command': 'ls',
#     'full_command': 'ls -l',
#     'stdout': 'total 0\nlrwxrwxrwx 1 jovyan users 71 Jan 26 19:55 A_1_abundance.tsv -> /home/jovyan/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv\ndrwxr-sr-x 2 jovyan users 10 Jan 26 19:54 TSVFiles',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:55',
#     'command': 'ls',
#     'full_command': 'ls',
#     'stdout': 'TSVFiles',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:55',
#     'command': 'cd',
#     'full_command': 'cd TSVFiles/',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:55',
#     'command': 'ln',
#     'full_command': 'ln -s ~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv A_1_abundance.tsv',
#     'stdout': '',
#     'stderr': '',
#     'filename': '',
#     'file': ''},
#    {'time': '2024-01-26:19:55',
#     'command': 'ls',
#     'full_command': 'ls -l',
#     'stdout': 'total 0\nlrwxrwxrwx 1 jovyan users 71 Jan 26 19:55 A_1_abundance.tsv -> /home/jovyan/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#     'stderr': '',
#     'filename': '',
#     'file': ''}]}}

# %%
#Iterate and load all files in a folder
loaded = []
for i in os.listdir(data_folder):
    with open(data_folder + i, "r+") as f:
        load = json.load(f)
        loaded.append(load)
loaded
# Out:
# [{'_id': 'Bash:fcabd0f0-d6d7-4cda-954d-e03851cfde74',
#   '_rev': '4042-ae70190509cd64878bf585bce06a94f8',
#   'course_id': 'Cyverse-RNA-Tutorial',
#   'created_timestamp': '2023-03-23 20:50:41.672720',
#   'log': {'commands': [{'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls /home/jovyan',
#      'stderr': '',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'time': '2023-03-23:20:50'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '.',
#      'full_command': 'ls .',
#      'stderr': '',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'time': '2023-03-23:20:54'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'time': '2023-03-23:20:54'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '..',
#      'full_command': 'ls ..',
#      'stderr': '',
#      'stdout': 'jovyan',
#      'time': '2023-03-23:20:54'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#      'stderr': '',
#      'stdout': 'Drug_A\nDrug_B',
#      'time': '2023-03-23:20:54'},
#     {'command': 'ls',
#      'file': '',
#      'filename': './data-store/data/input/RNA_SEQ_SAMPLES',
#      'full_command': 'ls ./data-store/data/input/RNA_SEQ_SAMPLES',
#      'stderr': '',
#      'stdout': 'Drug_A\nDrug_B',
#      'time': '2023-03-23:20:55'},
#     {'command': 'ls',
#      'file': '',
#      'filename': 'stderr.txt',
#      'full_command': 'ls stderr.txt',
#      'stderr': '',
#      'stdout': 'stderr.txt',
#      'time': '2023-03-23:20:55'},
#     {'command': 'ls',
#      'file': '',
#      'filename': 'Stderr.txt',
#      'full_command': 'ls Stderr.txt',
#      'stderr': "ls: cannot access 'Stderr.txt': No such file or directory",
#      'stdout': '',
#      'time': '2023-03-23:20:57'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls –l data-store/data/input/Discovery/',
#      'stderr': "ls: cannot access '–l': No such file or directory",
#      'stdout': 'data-store/data/input/Discovery/:\nFilteredSortedOutput\nRNASequenceOutput\nTSVFiles\nUncompressedSamples',
#      'time': '2023-03-23:21:36'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls –l data-store/data/input/Discovery/TSVFiles',
#      'stderr': "ls: cannot access '–l': No such file or directory",
#      'stdout': 'data-store/data/input/Discovery/TSVFiles:\nA_1_abundance.tsv\nA_2_abundance.tsv\nB_1_abundance.tsv\nB_2_abundance.tsv',
#      'time': '2023-03-23:21:37'},
#     {'command': 'history',
#      'file': '',
#      'filename': '',
#      'full_command': 'history',
#      'stderr': '',
#      'stdout': ' 1 ls /home/jovyan\n 2 ls .\n 3 ls\n 4 ls ..\n 5 ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 6 ls ./data-store/data/input/RNA_SEQ_SAMPLES\n 7 ls stderr.txt\n 8 ls Stderr.txt\n 9 ls –l data-store/data/input/Discovery/\n 10 ls –l data-store/data/input/Discovery/TSVFiles\n 11 history',
#      'time': '2023-03-23:21:37'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls – l',
#      'stderr': "ls: cannot access '–': No such file or directory\nls: cannot access 'l': No such file or directory",
#      'stdout': '',
#      'time': '2023-03-23:21:38'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l',
#      'stderr': '',
#      'stdout': 'total 4\ndrwxrwsrwx 2 root jovyan 42 Mar 23 20:46 data-store\n-rw-r--r-- 1 jovyan users 0 Mar 23 21:38 stderr.txt\n-rw-r--r-- 1 jovyan users 0 Mar 23 21:38 stdout.txt\ndrwxr-xr-x 6 jovyan users 4096 Mar 23 20:50 SuperShell\ndrwsrwsr-x 2 jovyan users 10 May 3 2022 work',
#      'time': '2023-03-23:21:38'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l stderr.txt',
#      'stderr': '',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Mar 23 21:38 stderr.txt',
#      'time': '2023-03-23:21:38'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l ./data-store/data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#      'stderr': '',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Mar 23 21:38 stderr.txt\n\n./data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B',
#      'time': '2023-03-23:21:38'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l -R ./data-store/data/input/RNA_SEQ_SAMPLES/',
#      'stderr': '',
#      'stdout': './data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 0\n-r-------- 1 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-------- 1 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-------- 1 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 0\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#      'time': '2023-03-23:21:38'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd RNA_SEQ_SAMPLES',
#      'stderr': '/home/jovyan/.offline.sh: line 354: cd: RNA_SEQ_SAMPLES: No such file or directory',
#      'stdout': '',
#      'time': '2023-03-23:21:39'},
#     {'command': 'pwd',
#      'file': '',
#      'filename': '',
#      'full_command': 'pwd',
#      'stderr': '',
#      'stdout': '/home/jovyan',
#      'time': '2023-03-23:21:39'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'time': '2023-03-23:21:39'},
#     {'command': 'cd',
#      'file': '',
#      'filename': './data-store/data/input/RNA_SEQ_SAMPLES/',
#      'full_command': 'cd ./data-store/data/input/RNA_SEQ_SAMPLES/',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:40'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd Drug_A',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:41'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#      'time': '2023-03-23:21:41'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '..',
#      'full_command': 'cd ..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:41'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '..',
#      'full_command': 'cd ..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:41'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:41'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:42'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:42'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:42'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_A',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:43'},
#     {'command': 'which',
#      'file': '',
#      'filename': '',
#      'full_command': 'which ls',
#      'stderr': '',
#      'stdout': '/usr/bin/ls',
#      'time': '2023-03-23:21:43'},
#     {'command': 'which',
#      'file': '',
#      'filename': '',
#      'full_command': 'which cd',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:43'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:45'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '../..',
#      'full_command': 'cd ../..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:45'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd RNA_SEQ_SAMPLES/Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-23:21:45'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls –a',
#      'stderr': "ls: cannot access '–a': No such file or directory",
#      'stdout': '',
#      'time': '2023-03-23:21:45'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -a',
#      'stderr': '',
#      'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#      'time': '2023-03-24:00:31'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd /home/jovyan/data-store/data/output',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-24:00:32'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir misc',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-24:00:32'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd misc',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-24:00:32'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir misc_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-24:00:32'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'misc_child',
#      'time': '2023-03-24:00:33'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir misc_child/misc_child_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-24:00:33'}]},
#   'log_id': 'f54d00390f36c13144c7f51475d2cf8d855ec1e20c0ac0f8d18eed5b18768a71',
#   'log_type': 'Bash',
#   'machine_id': 'a426c',
#   'session_id': 'emilyshen',
#   'timestamp': '2023-03-26 20:45:53.781616'},
#  {'_id': 'Bash:ed392028-42cd-427a-a3ba-02dba9d0c80f',
#   '_rev': '156-25a1f0be2a5ff2229f45b092975e9c77',
#   'course_id': 'Cyverse-RNA-Tutorial',
#   'created_timestamp': '2023-03-30 17:12:54.184397',
#   'log': {'commands': [{'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls /home/jovyan',
#      'stderr': '',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'time': '2023-03-30:17:13'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '.',
#      'full_command': 'ls .',
#      'stderr': '',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'time': '2023-03-30:17:13'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '..',
#      'full_command': 'ls ..',
#      'stderr': '',
#      'stdout': 'jovyan',
#      'time': '2023-03-30:17:13'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#      'stderr': '',
#      'stdout': 'Drug_A\nDrug_B',
#      'time': '2023-03-30:17:13'},
#     {'command': 'ls',
#      'file': '',
#      'filename': './data-store/data/input/RNA_SEQ_SAMPLES',
#      'full_command': 'ls ./data-store/data/input/RNA_SEQ_SAMPLES',
#      'stderr': '',
#      'stdout': 'Drug_A\nDrug_B',
#      'time': '2023-03-30:17:14'},
#     {'command': 'ls',
#      'file': '',
#      'filename': 'stderr.txt',
#      'full_command': 'ls stderr.txt',
#      'stderr': '',
#      'stdout': 'stderr.txt',
#      'time': '2023-03-30:17:14'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l data-store/data/input/Discovery/',
#      'stderr': '',
#      'stdout': 'total 0\ndr-x------ 1 jovyan jovyan 0 Sep 9 2022 FilteredSortedOutput\ndr-x------ 1 jovyan jovyan 0 Sep 9 2022 RNASequenceOutput\ndr-x------ 1 jovyan jovyan 0 Sep 9 2022 TSVFiles\ndr-x------ 1 jovyan jovyan 0 Sep 9 2022 UncompressedSamples',
#      'time': '2023-03-30:17:15'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l data-store/data/input/Discovery/TSVFiles',
#      'stderr': '',
#      'stdout': 'total 0\n-r-------- 1 jovyan jovyan 6237689 Sep 8 2022 A_1_abundance.tsv\n-r-------- 1 jovyan jovyan 6135948 Sep 8 2022 A_2_abundance.tsv\n-r-------- 1 jovyan jovyan 6237909 Sep 8 2022 B_1_abundance.tsv\n-r-------- 1 jovyan jovyan 6237909 Sep 8 2022 B_2_abundance.tsv',
#      'time': '2023-03-30:17:16'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l',
#      'stderr': '',
#      'stdout': 'total 4\ndrwxrwsrwx 2 root jovyan 42 Mar 30 17:10 data-store\n-rw-r--r-- 1 jovyan users 0 Mar 30 17:16 stderr.txt\ndrwxr-xr-x 6 jovyan users 4096 Mar 30 17:12 SuperShell\ndrwsrwsr-x 2 jovyan users 10 May 3 2022 work',
#      'time': '2023-03-30:17:16'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l stderr.txt',
#      'stderr': '',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Mar 30 17:17 stderr.txt',
#      'time': '2023-03-30:17:17'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l ./data-store/data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#      'stderr': '',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Mar 30 17:17 stderr.txt\n\n./data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B',
#      'time': '2023-03-30:17:17'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l -R ./data-store/data/input/RNA_SEQ_SAMPLES/',
#      'stderr': '',
#      'stdout': './data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 1 jovyan jovyan 0 May 29 2020 Drug_B\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 0\n-r-------- 1 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-------- 1 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-------- 1 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 0\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-------- 1 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-------- 1 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#      'time': '2023-03-30:17:17'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd RNA_SEQ_SAMPLES',
#      'stderr': '/home/jovyan/.offline.sh: line 354: cd: RNA_SEQ_SAMPLES: No such file or directory',
#      'stdout': '',
#      'time': '2023-03-30:17:17'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd data-store/data/input/RNA_SEQ_SAMPLES/',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:18'},
#     {'command': 'pwd',
#      'file': '',
#      'filename': '',
#      'full_command': 'pwd',
#      'stderr': '',
#      'stdout': '/home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#      'time': '2023-03-30:17:18'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'Drug_A\nDrug_B',
#      'time': '2023-03-30:17:18'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '..',
#      'full_command': 'cd ..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:18'},
#     {'command': 'pwd',
#      'file': '',
#      'filename': '',
#      'full_command': 'pwd',
#      'stderr': '',
#      'stdout': '/home/jovyan/data-store/data/input',
#      'time': '2023-03-30:17:18'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '..',
#      'full_command': 'cd ..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:18'},
#     {'command': 'pwd',
#      'file': '',
#      'filename': '',
#      'full_command': 'pwd',
#      'stderr': '',
#      'stdout': '/home/jovyan/data-store/data',
#      'time': '2023-03-30:17:18'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:19'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:19'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:19'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:19'},
#     {'command': 'pwd',
#      'file': '',
#      'filename': '',
#      'full_command': 'pwd',
#      'stderr': '',
#      'stdout': '/home/jovyan',
#      'time': '2023-03-30:17:19'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_A',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:19'},
#     {'command': 'which',
#      'file': '',
#      'filename': '',
#      'full_command': 'which ls',
#      'stderr': '',
#      'stdout': '/usr/bin/ls',
#      'time': '2023-03-30:17:20'},
#     {'command': 'which',
#      'file': '',
#      'filename': '',
#      'full_command': 'which cd',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:20'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~/data-store/data/input/RNA_SEQ_SAMPLES/Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:20'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '../Drug_B',
#      'full_command': 'cd ../Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:20'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '../..',
#      'full_command': 'cd ../..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:21'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd RNA_SEQ_SAMPLES/Drug_B',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:21'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls –a',
#      'stderr': "ls: cannot access '–a': No such file or directory",
#      'stdout': '',
#      'time': '2023-03-30:17:21'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -a',
#      'stderr': '',
#      'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#      'time': '2023-03-30:17:21'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '-a.',
#      'full_command': 'ls -a.',
#      'stderr': "ls: invalid option -- '.'\nTry 'ls --help' for more information.",
#      'stdout': '',
#      'time': '2023-03-30:17:22'},
#     {'command': 'cd',
#      'file': '',
#      'filename': './../Drug_A',
#      'full_command': 'cd ./../Drug_A',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:23'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd /home/jovyan/data-store/data/output',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:24'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:24'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir misc',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:24'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'misc',
#      'time': '2023-03-30:17:24'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd misc',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:24'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir misc_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:25'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir misc_child/misc_child_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:25'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir misc_child/misc_child_child/misc_child_child_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:25'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'misc_child',
#      'time': '2023-03-30:17:25'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd misc_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:26'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'misc_child_child',
#      'time': '2023-03-30:17:26'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd misc_child_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:26'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'misc_child_child_child',
#      'time': '2023-03-30:17:26'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '../../../',
#      'full_command': 'cd ../../../',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:26'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir UncompressedSamples',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:26'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir FilteredSortedOutput',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:26'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir TSVFiles',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:26'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir PermissionsTest',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:27'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir bin',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:27'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'bin\nFilteredSortedOutput\nmisc\nPermissionsTest\nTSVFiles\nUncompressedSamples',
#      'time': '2023-03-30:17:27'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir PermissionsTest/PermissionsChild',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:29'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd misc',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:29'},
#     {'command': 'pico',
#      'diff_l': 2,
#      'diff_wc': 2,
#      'file': 'Hello\nWorld',
#      'filename': 'hello.txt',
#      'new_l': 2,
#      'new_wc': 2,
#      'old_l': 0,
#      'old_wc': 0,
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:30',
#      'total_time(s)': 69},
#     {'command': 'pico',
#      'diff_l': 2,
#      'diff_wc': 3,
#      'file': 'goodbye beautiful\nworld',
#      'filename': 'goodbye.txt',
#      'new_l': 2,
#      'new_wc': 3,
#      'old_l': 0,
#      'old_wc': 0,
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:31',
#      'total_time(s)': 23},
#     {'command': 'cat',
#      'file': 'Hello\nWorld',
#      'filename': 'hello.txt',
#      'full_command': 'cat hello.txt',
#      'stderr': '',
#      'stdout': 'Hello\nWorld',
#      'time': '2023-03-30:17:32'},
#     {'command': 'cat',
#      'file': 'Hello\nWorld',
#      'filename': 'hello.txt',
#      'full_command': 'cat hello.txt goodbye.txt',
#      'stderr': '',
#      'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld',
#      'time': '2023-03-30:17:32'},
#     {'command': 'cat',
#      'file': '',
#      'filename': '',
#      'full_command': 'cat',
#      'stderr': '',
#      'stdout': 'abc\ndef',
#      'time': '2023-03-30:17:33'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls > ls.out',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:34'},
#     {'command': 'cat',
#      'file': 'Hello\nWorld',
#      'filename': 'hello.txt',
#      'full_command': 'cat hello.txt goodbye.txt > hello_goodbye.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:34'},
#     {'command': 'cat',
#      'file': 'Hello\nWorld\ngoodbye beautiful\nworld',
#      'filename': 'hello_goodbye.txt',
#      'full_command': 'cat hello_goodbye.txt',
#      'stderr': '',
#      'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld',
#      'time': '2023-03-30:17:35'},
#     {'command': 'cat',
#      'file': '',
#      'filename': '',
#      'full_command': 'cat < hello.txt',
#      'stderr': '',
#      'stdout': 'Hello\nWorld',
#      'time': '2023-03-30:17:35'},
#     {'command': 'cat',
#      'file': '',
#      'filename': '',
#      'full_command': 'cat > cat.out',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:36'},
#     {'command': 'echo',
#      'file': '',
#      'filename': '',
#      'full_command': 'echo “hello world”',
#      'stderr': '',
#      'stdout': '“hello world”',
#      'time': '2023-03-30:17:36'},
#     {'command': 'echo',
#      'file': '',
#      'filename': '',
#      'full_command': 'echo 1 2',
#      'stderr': '',
#      'stdout': '1 2',
#      'time': '2023-03-30:17:36'},
#     {'command': 'echo',
#      'file': '',
#      'filename': '',
#      'full_command': 'echo “hello world” > misc_child/echo.out',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:36'},
#     {'command': 'echo',
#      'file': '',
#      'filename': '',
#      'full_command': 'echo “goodbye world” > misc_child/echo_output.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:37'},
#     {'command': 'cat',
#      'file': '“goodbye world”',
#      'filename': 'misc_child/echo_output.txt',
#      'full_command': 'cat misc_child/echo_output.txt',
#      'stderr': '',
#      'stdout': '“goodbye world”',
#      'time': '2023-03-30:17:37'},
#     {'command': 'echo',
#      'file': '',
#      'filename': '',
#      'full_command': 'echo “hello world” >> misc_child/echo_output.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:37'},
#     {'command': 'cat',
#      'file': '“goodbye world”\n“hello world”',
#      'filename': 'misc_child/echo_output.txt',
#      'full_command': 'cat misc_child/echo_output.txt',
#      'stderr': '',
#      'stdout': '“goodbye world”\n“hello world”',
#      'time': '2023-03-30:17:37'},
#     {'command': 'cat',
#      'file': 'Hello\nWorld',
#      'filename': 'hello.txt',
#      'full_command': 'cat hello.txt goodbye.txt hello_goodbye.txt ls.out cat',
#      'stderr': 'cat: cat: No such file or directory',
#      'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye beautiful\nworld\ngoodbye.txt\nhello.txt\nls.out\nmisc_child',
#      'time': '2023-03-30:17:38'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'cat.out\ngoodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#      'time': '2023-03-30:17:38'},
#     {'command': 'cat',
#      'file': '',
#      'filename': '',
#      'full_command': 'cat ~/data-store/data/output/misc/*',
#      'stderr': 'cat: /home/jovyan/data-store/data/output/misc/misc_child: Is a directory',
#      'stdout': '\rThis is cat input\nMore cat input\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld\ngoodbye.txt\nhello.txt\nls.out\nmisc_child',
#      'time': '2023-03-30:17:39'},
#     {'command': 'cat',
#      'file': 'Hello\nWorld\ngoodbye beautiful\nworld',
#      'filename': 'hello_goodbye.txt',
#      'full_command': 'cat hello_goodbye.txt hello.txt',
#      'stderr': '',
#      'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld',
#      'time': '2023-03-30:17:40'},
#     {'command': 'cat',
#      'file': 'Hello\nWorld\ngoodbye beautiful\nworld',
#      'filename': 'hello_goodbye.txt',
#      'full_command': 'cat hello_goodbye.txt hello.txt',
#      'stderr': '',
#      'stdout': 'Hello\nWorld\ngoodbye beautiful\nworld\nHello\nWorld',
#      'time': '2023-03-30:17:40'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls –l ~/*.txt',
#      'stderr': "ls: cannot access '–l': No such file or directory",
#      'stdout': '/home/jovyan/stderr.txt',
#      'time': '2023-03-30:17:40'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l ~/*.txt',
#      'stderr': '',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Mar 30 17:40 /home/jovyan/stderr.txt',
#      'time': '2023-03-30:17:40'},
#     {'command': 'echo',
#      'file': '\rThis is cat input\nMore cat input',
#      'filename': 'cat.out',
#      'full_command': 'echo cat.out goodbye.txt hello_goodbye.txt hello.txt ls.out misc_child',
#      'stderr': '',
#      'stdout': 'cat.out goodbye.txt hello_goodbye.txt hello.txt ls.out misc_child',
#      'time': '2023-03-30:17:41'},
#     {'command': 'echo',
#      'file': '',
#      'filename': '~/*.txt',
#      'full_command': 'echo ~/*.txt',
#      'stderr': '',
#      'stdout': '/home/jovyan/stderr.txt',
#      'time': '2023-03-30:17:41'},
#     {'command': 'cp',
#      'file': 'goodbye beautiful\nworld',
#      'filename': 'goodbye.txt',
#      'full_command': 'cp goodbye.txt copied_goodbye.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:42'},
#     {'command': 'cp',
#      'file': 'goodbye beautiful\nworld',
#      'filename': 'goodbye.txt',
#      'full_command': 'cp goodbye.txt misc_child/copied_goodbye.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:42'},
#     {'command': 'cp',
#      'file': 'goodbye beautiful\nworld',
#      'filename': 'goodbye.txt',
#      'full_command': 'cp goodbye.txt misc_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:43'},
#     {'command': 'ls',
#      'file': '',
#      'filename': './misc_child',
#      'full_command': 'ls ./misc_child',
#      'stderr': '',
#      'stdout': 'copied_goodbye.txt\necho.out\necho_output.txt\ngoodbye.txt\nmisc_child_child',
#      'time': '2023-03-30:17:43'},
#     {'command': 'mv',
#      'file': '',
#      'filename': 'goodbye.txt',
#      'full_command': 'mv goodbye.txt renamed_goodbye.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:43'},
#     {'command': 'mv',
#      'file': '',
#      'filename': 'renamed_goodbye.txt',
#      'full_command': 'mv renamed_goodbye.txt misc_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:44'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nhello.txt\nls.out\nmisc_child',
#      'time': '2023-03-30:17:45'},
#     {'command': 'mv',
#      'file': '',
#      'filename': 'hello.txt',
#      'full_command': 'mv hello.txt ~',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:45'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '..',
#      'full_command': 'cd ..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:45'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:45'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'data-store\nhello.txt\nstderr.txt\nSuperShell\nwork',
#      'time': '2023-03-30:17:45'},
#     {'command': 'ln',
#      'file': '',
#      'filename': '',
#      'full_command': 'ln -s hello.txt linked _hello.txt',
#      'stderr': "ln: target '_hello.txt' is not a directory",
#      'stdout': '',
#      'time': '2023-03-30:17:46'},
#     {'command': 'ln',
#      'file': '',
#      'filename': '',
#      'full_command': 'ln -s hello.txt linked_hello.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:17:46'},
#     {'command': 'cat',
#      'file': 'Hello\nWorld',
#      'filename': 'linked_hello.txt',
#      'full_command': 'cat linked_hello.txt',
#      'stderr': '',
#      'stdout': 'Hello\nWorld',
#      'time': '2023-03-30:17:46'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l linked_hello.txt',
#      'stderr': '',
#      'stdout': 'lrwxrwxrwx 1 jovyan users 9 Mar 30 17:46 linked_hello.txt -> hello.txt',
#      'time': '2023-03-30:17:46'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir link_test',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:39'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd link_test',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:39'},
#     {'command': 'ln',
#      'file': '',
#      'filename': '',
#      'full_command': 'ln -s ../hello.txt hello.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:39'},
#     {'command': 'cat',
#      'file': 'Hello\nWorld',
#      'filename': 'hello.txt',
#      'full_command': 'cat hello.txt',
#      'stderr': '',
#      'stdout': 'Hello\nWorld',
#      'time': '2023-03-30:19:39'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l hello.txt',
#      'stderr': '',
#      'stdout': 'lrwxrwxrwx 1 jovyan users 12 Mar 30 19:39 hello.txt -> ../hello.txt',
#      'time': '2023-03-30:19:39'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd ~',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:40'},
#     {'command': 'cp',
#      'file': 'Hello\nWorld',
#      'filename': 'hello.txt',
#      'full_command': 'cp hello.txt copied_hello.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:41'},
#     {'command': 'pico',
#      'diff_l': 0,
#      'diff_wc': 0,
#      'file': 'Hello\nUniverse',
#      'filename': 'hello.txt',
#      'new_l': 2,
#      'new_wc': 2,
#      'old_l': 2,
#      'old_wc': 2,
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:42',
#      'total_time(s)': 25},
#     {'command': 'cat',
#      'file': 'Hello\nUniverse',
#      'filename': 'hello.txt',
#      'full_command': 'cat hello.txt copied_hello.txt',
#      'stderr': '',
#      'stdout': 'Hello\nUniverse\nHello\nWorld',
#      'time': '2023-03-30:19:42'},
#     {'command': 'diff',
#      'file': 'Hello\nUniverse',
#      'filename': 'hello.txt',
#      'full_command': 'diff hello.txt copied_hello.txt',
#      'stderr': '',
#      'stdout': '2c2\n< Universe\n---\n> World',
#      'time': '2023-03-30:19:42'},
#     {'command': 'diff',
#      'file': 'Hello\nUniverse',
#      'filename': 'hello.txt',
#      'full_command': 'diff hello.txt linked_hello.txt',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:43'},
#     {'command': 'cp',
#      'file': '',
#      'filename': '',
#      'full_command': 'cp ~/data-store/data/output/misc ~/misc',
#      'stderr': "cp: -r not specified; omitting directory '/home/jovyan/data-store/data/output/misc'",
#      'stdout': '',
#      'time': '2023-03-30:19:43'},
#     {'command': 'cp',
#      'file': '',
#      'filename': '',
#      'full_command': 'cp -r ~/data-store/data/output/misc ~/misc',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:44'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls ~/data-store/data/output/misc',
#      'stderr': '',
#      'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nls.out\nmisc_child',
#      'time': '2023-03-30:19:44'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls ~/misc',
#      'stderr': '',
#      'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nls.out\nmisc_child',
#      'time': '2023-03-30:19:44'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd misc',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:45'},
#     {'command': 'mv',
#      'file': '',
#      'filename': '',
#      'full_command': 'mv misc_child renamed_misc_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:45'},
#     {'command': 'ln',
#      'file': '',
#      'filename': '',
#      'full_command': 'ln -s renamed_misc_child linked_misc_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:46'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir renamed_misc_child/misc_child_another_child',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:47'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'cat.out\ncopied_goodbye.txt\nhello_goodbye.txt\nlinked_misc_child\nls.out\nrenamed_misc_child',
#      'time': '2023-03-30:19:48'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls linked_misc_child',
#      'stderr': '',
#      'stdout': 'copied_goodbye.txt\necho.out\necho_output.txt\ngoodbye.txt\nmisc_child_another_child\nmisc_child_child\nrenamed_goodbye.txt',
#      'time': '2023-03-30:19:48'},
#     {'command': 'pwd',
#      'file': '',
#      'filename': '',
#      'full_command': 'pwd',
#      'stderr': '',
#      'stdout': '/home/jovyan/misc',
#      'time': '2023-03-30:19:48'},
#     {'command': 'rm',
#      'diff_l': -2,
#      'diff_wc': -2,
#      'file': '',
#      'filename': '-i',
#      'new_l': 0,
#      'new_wc': 0,
#      'old_l': 2,
#      'old_wc': 2,
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:49',
#      'total_time(s)': 0},
#     {'command': 'rm',
#      'diff_l': -2,
#      'diff_wc': -2,
#      'file': '',
#      'filename': '-i',
#      'new_l': 0,
#      'new_wc': 0,
#      'old_l': 2,
#      'old_wc': 2,
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:50',
#      'total_time(s)': 0},
#     {'command': 'rm',
#      'diff_l': -2,
#      'diff_wc': -2,
#      'file': '',
#      'filename': '-i',
#      'new_l': 0,
#      'new_wc': 0,
#      'old_l': 2,
#      'old_wc': 2,
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:50',
#      'total_time(s)': 6},
#     {'command': '/bin/ls',
#      'file': '',
#      'filename': '',
#      'full_command': '/bin/ls RNA_SEQ_SAMPLES',
#      'stderr': "/bin/ls: cannot access 'RNA_SEQ_SAMPLES': No such file or directory",
#      'stdout': '',
#      'time': '2023-03-30:19:51'},
#     {'command': '/usr/bin/which',
#      'file': '',
#      'filename': '',
#      'full_command': '/usr/bin/which ls',
#      'stderr': '',
#      'stdout': '/usr/bin/ls',
#      'time': '2023-03-30:19:51'},
#     {'command': 'export',
#      'file': '',
#      'filename': '',
#      'full_command': 'export PATH="$PATH:$HOME/bin"',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:52'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:53'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'copied_hello.txt\ndata-store\nhello.txt\nlinked_hello.txt\nlink_test\nmisc\nstderr.txt\nSuperShell\nwork',
#      'time': '2023-03-30:19:53'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd work',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:53'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:53'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir Bash',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:53'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd Bash',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:53'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls ~/data-store/data/input/Discovery',
#      'stderr': '',
#      'stdout': 'FilteredSortedOutput\nRNASequenceOutput\nTSVFiles\nUncompressedSamples',
#      'time': '2023-03-30:19:53'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls ~/data-store/data/input/Discovery/TSVFiles',
#      'stderr': '',
#      'stdout': 'A_1_abundance.tsv\nA_2_abundance.tsv\nB_1_abundance.tsv\nB_2_abundance.tsv',
#      'time': '2023-03-30:19:54'},
#     {'command': 'mkdir',
#      'file': '',
#      'filename': '',
#      'full_command': 'mkdir TSVFiles',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:55'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd TSVFiles',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:55'},
#     {'command': 'ln',
#      'file': '',
#      'filename': '',
#      'full_command': 'ln -s A_1_abundance.tsv ~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#      'stderr': "ln: failed to create symbolic link '/home/jovyan/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv': File exists",
#      'stdout': '',
#      'time': '2023-03-30:19:56'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#      'full_command': 'ls ~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv A_1_abundance.tsv',
#      'stderr': "ls: cannot access 'A_1_abundance.tsv': No such file or directory",
#      'stdout': '/home/jovyan/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#      'time': '2023-03-30:19:56'},
#     {'command': 'ln',
#      'file': '',
#      'filename': '',
#      'full_command': 'ln -s ~/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv A_1_abundance.tsv',
#      'stderr': '',
#      'stdout': '',
#      'time': '2023-03-30:19:57'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -l A_1_abundance.tsv',
#      'stderr': '',
#      'stdout': 'lrwxrwxrwx 1 jovyan users 71 Mar 30 19:57 A_1_abundance.tsv -> /home/jovyan/data-store/data/input/Discovery/TSVFiles/A_1_abundance.tsv',
#      'time': '2023-03-30:19:57'}]},
#   'log_id': 'ae49f45694333e9ca5064cfef20c95339d30c7c469fdd3144ca99f3a551bbe93',
#   'log_type': 'Bash',
#   'machine_id': 'a4797',
#   'session_id': 'gunings',
#   'timestamp': '2023-03-30 19:58:27.474415'},
#  {'_id': {'$oid': '65971be1bdd0ccda54bcd67c'},
#   'timestamp': '2024-01-04 21:41:32.859',
#   'log_id': '2e123e766d95c82542c279d77c559c8674d147874d538bb576ebb6f9d29fada5',
#   'machine_id': 'a6942',
#   'session_id': 'treesandwich4182',
#   'course_id': 'Cyverse-RNA-Tutorial',
#   'log_type': 'Bash',
#   'log': {'commands': [{'time': '2024-01-04:20:59',
#      'command': 'echo',
#      'full_command': 'echo yeah ok',
#      'stdout': 'yeah ok',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:20:59',
#      'command': 'ls',
#      'full_command': 'ls /home/jovyan/',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:20:59',
#      'command': 'ls',
#      'full_command': 'ls',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:20:59',
#      'command': 'ls',
#      'full_command': 'ls .',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'stderr': '',
#      'filename': '.',
#      'file': ''},
#     {'time': '2024-01-04:20:59',
#      'command': 'ls',
#      'full_command': 'ls ..',
#      'stdout': 'jovyan\nshiny',
#      'stderr': '',
#      'filename': '..',
#      'file': ''},
#     {'time': '2024-01-04:21:00',
#      'command': 'ls',
#      'full_command': 'ls ..jovyan',
#      'stdout': '',
#      'stderr': "ls: cannot access '..jovyan': No such file or directory",
#      'filename': '..jovyan',
#      'file': ''},
#     {'time': '2024-01-04:21:00',
#      'command': 'ls',
#      'full_command': 'ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES',
#      'stdout': 'Drug_A\nDrug_B',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:21:00',
#      'command': 'ls',
#      'full_command': 'ls ./data-store/data/input/RNA_SEQ_SAMPLES',
#      'stdout': 'Drug_A\nDrug_B',
#      'stderr': '',
#      'filename': './data-store/data/input/RNA_SEQ_SAMPLES',
#      'file': ''},
#     {'time': '2024-01-04:21:01',
#      'command': 'ls',
#      'full_command': 'ls stderr.txt',
#      'stdout': 'stderr.txt',
#      'stderr': '',
#      'filename': 'stderr.txt',
#      'file': ''},
#     {'time': '2024-01-04:21:02',
#      'command': 'ls',
#      'full_command': 'ls data-store/data/input/Discovery/',
#      'stdout': 'FilteredSortedOutput\nRNASequenceOutput\nTSVFiles\nUncompressedSamples',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:21:02',
#      'command': 'ls',
#      'full_command': 'ls -l data-store/data/input/Discovery/',
#      'stdout': 'total 0\ndr-x------ 0 jovyan jovyan 0 Jan 4 20:51 FilteredSortedOutput\ndr-x------ 0 jovyan jovyan 0 Jan 4 20:51 RNASequenceOutput\ndr-x------ 0 jovyan jovyan 0 Jan 4 20:51 TSVFiles\ndr-x------ 0 jovyan jovyan 0 Jan 4 20:51 UncompressedSamples',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:21:02',
#      'command': 'ls',
#      'full_command': 'ls -l data-store/data/input/Discovery/TSVFiles',
#      'stdout': 'total 24272\n-r-x------ 0 jovyan jovyan 6237689 Jan 4 20:00 A_1_abundance.tsv\n-r-x------ 0 jovyan jovyan 6135948 Jan 4 20:00 A_2_abundance.tsv\n-r-x------ 0 jovyan jovyan 6237909 Jan 4 20:00 B_1_abundance.tsv\n-r-x------ 0 jovyan jovyan 6237909 Jan 4 20:00 B_2_abundance.tsv',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:21:03',
#      'command': 'history',
#      'full_command': 'history',
#      'stdout': ' 1 sinfo\n 2 echo yeah ok\n 3 ls /home/jovyan/\n 4 ls\n 5 ls .\n 6 ls ..\n 7 ls ..jovyan\n 8 sinfo\n 9 shelp\n 10 ls /home/jovyan/data-store/data/input/RNA_SEQ_SAMPLES\n 11 \n 12 ls ./data-store/data/input/RNA_SEQ_SAMPLES\n 13 ls stderr.txt\n 14 ls data-store/data/input/Discovery/\n 15 ls -l data-store/data/input/Discovery/\n 16 ls -l data-store/data/input/Discovery/TSVFiles\n 17 history',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:21:05',
#      'command': 'ls',
#      'full_command': 'ls -l stderr.txt',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Jan 4 21:05 stderr.txt',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:21:05',
#      'command': 'ls',
#      'full_command': 'ls -l ./data-store/data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Jan 4 21:05 stderr.txt\n\n./data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_B',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2024-01-04:21:05',
#      'command': 'ls',
#      'full_command': 'ls -l -R ./data-store/data/input/RNA_SEQ_SAMPLES/',
# ...
#      'time': '2022-12-01:20:25'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#      'time': '2022-12-01:20:26'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls -a',
#      'stderr': '',
#      'stdout': 'Drug_B_1.fastq\nDrug_B_1.fastq.gz\nDrug_B_2.fastq\nDrug_B_2.fastq.gz',
#      'time': '2022-12-01:20:26'},
#     {'command': 'cd',
#      'file': '',
#      'filename': './../Drug_A',
#      'full_command': 'cd ./../Drug_A',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-12-01:20:26'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'Drug_A_1.fastq\nDrug_A_1.fastq.gz\nDrug_A_2.fastq\nDrug_A_2.fastq.gz',
#      'time': '2022-12-01:20:26'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '..',
#      'full_command': 'cd ..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-12-01:20:26'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'Drug_A\nDrug_B',
#      'time': '2022-12-01:20:26'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '..',
#      'full_command': 'cd ..',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-12-01:20:26'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'Bash\nDiscovery\nDNASubway\ngenome.fas\nRNA_SEQ_SAMPLES',
#      'time': '2022-12-01:20:26'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd Bash/',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-12-01:20:26'},
#     {'command': 'pwd',
#      'file': '',
#      'filename': '',
#      'full_command': 'pwd',
#      'stderr': '',
#      'stdout': '/home/jovyan/data/input/Bash',
#      'time': '2022-12-01:20:27'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-12-01:20:27'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-12-01:20:28'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-12-01:20:31'},
#     {'command': 'exut',
#      'file': '',
#      'filename': '',
#      'full_command': 'exut',
#      'stderr': '/home/jovyan/.offline.sh: line 368: exut: command not found',
#      'stdout': '',
#      'time': '2022-11-21:21:55'},
#     {'command': 'exut',
#      'file': '',
#      'filename': '',
#      'full_command': 'exut',
#      'stderr': '/home/jovyan/.offline.sh: line 368: exut: command not found',
#      'stdout': '',
#      'time': '2022-11-21:21:55'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls /home/jovyan',
#      'stderr': '',
#      'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#      'time': '2022-10-13:23:59'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#      'time': '2022-10-14:00:01'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls /home/jovyan/RNA_SEQ_SAMPLES',
#      'stderr': "ls: cannot access '/home/jovyan/RNA_SEQ_SAMPLES': No such file or directory",
#      'stdout': '',
#      'time': '2022-10-14:00:01'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls home',
#      'stderr': '',
#      'stdout': 'gunings\nshared',
#      'time': '2022-10-14:00:22'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls gunings/RNA_SEQ_SAMPLES',
#      'stderr': "ls: cannot access 'gunings/RNA_SEQ_SAMPLES': No such file or directory",
#      'stdout': '',
#      'time': '2022-10-14:00:22'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls /gunings/RNA_SEQ_SAMPLES',
#      'stderr': "ls: cannot access '/gunings/RNA_SEQ_SAMPLES': No such file or directory",
#      'stdout': '',
#      'time': '2022-10-14:00:22'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls gunings',
#      'stderr': "ls: cannot access 'gunings': No such file or directory",
#      'stdout': '',
#      'time': '2022-10-14:00:22'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd gunings',
#      'stderr': '/home/jovyan/.offline.sh: line 354: cd: gunings: No such file or directory',
#      'stdout': '',
#      'time': '2022-10-14:00:22'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'data\nhome\nstderr.txt\nSuperShell',
#      'time': '2022-10-14:00:23'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd home/gunings',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-10-14:00:23'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'analyses\nBash\nDiscovery\nDNASubway\nPermissionsTest',
#      'time': '2022-10-14:00:23'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-10-14:00:23'},
#     {'command': 'ls',
#      'file': '',
#      'filename': 'Stdout.txt',
#      'full_command': 'ls Stdout.txt',
#      'stderr': "ls: cannot access 'Stdout.txt': No such file or directory",
#      'stdout': '',
#      'time': '2022-10-14:00:23'},
#     {'command': 'clear',
#      'file': '',
#      'filename': '',
#      'full_command': 'clear',
#      'stderr': '',
#      'stdout': '\x1b[H\x1b[2J\x1b[3J',
#      'time': '2022-12-15:19:11'},
#     {'command': 'ls',
#      'file': '',
#      'filename': '',
#      'full_command': 'ls',
#      'stderr': '',
#      'stdout': 'data\nhome\nstderr.txt\nstdout.txt\nSuperShell',
#      'time': '2022-12-15:19:11'},
#     {'command': 'cd',
#      'file': '',
#      'filename': '',
#      'full_command': 'cd',
#      'stderr': '',
#      'stdout': '',
#      'time': '2022-12-15:19:14'},
#     {'command': 'clear',
#      'file': '',
#      'filename': '',
#      'full_command': 'clear',
#      'stderr': '',
#      'stdout': '\x1b[H\x1b[2J\x1b[3J',
#      'time': '2022-12-15:19:16'}]},
#   'log_id': '6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353411be02043e60902e7',
#   'log_type': 'Bash',
#   'machine_id': 'a9321',
#   'session_id': 'None',
#   'timestamp': '2022-09-30 01:51:00.512308'},
#  {'_id': {'$oid': '6584abbfbdd0ccda5497399a'},
#   'timestamp': '2023-12-21 21:39:05.18',
#   'log_id': '8090023b6fc6c30ba6852ec3e657289ec24344c46975fc1feede8b3ab5f4e2a7',
#   'machine_id': 'a8d37',
#   'session_id': 'johnsmith123',
#   'course_id': 'Cyverse-RNA-Tutorial',
#   'log_type': 'Bash',
#   'log': {'commands': [{'time': '2023-12-21:21:19',
#      'command': 'ls',
#      'full_command': 'ls /home/jovyan',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:19',
#      'command': 'ls',
#      'full_command': 'ls stderr.txt',
#      'stdout': 'stderr.txt',
#      'stderr': '',
#      'filename': 'stderr.txt',
#      'file': ''},
#     {'time': '2023-12-21:21:20',
#      'command': 'ls',
#      'full_command': 'ls',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:20',
#      'command': 'ls',
#      'full_command': 'ls Stderr.txt',
#      'stdout': '',
#      'stderr': "ls: cannot access 'Stderr.txt': No such file or directory",
#      'filename': 'Stderr.txt',
#      'file': ''},
#     {'time': '2023-12-21:21:20',
#      'command': 'ls',
#      'full_command': 'ls data-store/',
#      'stdout': 'data\nhome\nuser',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:21',
#      'command': 'ls',
#      'full_command': 'ls data-store/data/input/Discovery/',
#      'stdout': 'FilteredSortedOutput\nRNASequenceOutput\nTSVFiles\nUncompressedSamples',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:21',
#      'command': 'history',
#      'full_command': 'history',
#      'stdout': ' 1 ls /home/jovyan\n 2 ls stderr.txt\n 3 ls\n 4 ls Stderr.txt\n 5 ls data-store/\n 6 ls data-store/data/input/Discovery/\n 7 history',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:22',
#      'command': 'ls',
#      'full_command': 'ls data-store/data/input/Discovery/',
#      'stdout': 'FilteredSortedOutput\nRNASequenceOutput\nTSVFiles\nUncompressedSamples',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:22',
#      'command': 'ls',
#      'full_command': 'ls -l data-store/data/input/Discovery/',
#      'stdout': 'total 0\ndr-x------ 0 jovyan jovyan 0 Dec 21 21:07 FilteredSortedOutput\ndr-x------ 0 jovyan jovyan 0 Dec 21 21:07 RNASequenceOutput\ndr-x------ 0 jovyan jovyan 0 Dec 21 21:07 TSVFiles\ndr-x------ 0 jovyan jovyan 0 Dec 21 21:07 UncompressedSamples',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:22',
#      'command': 'ls',
#      'full_command': 'ls -l data-store/data/input/Discovery/TSVFiles',
#      'stdout': 'total 24272\n-r-x------ 0 jovyan jovyan 6237689 Dec 21 20:00 A_1_abundance.tsv\n-r-x------ 0 jovyan jovyan 6135948 Dec 21 20:00 A_2_abundance.tsv\n-r-x------ 0 jovyan jovyan 6237909 Dec 21 20:00 B_1_abundance.tsv\n-r-x------ 0 jovyan jovyan 6237909 Dec 21 20:00 B_2_abundance.tsv',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:23',
#      'command': 'ls',
#      'full_command': 'ls home',
#      'stdout': '',
#      'stderr': "ls: cannot access 'home': No such file or directory",
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:23',
#      'command': 'ls',
#      'full_command': 'ls ./',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'stderr': '',
#      'filename': './',
#      'file': ''},
#     {'time': '2023-12-21:21:23',
#      'command': 'ls',
#      'full_command': 'ls',
#      'stdout': 'data-store\nstderr.txt\nstdout.txt\nSuperShell\nwork',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:23',
#      'command': 'ls',
#      'full_command': 'ls home',
#      'stdout': '',
#      'stderr': "ls: cannot access 'home': No such file or directory",
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:24',
#      'command': 'ls',
#      'full_command': 'ls ../',
#      'stdout': 'jovyan\nshiny',
#      'stderr': '',
#      'filename': '../',
#      'file': ''},
#     {'time': '2023-12-21:21:25',
#      'command': 'ls',
#      'full_command': 'ls -l',
#      'stdout': 'total 0\ndrwxrwsrwx 3 root jovyan 58 Dec 21 21:18 data-store\n-rw-r--r-- 1 jovyan users 0 Dec 21 21:25 stderr.txt\n-rw-r--r-- 1 jovyan users 0 Dec 21 21:25 stdout.txt\ndrwxr-sr-x 1 jovyan users 39 Oct 25 17:57 SuperShell\ndrwsrwsr-x 2 jovyan users 10 Mar 20 2023 work',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:26',
#      'command': 'ls',
#      'full_command': 'ls -l stderr.txt',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Dec 21 21:26 stderr.txt',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:26',
#      'command': 'ls',
#      'full_command': 'ls -l ./data-store/data/input/RNA_SEQ_SAMPLES/ stderr.txt',
#      'stdout': '-rw-r--r-- 1 jovyan users 0 Dec 21 21:26 stderr.txt\n\n./data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_B',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:26',
#      'command': 'ls',
#      'full_command': 'ls -l -R ./data-store/data/input/RNA_SEQ_SAMPLES/',
#      'stdout': './data-store/data/input/RNA_SEQ_SAMPLES/:\ntotal 0\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_A\ndr-x------ 0 jovyan jovyan 0 May 29 2020 Drug_B\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_A:\ntotal 9024\n-r-x------ 0 jovyan jovyan 3677295 May 20 2020 Drug_A_1.fastq\n-r-x------ 0 jovyan jovyan 804307 May 20 2020 Drug_A_1.fastq.gz\n-r-x------ 0 jovyan jovyan 3978812 May 22 2020 Drug_A_2.fastq\n-r-x------ 0 jovyan jovyan 772800 May 20 2020 Drug_A_2.fastq.gz\n\n./data-store/data/input/RNA_SEQ_SAMPLES/Drug_B:\ntotal 9392\n-r-x------ 0 jovyan jovyan 3978812 May 20 2020 Drug_B_1.fastq\n-r-x------ 0 jovyan jovyan 827189 May 22 2020 Drug_B_1.fastq.gz\n-r-x------ 0 jovyan jovyan 3978812 May 20 2020 Drug_B_2.fastq\n-r-x------ 0 jovyan jovyan 827189 May 22 2020 Drug_B_2.fastq.gz',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:27',
#      'command': 'ls',
#      'full_command': 'ls -l ./SuperShell',
#      'stdout': 'total 60364\n-rwxr-xr-x 1 jovyan users 47 Oct 25 17:57 add_interactive.sh\n-rwxr-xr-x 1 jovyan users 7154 Oct 25 17:57 codehelper.sh\n-rwxr-xr-x 1 jovyan users 9953 Oct 25 17:57 consent.txt\n-rwxr-xr-x 1 jovyan users 20 Oct 25 17:57 courseid.txt\n-rwxr-xr-x 1 jovyan users 440 Oct 25 17:57 cyverse_install.sh\n-rwxr-xr-x 1 jovyan users 82 Oct 25 17:57 disable_help.sh\n-rwxr-xr-x 1 jovyan users 493 Oct 25 17:57 docker_install.sh\n-rwxr-xr-x 1 jovyan users 83 Oct 25 17:57 enable_help.sh\n-rwxr-xr-x 1 jovyan users 256548 Oct 25 17:57 flowchart.png\ndrwxr-sr-x 2 jovyan users 239 Oct 25 17:57 images\n-rwxr-xr-x 1 jovyan users 449 Oct 25 17:57 install.sh\n-rwxr-xr-x 1 jovyan users 71 Oct 25 17:57 install_supershell.sh\n-rwxr-xr-x 1 jovyan users 25 Oct 25 17:57 interactive.txt\n-rwxr-xr-x 1 jovyan users 1074 Oct 25 17:57 LICENSE\n-rwxr-xr-x 1 jovyan users 678 Oct 25 17:57 linux_install.sh\n-rwxr-xr-x 1 jovyan users 699 Oct 25 17:57 mac_install.sh\n-rwxr-xr-x 1 jovyan users 0 Oct 25 17:57 mail.txt\n-rwxr-xr-x 1 jovyan users 39814 Oct 25 17:57 offline.sh\n-rwxr-xr-x 1 jovyan users 18137 Oct 25 17:57 offline_with_online.sh\n-rwxr-xr-x 1 jovyan users 2001 Oct 25 17:57 push_events.sh\n-rwxr-xr-x 1 jovyan users 3446 Oct 25 17:57 README.md\n-rwxr-xr-x 1 jovyan users 15 Oct 25 17:57 ruledir.txt\n-rwxr-xr-x 1 jovyan users 339 Oct 25 17:57 session_extract.sh\n-rwxr-xr-x 1 jovyan users 6105 Oct 25 17:57 shell2.sh\n-rwxr-xr-x 1 jovyan users 6101 Oct 25 17:57 shell.sh\ndrwxr-sr-x 2 jovyan users 71 Oct 25 17:57 StatParam\n-rwxr-xr-x 1 jovyan users 62 Oct 25 17:57 supershellhelpmessage.txt\n-rwxr-xr-x 1 jovyan users 3 Oct 25 17:57 supershellhelp.txt\ndrwxr-sr-x 1 jovyan users 55 Dec 21 21:18 SuperShellHistory\n-rwxr-xr-x 1 jovyan users 2118 Oct 25 17:57 supershellinfo.txt\ndrwxr-sr-x 3 jovyan users 144 Oct 25 17:57 SuperShellRules\n-rwxr-xr-x 1 jovyan users 30522687 Oct 25 17:57 TestSender2.jar\n-rwxr-xr-x 1 jovyan users 30523328 Oct 25 17:57 TestSender.jar\n-rwxr-xr-x 1 jovyan users 1195 Oct 25 17:57 title.txt\n-rwxr-xr-x 1 jovyan users 326139 Oct 25 17:57 Towards a Helpful Shell_ Scenarios and Commands.pdf',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:33',
#      'command': 'cd',
#      'full_command': 'cd',
#      'stdout': '',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:36',
#      'command': 'which',
#      'full_command': 'which pwd',
#      'stdout': '/usr/bin/pwd',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:36',
#      'command': 'which',
#      'full_command': 'which cd',
#      'stdout': '',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:36',
#      'command': 'which',
#      'full_command': 'which which',
#      'stdout': '/usr/bin/which',
#      'stderr': '',
#      'filename': '',
#      'file': ''},
#     {'time': '2023-12-21:21:36',
#      'command': 'which',
#      'full_command': 'which echo',
#      'stdout': '/usr/bin/echo',
#      'stderr': '',
#      'filename': '',
#      'file': ''}]}}]

# %% [markdown]
# # Process Data

# %% [markdown]
# ## Build Command Records - Array of JSON Objects

# %%
what_it_expects = [{"Animal": "Cat", "Size": "Medium"}, {"Animal": "Dog", "Size": "Large"}]
pd.DataFrame.from_records(what_it_expects)
# Out:
#   Animal    Size
# 0    Cat  Medium
# 1    Dog   Large

# %%
raw_records = []
log_list = raw_json['log']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    machine_id = i['machine_id']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        #Build the common columns for all events
        to_add = {
            "Log ID": log_id, 
            "Course": course, 
            "Log Type": log_type,
        }
        
        #add to dict with equal
        to_add['Machine ID'] = machine_id
        
        #Add each command to array and update 
        to_add.update(event)
        
        #Sometimes processing type prior to building frame is easiest
        #For example, pandas can understand datetime, but right now it is a string. 
        #Convert the time into a string using this datetime function.
        to_add['time'] = datetime.strptime(to_add['time'], "%Y-%m-%d:%H:%M")
        
        raw_records.append(to_add)

#Look at the records we have made
raw_records[0:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 log_list = raw_json['log']
#       3 for i in log_list:
#       4     #Variables to keep at the highest level
# ----> 5     log_id = i['log_id']
#       6     course = i['course_id']
#       7     log_type = i['log_type']
#
# TypeError: string indices must be integers, not 'str'

# %%
## Convert to Pandas Dataframe 
pd_records = pd.DataFrame.from_records(raw_records)
pd_records.head()
# Out:
#                                               Log ID         Course Log Type  \
# 0  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 1  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 2  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 3  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
# 4  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...  Comp-512-Test     Bash
#
#   Machine ID command file filename                 full_command  \
# 0   10bcd15c      ls                                         ls
# 1   10bcd15c  export                         export $TEST=Hello
# 2   10bcd15c  export                       export $TEST='Hello'
# 3   10bcd15c  export                export PATH=$PATH:$HOME/bin
# 4   10bcd15c  export                 export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#                  time  diff_l  diff_wc  new_l  new_wc  old_l  old_wc  \
# 0 2021-04-19 19:34:00     NaN      NaN    NaN     NaN    NaN     NaN
# 1 2021-04-19 19:35:00     NaN      NaN    NaN     NaN    NaN     NaN
# 2 2021-04-19 19:35:00     NaN      NaN    NaN     NaN    NaN     NaN
# 3 2021-04-19 19:36:00     NaN      NaN    NaN     NaN    NaN     NaN
# 4 2021-04-19 19:36:00     NaN      NaN    NaN     NaN    NaN     NaN
#
#    total_time(s)
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
print(max(pd_records['time']))
pd_records.info()
# Out:
# 2023-04-09 15:53:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Log ID         1070 non-null   object
#  1   Course         1070 non-null   object
#  2   Log Type       1070 non-null   object
#  3   Machine ID     1070 non-null   object
#  4   command        1070 non-null   object
#  5   file           1070 non-null   object
#  6   filename       1070 non-null   object
#  7   full_command   1049 non-null   object
#  8   stderr         1070 non-null   object
#  9   stdout         1070 non-null   object
#  10  time           1070 non-null   datetime64[ns]
#  11  diff_l         21 non-null     float64
#  12  diff_wc        21 non-null     float64
#  13  new_l          21 non-null     float64
#  14  new_wc         21 non-null     float64
#  15  old_l          21 non-null     float64
#  16  old_wc         21 non-null     float64
#  17  total_time(s)  21 non-null     float64
# dtypes: datetime64[ns](1), float64(7), object(10)
# memory usage: 150.6+ KB

# %% [markdown]
# ## Build Command Records - JSON of Arrays

# %%
high_level_json = {
    "Log ID": [],
    "Course": [],
    "Log Type": [], 
    "command": [],
    "file": [],
    "filename": [], 
    "full_command": [],
    "stderr": [],
    "stdout": [],
    "time": []
}
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        #Build the common columns for all events
        high_level_json['Log ID'].append(log_id)
        high_level_json['Course'].append(course)
        high_level_json['Log Type'].append(log_type)
        
        for i in event: 
            high_level_json[i].append(event[i])
        
        #Note it is a little more difficult to convert these strings here.
        #You could do an if in the for i in event statement 
        #We will leverage Pandas datetime function to do this for us. 
        

#Look at the JSON
high_level_json
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e85c11f36819> in <module>
#      26
#      27         for i in event:
# ---> 28             high_level_json[i].append(event[i])
#      29
#      30         #Note it is a little more difficult to convert these strings here.
#
# KeyError: 'diff_l'

# %%
## Convert to Dataframe 
pd_from_json = pd.DataFrame.from_dict(high_level_json)
pd_from_json.head()
# Out:
#                                               Log ID                Course  \
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 1  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 2  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 3  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 4  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
#
#   Log Type command file filename full_command  \
# 0     Bash      ls                         ls
# 1     Bash      ls             .         ls .
# 2     Bash   clear                      clear
# 3     Bash      cd                    cd Bash
# 4     Bash      cd                    cd home
#
#                                               stderr  \
# 0
# 1
# 2
# 3  /home/jovyan/.offline.sh: line 354: cd: Bash: ...
# 4
#
#                                stdout              time
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:19
# 1  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:20
# 2                           2022-09-29:19:20
# 3                                      2022-09-29:19:24
# 4                                      2022-09-29:19:24

# %%
## Notice Types 
pd_from_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Log ID        27 non-null     object
#  1   Course        27 non-null     object
#  2   Log Type      27 non-null     object
#  3   command       27 non-null     object
#  4   file          27 non-null     object
#  5   filename      27 non-null     object
#  6   full_command  27 non-null     object
#  7   stderr        27 non-null     object
#  8   stdout        27 non-null     object
#  9   time          27 non-null     object
# dtypes: object(10)
# memory usage: 2.2+ KB

# %%
## Time is an object, we want these to be datetimes, can do this in pandas 
pd_from_json['Timestamp'] = pd.to_datetime(pd_from_json['time'], format="%Y-%m-%d:%H:%M")
print(max(pd_from_json['time']))
print(max(pd_from_json['Timestamp']))
pd_from_json.info()
# Out:
# 2022-10-14:00:23
# 2022-10-14 00:23:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Log ID        27 non-null     object
#  1   Course        27 non-null     object
#  2   Log Type      27 non-null     object
#  3   command       27 non-null     object
#  4   file          27 non-null     object
#  5   filename      27 non-null     object
#  6   full_command  27 non-null     object
#  7   stderr        27 non-null     object
#  8   stdout        27 non-null     object
#  9   time          27 non-null     object
#  10  Timestamp     27 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 2.4+ KB

# %% [markdown]
# ## Build Command Records - DataFrame Hybrid

# %%
base_frame = pd.DataFrame()
log_list = raw_json['logs']
for i in log_list:
    #Variables to keep at the highest level
    log_id = i['log_id']
    course = i['course_id']
    log_type = i['log_type']
    
    #Base unit is the series of commands. 
    for event in i['log']['commands']:
        
        #Build a dataframe for the smallest unit
        subframe = pd.DataFrame.from_records([event])
        
        #Add common fields to subframe 
        subframe['Log ID'] = log_id
        subframe['Course'] = course
        subframe['Log Type'] = log_type
        
        if base_frame.shape[0] == 0:
            base_frame = subframe
            # breaks out of for loop 
            # a nifty command
            continue 
            
        base_frame = pd.concat([base_frame, subframe])
        

base_frame.head()
# Out:
#   command file filename full_command  \
# 0      ls                         ls
# 0      ls             .         ls .
# 0   clear                      clear
# 0      cd                    cd Bash
# 0      cd                    cd home
#
#                                               stderr  \
# 0
# 0
# 0
# 0  /home/jovyan/.offline.sh: line 354: cd: Bash: ...
# 0
#
#                                stdout              time  \
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:19
# 0  data\nhome\nstderr.txt\nSuperShell  2022-09-29:19:20
# 0                           2022-09-29:19:20
# 0                                      2022-09-29:19:24
# 0                                      2022-09-29:19:24
#
#                                               Log ID                Course  \
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
# 0  6c940b1fbdd022d6db2d5840dfd7207c30a060b05b4353...  Cyverse-RNA-Tutorial
#
#   Log Type
# 0     Bash
# 0     Bash
# 0     Bash
# 0     Bash
# 0     Bash

# %%
## Clean up again 
## Time is an object, we want these to be datetimes, can do this in pandas 
base_frame['Timestamp'] = pd.to_datetime(base_frame['time'], format="%Y-%m-%d:%H:%M")
base_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 0
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   command       27 non-null     object
#  1   file          27 non-null     object
#  2   filename      27 non-null     object
#  3   full_command  27 non-null     object
#  4   stderr        27 non-null     object
#  5   stdout        27 non-null     object
#  6   time          27 non-null     object
#  7   Log ID        27 non-null     object
#  8   Course        27 non-null     object
#  9   Log Type      27 non-null     object
#  10  Timestamp     27 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 2.5+ KB

# %% [markdown]
# # Export Dataframe

# %%
#This will allow you to manipulate what you export and not effect pd_records
to_export = pd_records.copy()

#Some column manipulation can be useful 
column_list = list(to_export.columns)

#You can reorder like so 
column_list.remove('time')
column_list = ["time"] + column_list
print(column_list)

#Rearrange columns, time is now the first column
to_export = to_export[column_list]
to_export.head()
# Out:
# ['time', 'Log ID', 'Course', 'Log Type', 'Machine ID', 'command', 'file', 'filename', 'full_command', 'stderr', 'stdout', 'diff_l', 'diff_wc', 'new_l', 'new_wc', 'old_l', 'old_wc', 'total_time(s)']
#                  time                                             Log ID  \
# 0 2021-04-19 19:34:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 1 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 2 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 3 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 4 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
#
#           Course Log Type Machine ID command file filename  \
# 0  Comp-512-Test     Bash   10bcd15c      ls
# 1  Comp-512-Test     Bash   10bcd15c  export
# 2  Comp-512-Test     Bash   10bcd15c  export
# 3  Comp-512-Test     Bash   10bcd15c  export
# 4  Comp-512-Test     Bash   10bcd15c  export
#
#                   full_command  \
# 0                           ls
# 1           export $TEST=Hello
# 2         export $TEST='Hello'
# 3  export PATH=$PATH:$HOME/bin
# 4   export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#    diff_l  diff_wc  new_l  new_wc  old_l  old_wc  total_time(s)
# 0     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 3     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN            NaN

# %%
# Make sure to add the suffix to the file name. You can also give path 
to_export.to_csv(output_dir + "response4.csv")

# %%
# If you are going to import to pandas later, I suggest pickle file 
# This will preserve types such as datetimes 
to_export.to_pickle(output_dir + "response4.pki")

# %% [markdown]
# # Read Back to Check

# %%
reloaded = pd.read_pickle(output_dir + "response2.pki")
reloaded.head()
# Out:
#                  time                                             Log ID  \
# 0 2021-04-19 19:34:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 1 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 2 2021-04-19 19:35:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 3 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
# 4 2021-04-19 19:36:00  490cd3ad601e875614199fc11aa5ebe2ad67d289cbe519...
#
#           Course Log Type Machine ID command file filename  \
# 0  Comp-512-Test     Bash   10bcd15c      ls
# 1  Comp-512-Test     Bash   10bcd15c  export
# 2  Comp-512-Test     Bash   10bcd15c  export
# 3  Comp-512-Test     Bash   10bcd15c  export
# 4  Comp-512-Test     Bash   10bcd15c  export
#
#                   full_command  \
# 0                           ls
# 1           export $TEST=Hello
# 2         export $TEST='Hello'
# 3  export PATH=$PATH:$HOME/bin
# 4   export PATH=$PATH:test/bin
#
#                                               stderr                  stdout  \
# 0                                                     SuperShell\nstderr.txt
# 1  /home/supershell/.offline.sh: line 358: export...
# 2  /home/supershell/.offline.sh: line 358: export...
# 3
# 4
#
#    diff_l  diff_wc  new_l  new_wc  old_l  old_wc  total_time(s)
# 0     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 3     NaN      NaN    NaN     NaN    NaN     NaN            NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN            NaN

# %%
reloaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           333 non-null    datetime64[ns]
#  1   Log ID         333 non-null    object
#  2   Course         333 non-null    object
#  3   Log Type       333 non-null    object
#  4   Machine ID     333 non-null    object
#  5   command        333 non-null    object
#  6   file           333 non-null    object
#  7   filename       333 non-null    object
#  8   full_command   326 non-null    object
#  9   stderr         333 non-null    object
#  10  stdout         333 non-null    object
#  11  diff_l         7 non-null      float64
#  12  diff_wc        7 non-null      float64
#  13  new_l          7 non-null      float64
#  14  new_wc         7 non-null      float64
#  15  old_l          7 non-null      float64
#  16  old_wc         7 non-null      float64
#  17  total_time(s)  7 non-null      float64
# dtypes: datetime64[ns](1), float64(7), object(10)
# memory usage: 47.0+ KB
